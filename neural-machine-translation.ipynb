# %% [markdown]
# # Translation with a Sequence to Sequence Network
#
# This project is split into two sections: Neural Machine Translation with (1) RNNs and (2) Transformer. To be more specifically, in Machine Translation, our goal is to convert a sentence from the source language (e.g. Vietnamese) to the target language (e.g. English). In this project, we will implement a sequence-to-sequence (Seq2Seq) network based on two architectures: **RNNs with Attention** and **Transformer**, to build a Neural Machine Translation (NMT) system.

# %% [markdown]
# That's a lot to digest, the goal of this project is to break it down into easy to understand parts. In this project we will:
#
# - Prepare the data.
# - Implement necessary components:
#     - With RNNs and attention architecture:
#         - Embedding Layer: to initialize the necessary word embeddings
#         - Declare basic components of our model.
#         - The Encoder & Decoder
#
#     - With Transformer Architecture:
#         - Positional embeddings.
#         - Transformer Layer
#
# - Build & train two our models.
# - Generate translations.

# %% [markdown]
# **Requirements**
#
# Firstly, apart from standards libraries, we need to install some package:
#
# 1, *sentencepiece*: To build our own vocabulary \\
# 2, *sacrebleu*: To evaluate our model using BLUE score metric

# %%
# %%capture
# !pip install sentencepiece==0.1.97
# !pip install tqdm==4.29.1
# !pip install sacrebleu
# !pip install nltk

# %% [markdown]
# Below, we import our standard libraries.

# %%
# Standard libraries
import sys
import json
import time
import math
import numpy as np
from typing import List, Tuple, Dict, Set, Union
from collections import Counter, namedtuple
from itertools import chain
from dataclasses import dataclass

# to compute BLUE score
import sacrebleu

# Pytorch
import torch
import torch.nn as nn
import torch.nn.utils
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence

# To train vocabulary
import sentencepiece as spm

# Ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/VietAI/ASM
# Out:
# /content/drive/MyDrive/Colab Notebooks/VietAI/ASM

# %%
#@title Default hyperparameters
@dataclass
class Args:
    cuda: str = "cuda:0"
    train_src: str = "data/train.vi"
    train_tgt: str = "data/train.en"
    dev_src: str = "data/dev.vi"
    dev_tgt: str = 'data/dev.en'
    vocab_file: str = 'vocab.json'
    src_vocab_size: int = 15000
    tgt_vocab_size: int = 21000
    seed: int = 0
    batch_size: int = 32
    max_len: int = 320
    embed_size: int = 1024
    hidden_size: int = 768
    clip_grad: float = 5.0                  # gradient clipping
    log_every: int = 10                     # log every
    max_epoch: int = 30                     # max epoch
    patience: int = 5                       # wait for how many iterations to decay learning rate
    max_num_trial: int = 5                  # terminate training after how many trials
    lr_decay: float = 0.5                   # learning rate decay
    beam_size: int = 5                      # beam size
    lr: float = 0.001                       # learning rate
    uniform_init: float = 0.1               # uniformly initialize all parameters
    model_save_path: str = 'lstm_model.bin' # model save path
    valid_niter: int = 2000                 # perform validation after how many iterations
    dropout: float = 0.3    
    max_decoding_time_step: int = 70        # maximum number of decoding time steps

args = Args()
device = torch.device(args.cuda) if torch.cuda.is_available() else torch.device("cpu")

seed = int(args.seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed * 13 // 7)

# %% [markdown]
# Loading data files
# ==================
#
# The data for this project is a set of many thousands of Vietnamese to
# English translation pairs. We will download them first then save to 'data' folder.

# %%
# %%capture
# !pip install gdown
# !mkdir data
import gdown

data_path = 'https://drive.google.com/file/d/1eq68XlKxWBFCj4YgMRl2N5YdrZvB9FDs/view?usp=sharing'
gdown.download(data_path, args.train_src, quiet=False, fuzzy=True)

data_path = 'https://drive.google.com/file/d/1679j2kIvdl8Oe_WRSX0vi62JtOrhr1GD/view?usp=sharing'
gdown.download(data_path, args.train_tgt, quiet=False, fuzzy=True)

data_path = 'https://drive.google.com/file/d/1p0tBxnD-MVXyve772omfq1nFDraeI_sO/view?usp=sharing'
gdown.download(data_path, args.dev_src, quiet=False, fuzzy=True)

data_path = 'https://drive.google.com/file/d/1ZvBBTUwzYJuN4J8WCZ9-kZiBEm4iPpiL/view?usp=sharing'
gdown.download(data_path, args.dev_tgt, quiet=False, fuzzy=True)

# %% [markdown]
# ## Padding function
# In order to apply tensor operations, we must ensure that the sentences in a given batch are of the same length. Thus, we must identify the longest sentence in a batch and pad others to be the same length. Implement the pad_sents function, which shall produce these padded sentences.

# %%
def pad_sents(sents, pad_token):
    """ Pad list of sentences according to the longest sentence in the batch.
        The paddings should be at the end of each sentence.
    @param sents (list[list[str]]): list of sentences, where each sentence
                                    is represented as a list of words
    @param pad_token (str): padding token
    @returns sents_padded (list[list[str]]): list of sentences where sentences shorter
        than the max length sentence are padded out with the pad_token, such that
        each sentences in the batch now has equal length.
    """
    sents_padded = []

    len_list = [len(l) for l in sents]
    max_len = sorted(len_list,reverse=True)[0]
    for l in sents:
        for i in range(max_len-len(l)):
            l.append(pad_token)
        sents_padded.append(l)

    return sents_padded

# %% [markdown]
# Below, we define the *VocabEntry* class. The *VocabEntry* class is a vocabulary entry that contains a dictionary that maps words to indices and provides methods to convert words to indices, indices to words, and sentences to tensors. The purpose of this class is to facilitate the management of the vocabulary.

# %%
class VocabEntry(object):
    """ Vocabulary Entry, i.e. structure containing either
    src or tgt language terms.
    """
    def __init__(self, word2id=None):
        """ Init VocabEntry Instance.
        @param word2id (dict): dictionary mapping words 2 indices
        """
        if word2id:
            self.word2id = word2id
        else:
            self.word2id = dict()
            self.word2id['<pad>'] = 0   # Pad Token
            self.word2id['<s>'] = 1 # Start Token
            self.word2id['</s>'] = 2    # End Token
            self.word2id['<unk>'] = 3   # Unknown Token
        self.unk_id = self.word2id['<unk>']
        self.id2word = {v: k for k, v in self.word2id.items()}

    def __getitem__(self, word):
        """ Retrieve word's index. Return the index for the unk
        token if the word is out of vocabulary.
        @param word (str): word to look up.
        @returns index (int): index of word 
        """
        return self.word2id.get(word, self.unk_id)

    def __contains__(self, word):
        """ Check if word is captured by VocabEntry.
        @param word (str): word to look up
        @returns contains (bool): whether word is contained    
        """
        return word in self.word2id

    def __setitem__(self, key, value):
        """ Raise error, if one tries to edit the VocabEntry.
        """
        raise ValueError('vocabulary is readonly')

    def __len__(self):
        """ Compute number of words in VocabEntry.
        @returns len (int): number of words in VocabEntry
        """
        return len(self.word2id)

    def __repr__(self):
        """ Representation of VocabEntry to be used
        when printing the object.
        """
        return 'Vocabulary[size=%d]' % len(self)

    def id2word(self, wid):
        """ Return mapping of index to word.
        @param wid (int): word index
        @returns word (str): word corresponding to index
        """
        return self.id2word[wid]

    def add(self, word):
        """ Add word to VocabEntry, if it is previously unseen.
        @param word (str): word to add to VocabEntry
        @return index (int): index that the word has been assigned
        """
        if word not in self:
            wid = self.word2id[word] = len(self)
            self.id2word[wid] = word
            return wid
        else:
            return self[word]

    def words2indices(self, sents):
        """ Convert list of words or list of sentences of words
        into list or list of list of indices.
        @param sents (list[str] or list[list[str]]): sentence(s) in words
        @return word_ids (list[int] or list[list[int]]): sentence(s) in indices
        """
        if type(sents[0]) == list:
            for i in range(len(sents)):
                # set max length
                sents[i] = sents[i][:args.max_len]
            return [[self[w] for w in s] for s in sents]
        else:
            # set max length
            sents = sents[i][:args.max_len]
            return [self[w] for w in sents]

    def indices2words(self, word_ids):
        """ Convert list of indices into words.
        @param word_ids (list[int]): list of word ids
        @return sents (list[str]): list of words
        """
        return [self.id2word[w_id] for w_id in word_ids]

    def to_input_tensor(self, sents: List[List[str]], device: torch.device) -> torch.Tensor:
        """ Convert list of sentences (words) into tensor with necessary padding for 
        shorter sentences.

        @param sents (List[List[str]]): list of sentences (words)
        @param device: device on which to load the tesnor, i.e. CPU or GPU

        @returns sents_var: tensor of (max_sentence_length, batch_size)
        """
        word_ids = self.words2indices(sents)
        sents_t = pad_sents(word_ids, self['<pad>'])
        sents_var = torch.tensor(sents_t, dtype=torch.long, device=device)
        return torch.t(sents_var)

    @staticmethod
    def from_corpus(corpus, size, freq_cutoff=2):
        """ Given a corpus construct a Vocab Entry.
        @param corpus (list[str]): corpus of text produced by read_corpus function
        @param size (int): # of words in vocabulary
        @param freq_cutoff (int): if word occurs n < freq_cutoff times, drop the word
        @returns vocab_entry (VocabEntry): VocabEntry instance produced from provided corpus
        """
        vocab_entry = VocabEntry()
        word_freq = Counter(chain(*corpus))
        valid_words = [w for w, v in word_freq.items() if v >= freq_cutoff]
        print('number of word types: {}, number of word types w/ frequency >= {}: {}'
              .format(len(word_freq), freq_cutoff, len(valid_words)))
        top_k_words = sorted(valid_words, key=lambda w: word_freq[w], reverse=True)[:size]
        for word in top_k_words:
            vocab_entry.add(word)
        return vocab_entry
    
    @staticmethod
    def from_subword_list(subword_list):
        vocab_entry = VocabEntry()
        for subword in subword_list:
            vocab_entry.add(subword)
        return vocab_entry

# %% [markdown]
# Afterwards, we use a **Vocab** class to wrap vocabulary used for both the source and target languages in a machine translation task. It is composed of two VocabEntry objects, one for the source language and one for the target language.
#
# The build method is used to construct a **Vocab** object from a list of subwords generated by SentencePiece for both the source and target languages. Then, we save them to a JSON file.

# %%
class Vocab(object):
    """ Vocab encapsulating src and target langauges.
    """
    def __init__(self, src_vocab: VocabEntry, tgt_vocab: VocabEntry):
        """ Init Vocab.
        @param src_vocab (VocabEntry): VocabEntry for source language
        @param tgt_vocab (VocabEntry): VocabEntry for target language
        """
        self.src = src_vocab
        self.tgt = tgt_vocab

    @staticmethod
    def build(src_sents, tgt_sents) -> 'Vocab':
        """ Build Vocabulary.
        @param src_sents (list[str]): Source subwords provided by SentencePiece
        @param tgt_sents (list[str]): Target subwords provided by SentencePiece
        """

        print('initialize source vocabulary ..')
        src = VocabEntry.from_subword_list(src_sents)

        print('initialize target vocabulary ..')
        tgt = VocabEntry.from_subword_list(tgt_sents)

        return Vocab(src, tgt)

    def save(self, file_path):
        """ Save Vocab to file as JSON dump.
        @param file_path (str): file path to vocab file
        """
        with open(file_path, 'w') as f:
            json.dump(dict(src_word2id=self.src.word2id, tgt_word2id=self.tgt.word2id), f, indent=2)

    @staticmethod
    def load(file_path):
        """ Load vocabulary from JSON dump.
        @param file_path (str): file path to vocab file
        @returns Vocab object loaded from JSON dump
        """
        entry = json.load(open(file_path, 'r'))
        src_word2id = entry['src_word2id']
        tgt_word2id = entry['tgt_word2id']

        return Vocab(VocabEntry(src_word2id), VocabEntry(tgt_word2id))

    def __repr__(self):
        """ Representation of Vocab to be used
        when printing the object.
        """
        return 'Vocab(source %d words, target %d words)' % (len(self.src), len(self.tgt))


def get_vocab_list(file_path, source, vocab_size):
    """ Use SentencePiece to tokenize and acquire list of unique subwords.
    @param file_path (str): file path to corpus
    @param source (str): tgt or src
    @param vocab_size: desired vocabulary size
    """ 
    spm.SentencePieceTrainer.Train(input=file_path, model_prefix=source, vocab_size=vocab_size)     # train the spm model
    sp = spm.SentencePieceProcessor()   # create an instance; this saves .model and .vocab files 
    sp.Load('{}.model'.format(source))  # loads tgt.model or src.model
    sp_list = [sp.IdToPiece(piece_id) for piece_id in range(sp.GetPieceSize())] # this is the list of subwords
    return sp_list

# %% [markdown]
# ### Train and save our vocabulary to a json file

# %%
print('read in source sentences: %s' % args.train_src)
print('read in target sentences: %s' % args.train_tgt)

src_sents = get_vocab_list(args.train_src, source='src', vocab_size=args.src_vocab_size)
tgt_sents = get_vocab_list(args.train_tgt, source='tgt', vocab_size=args.tgt_vocab_size)
vocab = Vocab.build(src_sents, tgt_sents)
print('generated vocabulary, source %d words, target %d words' % (len(src_sents), len(tgt_sents)))

vocab.save(args.vocab_file)
print('vocabulary saved to %s' % args.vocab_file)
# Out:
# read in source sentences: data/train.vi
# read in target sentences: data/train.en
# initialize source vocabulary ..
# initialize target vocabulary ..
# generated vocabulary, source 15000 words, target 21000 words
# vocabulary saved to vocab.json

# %% [markdown]
# ### Read sentence pairs for training
# The full process for preparing the data is:
#
# - Read text file  into pairs
# - Encode raw text into subwords
# - Add word lists into our data

# %%
def read_corpus(file_path, source):
    """ Read file, where each sentence is dilineated by a `\n`.
    @param file_path (str): path to file containing corpus
    @param source (str): "tgt" or "src" indicating whether text
        is of the source language or target language
    """
    data = []
    sp = spm.SentencePieceProcessor()
    sp.load('{}.model'.format(source))

    with open(file_path, 'r', encoding='utf8') as f:
        for line in f:
            subword_tokens = sp.encode_as_pieces(line)
            # only append <s> and </s> to the target sentence
            if source == 'tgt':
                subword_tokens = ['<s>'] + subword_tokens + ['</s>']
            data.append(subword_tokens)

    return data

train_data_src = read_corpus(args.train_src, source='src')
train_data_tgt = read_corpus(args.train_tgt, source='tgt')

dev_data_src = read_corpus(args.dev_src, source='src')
dev_data_tgt = read_corpus(args.dev_tgt, source='tgt')

train_data = list(zip(train_data_src, train_data_tgt))
dev_data = list(zip(dev_data_src, dev_data_tgt))

# %%
# We define the batch_iter function to iterate through the given data in batches of a specified size, where each batch contains source and target sentences. 
# The sentences are sorted in reverse order by their length, so that longer sentences come first. 
# The function takes three arguments: the data to iterate through, the batch size, and a flag indicating whether to shuffle the data randomly or not.

def batch_iter(data, batch_size, shuffle=False):
    """ Yield batches of source and target sentences reverse sorted by length (largest to smallest).
    @param data (list of (src_sent, tgt_sent)): list of tuples containing source and target sentence
    @param batch_size (int): batch size
    @param shuffle (boolean): whether to randomly shuffle the dataset
    """
    batch_num = math.ceil(len(data) / batch_size)
    index_array = list(range(len(data)))

    if shuffle:
        np.random.shuffle(index_array)

    for i in range(batch_num):
        indices = index_array[i * batch_size: (i + 1) * batch_size]
        examples = [data[idx] for idx in indices]

        examples = sorted(examples, key=lambda e: len(e[0]), reverse=True)
        src_sents, tgt_sents = list(), list()
        for src_sent, tgt_sent in examples:
            if len(src_sent) > 0 and len(tgt_sent) > 0:
                src_sents.append(src_sent)
                tgt_sents.append(tgt_sent)
        yield src_sents, tgt_sents

# %% [markdown]
# ## Embedding Layer Initilization
#
# Implement the __init__ function in model_embeddings.py to initialize the necessary source and target embeddings.

# %%
class ModelEmbeddings(nn.Module): 
    """
    Class that converts input words to their embeddings.
    """
    def __init__(self, embed_size, vocab):
        """
        Init the Embedding layers.

        @param embed_size (int): Embedding size (dimensionality)
        @param vocab (Vocab): Vocabulary object containing src and tgt languages
                              See vocab.py for documentation.
        """
        super(ModelEmbeddings, self).__init__()
        self.embed_size = embed_size

        # default values

        src_pad_token_idx = vocab.src['<pad>']
        tgt_pad_token_idx = vocab.tgt['<pad>']

        ### TODO - Initialize the following variables:
        ###     self.source (Embedding Layer for source language)
        ###     self.target (Embedding Layer for target langauge)

        self.source = nn.Embedding(len(vocab.src),embed_size,padding_idx=src_pad_token_idx)
        self.target = nn.Embedding(len(vocab.tgt),embed_size,padding_idx=tgt_pad_token_idx)

# %% [markdown]
# # The Seq2Seq Model 1: RNNs with global attention
#
# In this section, we describe the training procedure for the proposed NMT system, which uses a Bidirectional LSTM Encoder and a Unidirectional LSTM Decoder.
#
# <img src="https://i.ibb.co/pjRW6tC/arc.png" alt="arc" border="0" width=70%>
#
# # Model description (training procedure)
#
# Given a sentence in the source language, we look up the character or word embeddings from an **embeddings matrix**, yielding $x_1,...,x_m (x_i \in \mathbb{R}^e)$, where $m$ is the length of the source sentence and e is the embedding size. We feed the embeddings to the bidirectional encoder, yielding hidden states and cell states for both the forwards (→) and backwards (←) LSTMs. The forwards and backwards versions are concatenated to give hidden states $h^{enc}_i$ and cell states $c^{enc}_i$ :
#
# $$ h^{enc}_i = [\overleftarrow{h^{enc}_i}; \overrightarrow{h^{enc}_i}] \:\: \text{where} \:\: h^{enc}_i \in \mathbb{R}^{2h \times 1} $$
# $$ c^{enc}_i = [\overleftarrow{c^{enc}_i}; \overrightarrow{c^{enc}_i}] \:\: \text{where} \:\: c^{enc}_i \in \mathbb{R}^{2h \times 1} $$ \\
#
# We then initialize the **decoder**’s first hidden state $h^{enc}_0$ and cell state $c^{enc}_0$  with a linear projection of the encoder’s final hidden state and final cell state.
#
# $$ h^{dec}_0 = W_h[\overleftarrow{h^{enc}_1}; \overrightarrow{h^{enc}_m}] \:\: \text{where} \:\: h^{dec}_0 \in \mathbb{R}^{h \times 1} $$
# $$ c^{dec}_0 = W_c[\overleftarrow{c^{enc}_1}; \overrightarrow{c^{enc}_m}] \:\: \text{where} \:\: c^{dec}_0 \in \mathbb{R}^{h \times 1} $$ \\
#
# With the decoder initialized, we must now feed it a target sentence. On the $t^{th}$ step, we look up the embedding for the $t^{th}$ subword, $y_t \in \mathbb{R}^{e \times 1}$ . We then concatenate $y_t$ with the combined-output vector $o_{t-1} \in \mathbb{R}^{h \times 1}$ from the previous timestep (we will explain what this is later!) to produce $\bar{y_t} \in \mathbb{R}^{(e+h) \times 1}$. Note that for the first target subword (i.e. the start token) $o_0$ is a zero-vector. We then feed $\bar{y_t}$ as input to the decoder.
#
#
# $$ h^{dec}_t , c^{dec}_t = \text{Decoder}(\bar{y_t},  h^{dec}_{t-1} , c^{dec}_{t-1} ) \:\:\: \text{where} \:\:\: h^{dec}_t \in \mathbb{R}^{h \times 1} , c^{dec}_t \in \mathbb{R}^{h \times 1} $$ \\
#
# We then use $h^{dec}_t$ to compute multiplicative attention over $h^{enc}_1,...,, h^{enc}_m$ :
#
# $$ e_{t,i} = (h_t^{dec})^TW_{attProj}h^{enc}_i \:\:\: \text{where} \:\:\: e_t \in \mathbb{R}^{m \times 1}, W_{attProj} \in \mathbb{R}^{h \times 2h} $$
#
# $$ \alpha_t = softmax(e_t) \:\:\: \text{where} \:\:\: \alpha_t \in \mathbb{R}^{m \times 1}$$
#
# $$ a_t = ∑_{i=1}^m \alpha_{t, i} h^{enc}_i \:\:\: \text{where} \:\:\: a_t \in \mathbb{R}^{2h \times 1}$$ \\
#
# We now concatenate the attention output $a_t$ with the decoder hidden state $h^{dec}_t$ and pass this through a linear layer, tanh, and dropout to attain the *combined-output* vector $o_t$.
#
# $$ u_t = [a_t;h^{dec}_t] \:\:\: \text{where} \:\:\: u_t \in \mathbb{R}^{3h \times 1} $$
#
# $$ v_t = W_uu_t \:\:\: where \:\:\: v_t \in \mathbb{R}^{h \times 1},W_u \in \mathbb{R}^{h \times 3h}$$
#
# $$ o_t = dropout(tanh(v_t)) \:\:\: where \:\:\: o_t \in \mathbb{R}^{h \times 1}$$ \\
#
# Then, we produce a probability distribution $P_t$ over target subwords at the $t^{th}$ timestep:
#
# $$ P_t = softmax(W_{vocab}o_t) \:\:\: where \:\:\: P_t \in \mathbb{R}^{V_t \times 1}, W_{vocab}\in \mathbb{R}^{V_t \times h} $$
#
# Here, $V_t$ is the size of the target vocabulary. Finally, to train the network we then compute the cross entropy loss between $P_t$ and $g_t$, where $g_t$ is the one-hot vector of the target subword at timestep $t$:
#
# $$ J_t(θ) = CrossEntropy(P_t, g_t)$$
# Here, $θ$ represents all the parameters of the model and $J_t(θ)$ is the loss on step t of the decoder.
#
# Now that we have described the model, let’s try implementing it Mandarin Vietnamese to English translation!

# %% [markdown]
# # Initialize layers in NMT model
# Implement the init function to initialize the necessary model layers (LSTM, projection, and dropout) for the NMT system.

# %% [markdown]
# # Encoder
#
# Implement the encode function. This function converts the padded source sentences into the tensor $X$, generates $h^{enc}_1 , . . . , h^{enc}_m $, and computes the initial state $h^{dec}_0$ and initial cell  $h^{dec}_0$ for the $\text{Decoder}$

# %% [markdown]
# # Decoder
# Implement the decode function. This function constructs $\bar{y}$ and runs the step function over every timestep for the input.

# %% [markdown]
# # Decoder step
# Implement the step function. This function applies the Decoder’s LSTM cell for a single timestep, computing the encoding of the target subword $h^{dec}_t$ , the attention scores $e_t$, attention distribution $\alpha_t$, the attention output $a_t$, and finally the combined output $o_t$.

# %%
Hypothesis = namedtuple('Hypothesis', ['value', 'score'])

class NMT(nn.Module):
    """ Simple Neural Machine Translation Model:
        - Bidrectional LSTM Encoder
        - Unidirection LSTM Decoder
        - Global Attention Model (Luong, et al. 2015)
    """

    def __init__(self, embed_size, hidden_size, vocab, dropout_rate=0.2):
        """ Init NMT Model.

        @param embed_size (int): Embedding size (dimensionality)
        @param hidden_size (int): Hidden Size, the size of hidden states (dimensionality)
        @param vocab (Vocab): Vocabulary object containing src and tgt languages
                              See vocab.py for documentation.
        @param dropout_rate (float): Dropout probability, for attention
        """
        super(NMT, self).__init__()
        self.model_embeddings = ModelEmbeddings(embed_size, vocab)
        self.hidden_size = hidden_size
        self.dropout_rate = dropout_rate
        self.vocab = vocab

        # For sanity check only, not relevant to implementation
        self.gen_sanity_check = False
        self.counter = 0

        ### TODO - Initialize the following variables IN THIS ORDER:
        ###     self.post_embed_cnn (Conv1d layer with kernel size 2, input and output channels = embed_size,
        ###         padding = same to preserve output shape )
        ###     self.encoder (Bidirectional LSTM with bias)
        ###     self.decoder (LSTM Cell with bias)
        ###     self.h_projection (Linear Layer with no bias), called W_{h} .
        ###     self.c_projection (Linear Layer with no bias), called W_{c} .
        ###     self.att_projection (Linear Layer with no bias), called W_{attProj}.
        ###     self.combined_output_projection (Linear Layer with no bias), called W_{u}.
        ###     self.target_vocab_projection (Linear Layer with no bias), called W_{vocab}.
        ###     self.dropout (Dropout Layer)

        self.post_embed_cnn = nn.Conv1d(in_channels=embed_size,out_channels=embed_size,kernel_size=2,padding="same")
        self.encoder = nn.LSTM(input_size=embed_size,hidden_size=hidden_size,bidirectional=True,bias=True)
        self.decoder = nn.LSTMCell(input_size=embed_size+hidden_size,hidden_size=hidden_size,bias=True)
        self.h_projection = nn.Linear(in_features=2*hidden_size,out_features=hidden_size,bias=False)
        self.c_projection = nn.Linear(in_features=2*hidden_size,out_features=hidden_size,bias=False)
        self.att_projection = nn.Linear(in_features=2*hidden_size,out_features=hidden_size,bias=False)
        self.combined_output_projection = nn.Linear(in_features=3*hidden_size,out_features=hidden_size,bias=False)
        self.target_vocab_projection = nn.Linear(in_features=hidden_size,out_features=len(vocab.tgt),bias=False)
        self.dropout = nn.Dropout(p=dropout_rate)

    def forward(self, source: List[List[str]], target: List[List[str]]) -> torch.Tensor:
        """ Take a mini-batch of source and target sentences, compute the log-likelihood of
        target sentences under the language models learned by the NMT system.

        @param source (List[List[str]]): list of source sentence tokens
        @param target (List[List[str]]): list of target sentence tokens, wrapped by `<s>` and `</s>`

        @returns scores (Tensor): a variable/tensor of shape (b, ) representing the
                                    log-likelihood of generating the gold-standard target sentence for
                                    each example in the input batch. Here b = batch size.
        """
        # Compute sentence lengths
        # source_lengths = [len(s) for s in source]
        source_lengths = [len(s) if len(s) <= args.max_len else args.max_len for s in source]

        # Convert list of lists into tensors
        source_padded = self.vocab.src.to_input_tensor(source, device=self.device)  # Tensor: (src_len, b)
        target_padded = self.vocab.tgt.to_input_tensor(target, device=self.device)  # Tensor: (tgt_len, b)

        ###     Run the network forward:
        ###     1. Apply the encoder to `source_padded` by calling `self.encode()`
        ###     2. Generate sentence masks for `source_padded` by calling `self.generate_sent_masks()`
        ###     3. Apply the decoder to compute combined-output by calling `self.decode()`
        ###     4. Compute log probability distribution over the target vocabulary using the
        ###        combined_outputs returned by the `self.decode()` function.

        enc_hiddens, dec_init_state = self.encode(source_padded, source_lengths)
        enc_masks = self.generate_sent_masks(enc_hiddens, source_lengths)
        combined_outputs = self.decode(enc_hiddens, enc_masks, dec_init_state, target_padded)
        P = F.log_softmax(self.target_vocab_projection(combined_outputs), dim=-1)

        # Zero out, probabilities for which we have nothing in the target text
        target_masks = (target_padded != self.vocab.tgt['<pad>']).float()

        # Compute log probability of generating true target words
        target_gold_words_log_prob = torch.gather(P, index=target_padded[1:].unsqueeze(-1), dim=-1).squeeze(
            -1) * target_masks[1:]
        scores = target_gold_words_log_prob.sum(dim=0)
        return scores

    def encode(self, source_padded: torch.Tensor, source_lengths: List[int]) -> Tuple[
        torch.Tensor, Tuple[torch.Tensor, torch.Tensor]]:
        """ Apply the encoder to source sentences to obtain encoder hidden states.
            Additionally, take the final states of the encoder and project them to obtain initial states for decoder.

        @param source_padded (Tensor): Tensor of padded source sentences with shape (src_len, b), where
                                        b = batch_size, src_len = maximum source sentence length. Note that
                                       these have already been sorted in order of longest to shortest sentence.
        @param source_lengths (List[int]): List of actual lengths for each of the source sentences in the batch
        @returns enc_hiddens (Tensor): Tensor of hidden units with shape (b, src_len, h*2), where
                                        b = batch size, src_len = maximum source sentence length, h = hidden size.
        @returns dec_init_state (tuple(Tensor, Tensor)): Tuple of tensors representing the decoder's initial
                                                hidden state and cell. Both tensors should have shape (2, b, h).
        """

        ### TODO:
        ###     1. Construct Tensor `X` of source sentences with shape (src_len, b, e) using the source model embeddings.
        ###         src_len = maximum source sentence length, b = batch size, e = embedding size. Note
        ###         that there is no initial hidden state or cell for the encoder.
        ###     2. Apply the post_embed_cnn layer. Before feeding X into the CNN, first use torch.permute to change the
        ###         shape of X to (b, e, src_len). After getting the output from the CNN, still stored in the X variable,
        ###         remember to use torch.permute again to revert X back to its original shape.
        ###     3. Compute `enc_hiddens`, `last_hidden`, `last_cell` by applying the encoder to `X`.
        ###         - Before we can apply the encoder, we need to apply the `pack_padded_sequence` function to X.
        ###         - After we apply the encoder, we need to apply the `pad_packed_sequence` function to enc_hiddens.
        ###         - Note that the shape of the tensor output returned by the encoder RNN is (src_len, b, h*2) and we want to
        ###           return a tensor of shape (b, src_len, h*2) as `enc_hiddens`, so we may need to do more permuting.
        ###         - Note on using pad_packed_sequence -> For batched inputs, we need to make sure that each of the
        ###           individual input examples has the same shape.
        ###     4. Compute `dec_init_state` = (init_decoder_hidden, init_decoder_cell):
        ###         - `init_decoder_hidden`:
        ###             `last_hidden` is a tensor shape (2, b, h). The first dimension corresponds to forwards and backwards.
        ###             Concatenate the forwards and backwards tensors to obtain a tensor shape (b, 2*h).
        ###             Apply the h_projection layer to this in order to compute init_decoder_hidden.
        ###             This is h_0^{dec} in the PDF. Here b = batch size, h = hidden size
        ###         - `init_decoder_cell`:
        ###             `last_cell` is a tensor shape (2, b, h). The first dimension corresponds to forwards and backwards.
        ###             Concatenate the forwards and backwards tensors to obtain a tensor shape (b, 2*h).
        ###             Apply the c_projection layer to this in order to compute init_decoder_cell.
        ###             This is c_0^{dec} in the PDF. Here b = batch size, h = hidden size

        X = self.model_embeddings.source(source_padded)
        X = self.post_embed_cnn(X.permute(1,2,0))
        X = X.permute(2,0,1)
        enc_hiddens,(last_hidden,last_cell) = self.encoder(pack_padded_sequence(X,source_lengths))
        enc_hiddens = pad_packed_sequence(enc_hiddens)[0].permute(1,0,2)
        last_hidden = torch.cat((last_hidden[0],last_hidden[1]),dim=1)
        last_cell = torch.cat((last_cell[0],last_cell[1]),dim=1)
        init_decoder_hidden = self.h_projection(last_hidden)
        init_decoder_cell = self.c_projection(last_cell)
        dec_init_state = (init_decoder_hidden,init_decoder_cell)

        return enc_hiddens, dec_init_state

    def decode(self, enc_hiddens: torch.Tensor, enc_masks: torch.Tensor,
               dec_init_state: Tuple[torch.Tensor, torch.Tensor], target_padded: torch.Tensor) -> torch.Tensor:
        """Compute combined output vectors for a batch.

        @param enc_hiddens (Tensor): Hidden states (b, src_len, h*2), where
                                     b = batch size, src_len = maximum source sentence length, h = hidden size.
        @param enc_masks (Tensor): Tensor of sentence masks (b, src_len), where
                                     b = batch size, src_len = maximum source sentence length.
        @param dec_init_state (tuple(Tensor, Tensor)): Initial state and cell for decoder
        @param target_padded (Tensor): Gold-standard padded target sentences (tgt_len, b), where
                                       tgt_len = maximum target sentence length, b = batch size.

        @returns combined_outputs (Tensor): combined output tensor  (tgt_len, b,  h), where
                                        tgt_len = maximum target sentence length, b = batch_size,  h = hidden size
        """
        # Chop off the <END> token for max length sentences.
        target_padded = target_padded[:-1]

        # Initialize the decoder state (hidden and cell)
        dec_state = dec_init_state

        # Initialize previous combined output vector o_{t-1} as zero
        batch_size = enc_hiddens.size(0)
        o_prev = torch.zeros(batch_size, self.hidden_size, device=self.device)

        # Initialize a list we will use to collect the combined output o_t on each step
        combined_outputs = []

        ### TODO:
        ###     1. Apply the attention projection layer to `enc_hiddens` to obtain `enc_hiddens_proj`,
        ###         which should be shape (b, src_len, h),
        ###         where b = batch size, src_len = maximum source length, h = hidden size.
        ###         This is applying W_{attProj} to h^enc, as described in the PDF.
        ###     2. Construct tensor `Y` of target sentences with shape (tgt_len, b, e) using the target model embeddings.
        ###         where tgt_len = maximum target sentence length, b = batch size, e = embedding size.
        ###     3. Use the torch.split function to iterate over the time dimension of Y.
        ###         Within the loop, this will give we Y_t of shape (1, b, e) where b = batch size, e = embedding size.
        ###             - Squeeze Y_t into a tensor of dimension (b, e).
        ###             - Construct Ybar_t by concatenating Y_t with o_prev on their last dimension
        ###             - Use the step function to compute the the Decoder's next (cell, state) values
        ###               as well as the new combined output o_t.
        ###             - Append o_t to combined_outputs
        ###             - Update o_prev to the new o_t.
        ###     4. Use torch.stack to convert combined_outputs from a list length tgt_len of
        ###         tensors shape (b, h), to a single tensor shape (tgt_len, b, h)
        ###         where tgt_len = maximum target sentence length, b = batch size, h = hidden size.

        enc_hiddens_proj = self.att_projection(enc_hiddens)
        Y = self.model_embeddings.target(target_padded)
        Y = torch.split(Y,1,dim=0)
        for y_t in Y:
            y_t = torch.squeeze(y_t)
            ybar_t = torch.cat((y_t,o_prev),dim=1)
            dec_state,o_t,e_t = self.step(ybar_t,dec_state,enc_hiddens,enc_hiddens_proj,enc_masks)
            combined_outputs.append(o_t)
            o_prev = o_t
        combined_outputs=torch.stack(combined_outputs,dim=0)

        return combined_outputs

    def step(self, Ybar_t: torch.Tensor,
             dec_state: Tuple[torch.Tensor, torch.Tensor],
             enc_hiddens: torch.Tensor,
             enc_hiddens_proj: torch.Tensor,
             enc_masks: torch.Tensor) -> Tuple[Tuple, torch.Tensor, torch.Tensor]:
        """ Compute one forward step of the LSTM decoder, including the attention computation.

        @param Ybar_t (Tensor): Concatenated Tensor of [Y_t o_prev], with shape (b, e + h). The input for the decoder,
                                where b = batch size, e = embedding size, h = hidden size.
        @param dec_state (tuple(Tensor, Tensor)): Tuple of tensors both with shape (b, h), where b = batch size, h = hidden size.
                First tensor is decoder's prev hidden state, second tensor is decoder's prev cell.
        @param enc_hiddens (Tensor): Encoder hidden states Tensor, with shape (b, src_len, h * 2), where b = batch size,
                                    src_len = maximum source length, h = hidden size.
        @param enc_hiddens_proj (Tensor): Encoder hidden states Tensor, projected from (h * 2) to h. Tensor is with shape (b, src_len, h),
                                    where b = batch size, src_len = maximum source length, h = hidden size.
        @param enc_masks (Tensor): Tensor of sentence masks shape (b, src_len),
                                    where b = batch size, src_len is maximum source length.

        @returns dec_state (tuple (Tensor, Tensor)): Tuple of tensors both shape (b, h), where b = batch size, h = hidden size.
                First tensor is decoder's new hidden state, second tensor is decoder's new cell.
        @returns combined_output (Tensor): Combined output Tensor at timestep t, shape (b, h), where b = batch size, h = hidden size.
        @returns e_t (Tensor): Tensor of shape (b, src_len). It is attention scores distribution.
                                Note: we will not use this outside of this function.
                                      We are simply returning this value so that we can sanity check
                                      our implementation.
        """

        combined_output = None

        ### TODO:
        ###     1. Apply the decoder to `Ybar_t` and `dec_state`to obtain the new dec_state.
        ###     2. Split dec_state into its two parts (dec_hidden, dec_cell)
        ###     3. Compute the attention scores e_t, a Tensor shape (b, src_len).
        ###        Note: b = batch_size, src_len = maximum source length, h = hidden size.
        ###
        ###       Hints:
        ###         - dec_hidden is shape (b, h) and corresponds to h^dec_t in the PDF (batched)
        ###         - enc_hiddens_proj is shape (b, src_len, h) and corresponds to W_{attProj} h^enc (batched).
        ###         - Use batched matrix multiplication (torch.bmm) to compute e_t (be careful about the input/ output shapes!)
        ###         - To get the tensors into the right shapes for bmm, we will need to do some squeezing and unsqueezing.
        ###         - When using the squeeze() function make sure to specify the dimension we want to squeeze
        ###             over. Otherwise, we will remove the batch dimension accidentally, if batch_size = 1.

        dec_state = self.decoder(Ybar_t,dec_state)
        dec_hidden, dec_cell = dec_state[0], dec_state[1]
        e_t = torch.bmm(enc_hiddens_proj,dec_hidden.unsqueeze(-1)).squeeze(-1)

        # Set e_t to -inf where enc_masks has 1
        if enc_masks is not None:
            e_t.data.masked_fill_(enc_masks.bool(), -float('inf'))

        ### TODO:
        ###     1. Apply softmax to e_t to yield alpha_t
        ###     2. Use batched matrix multiplication between alpha_t and enc_hiddens to obtain the
        ###         attention output vector, a_t.
        # $$     Hints:
        ###           - alpha_t is shape (b, src_len)
        ###           - enc_hiddens is shape (b, src_len, 2h)
        ###           - a_t should be shape (b, 2h)
        ###           - we will need to do some squeezing and unsqueezing.
        ###     Note: b = batch size, src_len = maximum source length, h = hidden size.
        ###
        ###     3. Concatenate dec_hidden with a_t to compute tensor U_t
        ###     4. Apply the combined output projection layer to U_t to compute tensor V_t
        ###     5. Compute tensor O_t by first applying the Tanh function and then the dropout layer.
        
        alpha_t = F.softmax(e_t)
        a_t = torch.bmm(alpha_t.unsqueeze(1),enc_hiddens).squeeze(dim=1)
        U_t = torch.cat((a_t,dec_hidden),dim=1)
        V_t = self.combined_output_projection(U_t)
        O_t = self.dropout(F.tanh(V_t))

        combined_output = O_t
        return dec_state, combined_output, e_t

    def generate_sent_masks(self, enc_hiddens: torch.Tensor, source_lengths: List[int]) -> torch.Tensor:
        """ Generate sentence masks for encoder hidden states.

        @param enc_hiddens (Tensor): encodings of shape (b, src_len, 2*h), where b = batch size,
                                     src_len = max source length, h = hidden size.
        @param source_lengths (List[int]): List of actual lengths for each of the sentences in the batch.

        @returns enc_masks (Tensor): Tensor of sentence masks of shape (b, src_len),
                                    where src_len = max source length, h = hidden size.
        """
        enc_masks = torch.zeros(enc_hiddens.size(0), enc_hiddens.size(1), dtype=torch.float)
        for e_id, src_len in enumerate(source_lengths):
            enc_masks[e_id, src_len:] = 1
        return enc_masks.to(self.device)

    def beam_search(self, src_sent: List[str], beam_size: int = 5, max_decoding_time_step: int = 70) -> List[
        Hypothesis]:
        """ Given a single source sentence, perform beam search, yielding translations in the target language.
        @param src_sent (List[str]): a single source sentence (words)
        @param beam_size (int): beam size
        @param max_decoding_time_step (int): maximum number of time steps to unroll the decoding RNN
        @returns hypotheses (List[Hypothesis]): a list of hypothesis, each hypothesis has two fields:
                value: List[str]: the decoded target sentence, represented as a list of words
                score: float: the log-likelihood of the target sentence
        """
        src_sents_var = self.vocab.src.to_input_tensor([src_sent], self.device)

        src_encodings, dec_init_vec = self.encode(src_sents_var, [len(src_sent)])
        src_encodings_att_linear = self.att_projection(src_encodings)

        h_tm1 = dec_init_vec
        att_tm1 = torch.zeros(1, self.hidden_size, device=self.device)

        eos_id = self.vocab.tgt['</s>']

        hypotheses = [['<s>']]
        hyp_scores = torch.zeros(len(hypotheses), dtype=torch.float, device=self.device)
        completed_hypotheses = []

        t = 0
        while len(completed_hypotheses) < beam_size and t < max_decoding_time_step:
            t += 1
            hyp_num = len(hypotheses)

            exp_src_encodings = src_encodings.expand(hyp_num,
                                                     src_encodings.size(1),
                                                     src_encodings.size(2))

            exp_src_encodings_att_linear = src_encodings_att_linear.expand(hyp_num,
                                                                           src_encodings_att_linear.size(1),
                                                                           src_encodings_att_linear.size(2))

            y_tm1 = torch.tensor([self.vocab.tgt[hyp[-1]] for hyp in hypotheses], dtype=torch.long, device=self.device)
            y_t_embed = self.model_embeddings.target(y_tm1)

            x = torch.cat([y_t_embed, att_tm1], dim=-1)

            (h_t, cell_t), att_t, _ = self.step(x, h_tm1,
                                                exp_src_encodings, exp_src_encodings_att_linear, enc_masks=None)

            # log probabilities over target words
            log_p_t = F.log_softmax(self.target_vocab_projection(att_t), dim=-1)

            live_hyp_num = beam_size - len(completed_hypotheses)
            contiuating_hyp_scores = (hyp_scores.unsqueeze(1).expand_as(log_p_t) + log_p_t).view(-1)
            top_cand_hyp_scores, top_cand_hyp_pos = torch.topk(contiuating_hyp_scores, k=live_hyp_num)

            prev_hyp_ids = torch.div(top_cand_hyp_pos, len(self.vocab.tgt), rounding_mode='floor')
            hyp_word_ids = top_cand_hyp_pos % len(self.vocab.tgt)

            new_hypotheses = []
            live_hyp_ids = []
            new_hyp_scores = []

            for prev_hyp_id, hyp_word_id, cand_new_hyp_score in zip(prev_hyp_ids, hyp_word_ids, top_cand_hyp_scores):
                prev_hyp_id = prev_hyp_id.item()
                hyp_word_id = hyp_word_id.item()
                cand_new_hyp_score = cand_new_hyp_score.item()

                hyp_word = self.vocab.tgt.id2word[hyp_word_id]
                new_hyp_sent = hypotheses[prev_hyp_id] + [hyp_word]
                if hyp_word == '</s>':
                    completed_hypotheses.append(Hypothesis(value=new_hyp_sent[1:-1],
                                                           score=cand_new_hyp_score))
                else:
                    new_hypotheses.append(new_hyp_sent)
                    live_hyp_ids.append(prev_hyp_id)
                    new_hyp_scores.append(cand_new_hyp_score)

            if len(completed_hypotheses) == beam_size:
                break

            live_hyp_ids = torch.tensor(live_hyp_ids, dtype=torch.long, device=self.device)
            h_tm1 = (h_t[live_hyp_ids], cell_t[live_hyp_ids])
            att_tm1 = att_t[live_hyp_ids]

            hypotheses = new_hypotheses
            hyp_scores = torch.tensor(new_hyp_scores, dtype=torch.float, device=self.device)

        if len(completed_hypotheses) == 0:
            completed_hypotheses.append(Hypothesis(value=hypotheses[0][1:],
                                                   score=hyp_scores[0].item()))

        completed_hypotheses.sort(key=lambda hyp: hyp.score, reverse=True)

        return completed_hypotheses

    @property
    def device(self) -> torch.device:
        """ Determine which device to place the Tensors upon, CPU or GPU.
        """
        return self.model_embeddings.source.weight.device

    @staticmethod
    def load(model_path: str):
        """ Load the model from a file.
        @param model_path (str): path to model
        """
        params = torch.load(model_path, map_location=lambda storage, loc: storage)
        args = params['args']
        model = NMT(vocab=params['vocab'], **args)
        model.load_state_dict(params['state_dict'])

        return model

    def save(self, path: str):
        """ Save the odel to a file.
        @param path (str): path to the model
        """
        print('save model parameters to [%s]' % path, file=sys.stderr)

        params = {
            'args': dict(embed_size=self.model_embeddings.embed_size, hidden_size=self.hidden_size,
                         dropout_rate=self.dropout_rate),
            'vocab': self.vocab,
            'state_dict': self.state_dict()
        }

        torch.save(params, path)

# %% [markdown]
# Now it’s time to get things running!

# %%
#@title Evaluating function
def evaluate_ppl(model, dev_data, batch_size=32):
    """ Evaluate perplexity on dev sentences
    @param model (NMT): NMT Model
    @param dev_data (list of (src_sent, tgt_sent)): list of tuples containing source and target sentence
    @param batch_size (batch size)
    @returns ppl (perplixty on dev sentences)
    """
    was_training = model.training
    model.eval()

    cum_loss = 0.
    cum_tgt_words = 0.

    # no_grad() signals backend to throw away all gradients
    with torch.no_grad():
        for src_sents, tgt_sents in batch_iter(dev_data, batch_size):
            loss = -model(src_sents, tgt_sents).sum()

            cum_loss += loss.item()
            tgt_word_num_to_predict = sum(len(s[1:]) for s in tgt_sents)  # omitting leading `<s>`
            cum_tgt_words += tgt_word_num_to_predict

        ppl = np.exp(cum_loss / cum_tgt_words)

    if was_training:
        model.train()

    return ppl

def compute_corpus_level_bleu_score(references: List[List[str]], hypotheses: List[Hypothesis]) -> float:
    """ Given decoding results and reference sentences, compute corpus-level BLEU score.
    @param references (List[List[str]]): a list of gold-standard reference target sentences
    @param hypotheses (List[Hypothesis]): a list of hypotheses, one for each reference
    @returns bleu_score: corpus-level BLEU score
    """
    # remove the start and end tokens
    if references[0][0] == '<s>':
        references = [ref[1:-1] for ref in references]
    
    # detokenize the subword pieces to get full sentences
    detokened_refs = [''.join(pieces).replace('▁', ' ') for pieces in references]
    detokened_hyps = [''.join(hyp.value).replace('▁', ' ') for hyp in hypotheses]

    # sacreBLEU can take multiple references (golden example per sentence) but we only feed it one
    bleu = sacrebleu.corpus_bleu(detokened_hyps, [detokened_refs])

    return bleu.score

# %%
# Initialize our model and optimizer
model = NMT(embed_size=args.embed_size,
            hidden_size=args.hidden_size,
            dropout_rate=float(args.dropout),
            vocab=vocab)
model.train()

uniform_init = float(args.uniform_init)
if np.abs(uniform_init) > 0.:
    print('uniformly initialize parameters [-%f, +%f]' % (uniform_init, uniform_init), file=sys.stderr)
    for p in model.parameters():
        p.data.uniform_(-uniform_init, uniform_init)

model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=float(args.lr))
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]

# %%
#@title Training the model
num_trial = 0
train_iter = patience = cum_loss = report_loss = cum_tgt_words = report_tgt_words = 0
cum_examples = report_examples = epoch = valid_num = 0
hist_valid_scores = []
train_time = begin_time = time.time()
print('begin Maximum Likelihood training')

for epoch in range(args.max_epoch):
    for src_sents, tgt_sents in batch_iter(train_data, batch_size=args.batch_size, shuffle=True):
        train_iter += 1

        optimizer.zero_grad()

        batch_size = len(src_sents)

        example_losses = -model(src_sents, tgt_sents) # (batch_size,)
        batch_loss = example_losses.sum()
        loss = batch_loss / batch_size

        loss.backward()

        # clip gradient
        grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), args.clip_grad)

        optimizer.step()

        batch_losses_val = batch_loss.item()
        report_loss += batch_losses_val
        cum_loss += batch_losses_val

        tgt_words_num_to_predict = sum(len(s[1:]) for s in tgt_sents)  # omitting leading `<s>`
        report_tgt_words += tgt_words_num_to_predict
        cum_tgt_words += tgt_words_num_to_predict
        report_examples += batch_size
        cum_examples += batch_size

        if train_iter % (args.log_every*10) == 0:
            print('epoch %d, iter %d, avg. loss %.2f, avg. ppl %.2f ' \
                    'cum. examples %d, speed %.2f words/sec, time elapsed %.2f sec' % (epoch, train_iter,
                                                                                        report_loss / report_examples,
                                                                                        math.exp(report_loss / report_tgt_words),
                                                                                        cum_examples,
                                                                                        report_tgt_words / (time.time() - train_time),
                                                                                        time.time() - begin_time), file=sys.stderr)

            train_time = time.time()
            report_loss = report_tgt_words = report_examples = 0.

        # perform validation
        if train_iter % args.valid_niter == 0:
            print('epoch %d, iter %d, cum. loss %.2f, cum. ppl %.2f cum. examples %d' % (epoch, train_iter,
                                                                                        cum_loss / cum_examples,
                                                                                        np.exp(cum_loss / cum_tgt_words),
                                                                                        cum_examples), file=sys.stderr)

            cum_loss = cum_examples = cum_tgt_words = 0.
            valid_num += 1

            print('begin validation ...', file=sys.stderr)

            # compute dev. ppl and bleu
            dev_ppl = evaluate_ppl(model, dev_data, batch_size=128)   # dev batch size can be a bit larger
            valid_metric = -dev_ppl

            print('validation: iter %d, dev. ppl %f' % (train_iter, dev_ppl), file=sys.stderr)

            is_better = len(hist_valid_scores) == 0 or valid_metric > max(hist_valid_scores)
            hist_valid_scores.append(valid_metric)

            if is_better:
                patience = 0
                print('save currently the best model to [%s]' % args.model_save_path, file=sys.stderr)
                model.save(args.model_save_path)

                # also save the optimizers' state
                torch.save(optimizer.state_dict(), args.model_save_path + '.optim')
            elif patience < int(args.patience):
                patience += 1
                print('hit patience %d' % patience, file=sys.stderr)

                if patience == int(args.patience):
                    num_trial += 1
                    print('hit #%d trial' % num_trial, file=sys.stderr)
                    if num_trial == int(args.max_num_trial):
                        print('early stop!', file=sys.stderr)
                        exit(0)

                    # decay lr, and restore from previously best checkpoint
                    lr = optimizer.param_groups[0]['lr'] * float(args.lr_decay)
                    print('load previously best model and decay learning rate to %f' % lr, file=sys.stderr)

                    # load model
                    params = torch.load(args.model_save_path, map_location=lambda storage, loc: storage)
                    model.load_state_dict(params['state_dict'])
                    model = model.to(device)

                    print('restore parameters of the optimizers', file=sys.stderr)
                    optimizer.load_state_dict(torch.load(args.model_save_path + '.optim'))

                    # set new lr
                    for param_group in optimizer.param_groups:
                        param_group['lr'] = lr

                    # reset patience
                    patience = 0
# Out:
# begin Maximum Likelihood training
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:309: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/Convolution.cpp:1003.)
#   return F.conv1d(input, weight, bias, self.stride,
# /tmp/ipykernel_32/4047797146.py:348: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   alpha_t = F.softmax(e_t)
# epoch 0, iter 100, avg. loss 159.51, avg. ppl 315.13 cum. examples 3196, speed 3438.16 words/sec, time elapsed 25.77 sec
# epoch 0, iter 200, avg. loss 125.57, avg. ppl 93.24 cum. examples 6392, speed 3973.81 words/sec, time elapsed 48.04 sec
# epoch 0, iter 300, avg. loss 118.50, avg. ppl 65.06 cum. examples 9589, speed 4104.45 words/sec, time elapsed 70.15 sec
# epoch 0, iter 400, avg. loss 110.94, avg. ppl 51.17 cum. examples 12788, speed 4142.12 words/sec, time elapsed 91.92 sec
# epoch 0, iter 500, avg. loss 104.22, avg. ppl 42.32 cum. examples 15988, speed 4108.01 words/sec, time elapsed 113.60 sec
# epoch 0, iter 600, avg. loss 102.56, avg. ppl 37.78 cum. examples 19185, speed 3980.23 words/sec, time elapsed 136.28 sec
# epoch 0, iter 700, avg. loss 96.84, avg. ppl 32.82 cum. examples 22381, speed 4081.75 words/sec, time elapsed 158.00 sec
# epoch 0, iter 800, avg. loss 94.98, avg. ppl 29.56 cum. examples 25578, speed 4314.45 words/sec, time elapsed 178.78 sec
# epoch 0, iter 900, avg. loss 90.99, avg. ppl 26.69 cum. examples 28774, speed 4172.82 words/sec, time elapsed 200.00 sec
# epoch 0, iter 1000, avg. loss 90.28, avg. ppl 25.83 cum. examples 31973, speed 3916.30 words/sec, time elapsed 222.68 sec
# epoch 0, iter 1100, avg. loss 88.10, avg. ppl 24.56 cum. examples 35171, speed 3892.92 words/sec, time elapsed 245.29 sec
# epoch 0, iter 1200, avg. loss 86.47, avg. ppl 22.38 cum. examples 38366, speed 4212.61 words/sec, time elapsed 266.39 sec
# epoch 0, iter 1300, avg. loss 84.32, avg. ppl 21.54 cum. examples 41564, speed 4072.16 words/sec, time elapsed 287.96 sec
# epoch 0, iter 1400, avg. loss 81.29, avg. ppl 20.14 cum. examples 44761, speed 4211.92 words/sec, time elapsed 308.51 sec
# epoch 0, iter 1500, avg. loss 80.93, avg. ppl 19.86 cum. examples 47960, speed 4330.90 words/sec, time elapsed 328.51 sec
# epoch 0, iter 1600, avg. loss 82.26, avg. ppl 19.24 cum. examples 51157, speed 4018.36 words/sec, time elapsed 350.64 sec
# epoch 0, iter 1700, avg. loss 82.26, avg. ppl 18.52 cum. examples 54356, speed 4031.47 words/sec, time elapsed 373.01 sec
# epoch 0, iter 1800, avg. loss 79.98, avg. ppl 17.84 cum. examples 57551, speed 4268.70 words/sec, time elapsed 393.78 sec
# epoch 0, iter 1900, avg. loss 80.82, avg. ppl 17.56 cum. examples 60750, speed 3945.48 words/sec, time elapsed 416.65 sec
# epoch 0, iter 2000, avg. loss 77.50, avg. ppl 17.07 cum. examples 63949, speed 4080.45 words/sec, time elapsed 438.06 sec
# epoch 0, iter 2000, cum. loss 95.91, cum. ppl 31.59 cum. examples 63949
# begin validation ...
# validation: iter 2000, dev. ppl 15.094921
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 0, iter 2100, avg. loss 79.81, avg. ppl 16.62 cum. examples 3197, speed 3541.21 words/sec, time elapsed 463.70 sec
# epoch 0, iter 2200, avg. loss 76.99, avg. ppl 15.59 cum. examples 6395, speed 3996.46 words/sec, time elapsed 486.13 sec
# epoch 0, iter 2300, avg. loss 78.31, avg. ppl 16.08 cum. examples 9590, speed 4080.79 words/sec, time elapsed 508.20 sec
# epoch 0, iter 2400, avg. loss 77.40, avg. ppl 15.63 cum. examples 12788, speed 3887.21 words/sec, time elapsed 531.36 sec
# epoch 0, iter 2500, avg. loss 75.99, avg. ppl 15.18 cum. examples 15987, speed 3940.56 words/sec, time elapsed 554.04 sec
# epoch 0, iter 2600, avg. loss 74.97, avg. ppl 14.64 cum. examples 19183, speed 3964.55 words/sec, time elapsed 576.56 sec
# epoch 0, iter 2700, avg. loss 73.69, avg. ppl 14.07 cum. examples 22381, speed 3973.81 words/sec, time elapsed 599.00 sec
# epoch 0, iter 2800, avg. loss 72.22, avg. ppl 13.85 cum. examples 25578, speed 4005.82 words/sec, time elapsed 620.92 sec
# epoch 0, iter 2900, avg. loss 71.88, avg. ppl 14.24 cum. examples 28773, speed 3863.79 words/sec, time elapsed 643.30 sec
# epoch 0, iter 3000, avg. loss 72.95, avg. ppl 13.75 cum. examples 31969, speed 3975.40 words/sec, time elapsed 665.67 sec
# epoch 0, iter 3100, avg. loss 73.47, avg. ppl 13.82 cum. examples 35164, speed 4170.37 words/sec, time elapsed 687.11 sec
# epoch 0, iter 3200, avg. loss 72.30, avg. ppl 13.42 cum. examples 38363, speed 4195.99 words/sec, time elapsed 708.33 sec
# epoch 0, iter 3300, avg. loss 70.42, avg. ppl 12.88 cum. examples 41560, speed 4340.90 words/sec, time elapsed 728.63 sec
# epoch 0, iter 3400, avg. loss 70.69, avg. ppl 12.72 cum. examples 44759, speed 4216.25 words/sec, time elapsed 749.72 sec
# epoch 0, iter 3500, avg. loss 71.40, avg. ppl 12.70 cum. examples 47957, speed 4039.48 words/sec, time elapsed 771.96 sec
# epoch 0, iter 3600, avg. loss 68.76, avg. ppl 12.27 cum. examples 51157, speed 4250.57 words/sec, time elapsed 792.61 sec
# epoch 0, iter 3700, avg. loss 69.15, avg. ppl 12.40 cum. examples 54353, speed 4207.08 words/sec, time elapsed 813.48 sec
# epoch 0, iter 3800, avg. loss 70.40, avg. ppl 12.40 cum. examples 57550, speed 4263.92 words/sec, time elapsed 834.44 sec
# epoch 0, iter 3900, avg. loss 70.26, avg. ppl 12.25 cum. examples 60746, speed 4109.74 words/sec, time elapsed 856.25 sec
# epoch 0, iter 4000, avg. loss 70.81, avg. ppl 12.27 cum. examples 63945, speed 3795.99 words/sec, time elapsed 880.05 sec
# epoch 0, iter 4000, cum. loss 73.09, cum. ppl 13.78 cum. examples 63945
# begin validation ...
# validation: iter 4000, dev. ppl 11.603283
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 0, iter 4100, avg. loss 69.60, avg. ppl 12.03 cum. examples 3198, speed 3393.78 words/sec, time elapsed 906.42 sec
# epoch 1, iter 4200, avg. loss 66.52, avg. ppl 11.09 cum. examples 6367, speed 3997.13 words/sec, time elapsed 928.34 sec
# epoch 1, iter 4300, avg. loss 62.63, avg. ppl 9.40 cum. examples 9565, speed 4148.56 words/sec, time elapsed 949.89 sec
# epoch 1, iter 4400, avg. loss 62.44, avg. ppl 9.48 cum. examples 12764, speed 4260.80 words/sec, time elapsed 970.73 sec
# epoch 1, iter 4500, avg. loss 61.50, avg. ppl 9.19 cum. examples 15961, speed 4144.93 words/sec, time elapsed 992.12 sec
# epoch 1, iter 4600, avg. loss 62.62, avg. ppl 9.77 cum. examples 19159, speed 4137.18 words/sec, time elapsed 1013.35 sec
# epoch 1, iter 4700, avg. loss 62.43, avg. ppl 9.50 cum. examples 22356, speed 4030.03 words/sec, time elapsed 1035.35 sec
# epoch 1, iter 4800, avg. loss 65.22, avg. ppl 9.80 cum. examples 25551, speed 4136.39 words/sec, time elapsed 1057.42 sec
# epoch 1, iter 4900, avg. loss 61.83, avg. ppl 9.37 cum. examples 28749, speed 3928.69 words/sec, time elapsed 1079.91 sec
# epoch 1, iter 5000, avg. loss 60.94, avg. ppl 9.39 cum. examples 31947, speed 4374.24 words/sec, time elapsed 1099.81 sec
# epoch 1, iter 5100, avg. loss 63.54, avg. ppl 9.81 cum. examples 35146, speed 4069.99 words/sec, time elapsed 1121.68 sec
# epoch 1, iter 5200, avg. loss 62.25, avg. ppl 9.50 cum. examples 38345, speed 4043.04 words/sec, time elapsed 1143.56 sec
# epoch 1, iter 5300, avg. loss 62.87, avg. ppl 9.38 cum. examples 41543, speed 4276.28 words/sec, time elapsed 1164.56 sec
# epoch 1, iter 5400, avg. loss 62.99, avg. ppl 9.53 cum. examples 44742, speed 4055.09 words/sec, time elapsed 1186.60 sec
# epoch 1, iter 5500, avg. loss 62.38, avg. ppl 9.33 cum. examples 47937, speed 4033.33 words/sec, time elapsed 1208.72 sec
# epoch 1, iter 5600, avg. loss 62.86, avg. ppl 9.45 cum. examples 51134, speed 3697.73 words/sec, time elapsed 1232.92 sec
# epoch 1, iter 5700, avg. loss 62.92, avg. ppl 9.55 cum. examples 54330, speed 4041.85 words/sec, time elapsed 1254.97 sec
# epoch 1, iter 5800, avg. loss 62.40, avg. ppl 9.36 cum. examples 57528, speed 3949.74 words/sec, time elapsed 1277.56 sec
# epoch 1, iter 5900, avg. loss 62.70, avg. ppl 9.53 cum. examples 60727, speed 4112.88 words/sec, time elapsed 1299.19 sec
# epoch 1, iter 6000, avg. loss 62.63, avg. ppl 9.32 cum. examples 63924, speed 4057.99 words/sec, time elapsed 1321.30 sec
# epoch 1, iter 6000, cum. loss 63.16, cum. ppl 9.67 cum. examples 63924
# begin validation ...
# validation: iter 6000, dev. ppl 10.343093
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 1, iter 6100, avg. loss 62.20, avg. ppl 9.26 cum. examples 3198, speed 3364.94 words/sec, time elapsed 1347.85 sec
# epoch 1, iter 6200, avg. loss 61.85, avg. ppl 9.24 cum. examples 6395, speed 4137.60 words/sec, time elapsed 1369.34 sec
# epoch 1, iter 6300, avg. loss 64.52, avg. ppl 9.46 cum. examples 9593, speed 3958.09 words/sec, time elapsed 1392.54 sec
# epoch 1, iter 6400, avg. loss 61.63, avg. ppl 9.33 cum. examples 12790, speed 3852.81 words/sec, time elapsed 1415.44 sec
# epoch 1, iter 6500, avg. loss 61.44, avg. ppl 9.34 cum. examples 15987, speed 4003.67 words/sec, time elapsed 1437.41 sec
# epoch 1, iter 6600, avg. loss 61.38, avg. ppl 9.26 cum. examples 19185, speed 4190.86 words/sec, time elapsed 1458.45 sec
# epoch 1, iter 6700, avg. loss 61.12, avg. ppl 9.38 cum. examples 22381, speed 4125.12 words/sec, time elapsed 1479.61 sec
# epoch 1, iter 6800, avg. loss 61.69, avg. ppl 9.22 cum. examples 25580, speed 4059.66 words/sec, time elapsed 1501.49 sec
# epoch 1, iter 6900, avg. loss 60.78, avg. ppl 9.01 cum. examples 28779, speed 4300.99 words/sec, time elapsed 1522.06 sec
# epoch 1, iter 7000, avg. loss 61.82, avg. ppl 8.93 cum. examples 31977, speed 4157.98 words/sec, time elapsed 1543.78 sec
# epoch 1, iter 7100, avg. loss 61.62, avg. ppl 9.24 cum. examples 35173, speed 4147.47 words/sec, time elapsed 1565.14 sec
# epoch 1, iter 7200, avg. loss 61.79, avg. ppl 9.20 cum. examples 38366, speed 4149.96 words/sec, time elapsed 1586.56 sec
# epoch 1, iter 7300, avg. loss 63.07, avg. ppl 9.21 cum. examples 41564, speed 3981.47 words/sec, time elapsed 1609.37 sec
# epoch 1, iter 7400, avg. loss 61.11, avg. ppl 9.02 cum. examples 44759, speed 4001.09 words/sec, time elapsed 1631.56 sec
# epoch 1, iter 7500, avg. loss 62.48, avg. ppl 9.29 cum. examples 47955, speed 3919.97 words/sec, time elapsed 1654.41 sec
# epoch 1, iter 7600, avg. loss 60.38, avg. ppl 8.75 cum. examples 51153, speed 4043.18 words/sec, time elapsed 1676.43 sec
# epoch 1, iter 7700, avg. loss 61.65, avg. ppl 9.10 cum. examples 54349, speed 3844.17 words/sec, time elapsed 1699.64 sec
# epoch 1, iter 7800, avg. loss 60.87, avg. ppl 9.01 cum. examples 57546, speed 4101.60 words/sec, time elapsed 1721.23 sec
# epoch 1, iter 7900, avg. loss 61.84, avg. ppl 9.13 cum. examples 60742, speed 3977.91 words/sec, time elapsed 1743.70 sec
# epoch 1, iter 8000, avg. loss 60.93, avg. ppl 8.91 cum. examples 63940, speed 4399.62 words/sec, time elapsed 1763.95 sec
# epoch 1, iter 8000, cum. loss 61.71, cum. ppl 9.16 cum. examples 63940
# begin validation ...
# validation: iter 8000, dev. ppl 9.435976
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 1, iter 8100, avg. loss 60.24, avg. ppl 8.87 cum. examples 3199, speed 3474.45 words/sec, time elapsed 1789.36 sec
# epoch 1, iter 8200, avg. loss 60.98, avg. ppl 8.98 cum. examples 6396, speed 3929.98 words/sec, time elapsed 1811.96 sec
# epoch 1, iter 8300, avg. loss 60.30, avg. ppl 8.94 cum. examples 9593, speed 3968.33 words/sec, time elapsed 1834.13 sec
# epoch 2, iter 8400, avg. loss 54.98, avg. ppl 7.24 cum. examples 12761, speed 4193.13 words/sec, time elapsed 1855.12 sec
# epoch 2, iter 8500, avg. loss 52.79, avg. ppl 6.74 cum. examples 15956, speed 4283.09 words/sec, time elapsed 1875.77 sec
# epoch 2, iter 8600, avg. loss 51.72, avg. ppl 6.76 cum. examples 19155, speed 4051.61 words/sec, time elapsed 1897.14 sec
# epoch 2, iter 8700, avg. loss 53.75, avg. ppl 7.04 cum. examples 22350, speed 4010.25 words/sec, time elapsed 1919.08 sec
# epoch 2, iter 8800, avg. loss 53.60, avg. ppl 7.06 cum. examples 25545, speed 4158.28 words/sec, time elapsed 1940.15 sec
# epoch 2, iter 8900, avg. loss 55.11, avg. ppl 7.08 cum. examples 28743, speed 3927.32 words/sec, time elapsed 1963.08 sec
# epoch 2, iter 9000, avg. loss 54.06, avg. ppl 6.99 cum. examples 31943, speed 4124.66 words/sec, time elapsed 1984.65 sec
# epoch 2, iter 9100, avg. loss 54.82, avg. ppl 7.22 cum. examples 35143, speed 4243.69 words/sec, time elapsed 2005.56 sec
# epoch 2, iter 9200, avg. loss 53.91, avg. ppl 7.19 cum. examples 38338, speed 4149.37 words/sec, time elapsed 2026.61 sec
# epoch 2, iter 9300, avg. loss 55.42, avg. ppl 7.26 cum. examples 41537, speed 4139.26 words/sec, time elapsed 2048.21 sec
# epoch 2, iter 9400, avg. loss 54.28, avg. ppl 7.26 cum. examples 44735, speed 4201.52 words/sec, time elapsed 2069.05 sec
# epoch 2, iter 9500, avg. loss 55.03, avg. ppl 7.25 cum. examples 47931, speed 4065.16 words/sec, time elapsed 2090.90 sec
# epoch 2, iter 9600, avg. loss 56.44, avg. ppl 7.49 cum. examples 51128, speed 4251.37 words/sec, time elapsed 2111.98 sec
# epoch 2, iter 9700, avg. loss 56.03, avg. ppl 7.39 cum. examples 54324, speed 3958.60 words/sec, time elapsed 2134.60 sec
# epoch 2, iter 9800, avg. loss 57.06, avg. ppl 7.51 cum. examples 57521, speed 4022.23 words/sec, time elapsed 2157.09 sec
# epoch 2, iter 9900, avg. loss 56.66, avg. ppl 7.40 cum. examples 60718, speed 4031.76 words/sec, time elapsed 2179.54 sec
# epoch 2, iter 10000, avg. loss 55.70, avg. ppl 7.40 cum. examples 63915, speed 4024.91 words/sec, time elapsed 2201.64 sec
# epoch 2, iter 10000, cum. loss 55.65, cum. ppl 7.43 cum. examples 63915
# begin validation ...
# validation: iter 10000, dev. ppl 9.136871
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 2, iter 10100, avg. loss 57.39, avg. ppl 7.62 cum. examples 3196, speed 3187.62 words/sec, time elapsed 2229.98 sec
# epoch 2, iter 10200, avg. loss 54.75, avg. ppl 7.23 cum. examples 6394, speed 4100.99 words/sec, time elapsed 2251.57 sec
# epoch 2, iter 10300, avg. loss 56.34, avg. ppl 7.46 cum. examples 9591, speed 4272.48 words/sec, time elapsed 2272.54 sec
# epoch 2, iter 10400, avg. loss 56.14, avg. ppl 7.59 cum. examples 12785, speed 4220.40 words/sec, time elapsed 2293.51 sec
# epoch 2, iter 10500, avg. loss 55.53, avg. ppl 7.56 cum. examples 15982, speed 4130.38 words/sec, time elapsed 2314.76 sec
# epoch 2, iter 10600, avg. loss 56.30, avg. ppl 7.66 cum. examples 19178, speed 4057.66 words/sec, time elapsed 2336.54 sec
# epoch 2, iter 10700, avg. loss 56.30, avg. ppl 7.51 cum. examples 22375, speed 3781.48 words/sec, time elapsed 2360.14 sec
# epoch 2, iter 10800, avg. loss 54.76, avg. ppl 7.44 cum. examples 25572, speed 4090.02 words/sec, time elapsed 2381.48 sec
# epoch 2, iter 10900, avg. loss 56.83, avg. ppl 7.62 cum. examples 28771, speed 3984.45 words/sec, time elapsed 2403.95 sec
# epoch 2, iter 11000, avg. loss 56.36, avg. ppl 7.51 cum. examples 31971, speed 4183.03 words/sec, time elapsed 2425.33 sec
# epoch 2, iter 11100, avg. loss 57.09, avg. ppl 7.52 cum. examples 35170, speed 4151.01 words/sec, time elapsed 2447.14 sec
# epoch 2, iter 11200, avg. loss 56.37, avg. ppl 7.44 cum. examples 38370, speed 3945.63 words/sec, time elapsed 2469.92 sec
# epoch 2, iter 11300, avg. loss 56.03, avg. ppl 7.55 cum. examples 41566, speed 4147.42 words/sec, time elapsed 2491.27 sec
# epoch 2, iter 11400, avg. loss 55.59, avg. ppl 7.29 cum. examples 44763, speed 4010.70 words/sec, time elapsed 2513.58 sec
# epoch 2, iter 11500, avg. loss 55.41, avg. ppl 7.54 cum. examples 47961, speed 3941.70 words/sec, time elapsed 2535.83 sec
# epoch 2, iter 11600, avg. loss 57.14, avg. ppl 7.64 cum. examples 51160, speed 4212.76 words/sec, time elapsed 2557.17 sec
# epoch 2, iter 11700, avg. loss 55.40, avg. ppl 7.54 cum. examples 54355, speed 3978.98 words/sec, time elapsed 2579.18 sec
# epoch 2, iter 11800, avg. loss 55.58, avg. ppl 7.47 cum. examples 57554, speed 4200.19 words/sec, time elapsed 2600.23 sec
# epoch 2, iter 11900, avg. loss 55.54, avg. ppl 7.68 cum. examples 60751, speed 4075.92 words/sec, time elapsed 2621.60 sec
# epoch 2, iter 12000, avg. loss 55.65, avg. ppl 7.45 cum. examples 63951, speed 4163.95 words/sec, time elapsed 2642.89 sec
# epoch 2, iter 12000, cum. loss 56.02, cum. ppl 7.52 cum. examples 63951
# begin validation ...
# validation: iter 12000, dev. ppl 8.912764
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 2, iter 12100, avg. loss 56.40, avg. ppl 7.45 cum. examples 3195, speed 3490.83 words/sec, time elapsed 2668.59 sec
# epoch 2, iter 12200, avg. loss 56.98, avg. ppl 7.59 cum. examples 6393, speed 4261.46 words/sec, time elapsed 2689.69 sec
# epoch 2, iter 12300, avg. loss 56.42, avg. ppl 7.76 cum. examples 9590, speed 3954.64 words/sec, time elapsed 2711.95 sec
# epoch 2, iter 12400, avg. loss 58.31, avg. ppl 7.71 cum. examples 12788, speed 3944.36 words/sec, time elapsed 2735.10 sec
# epoch 2, iter 12500, avg. loss 57.76, avg. ppl 7.72 cum. examples 15986, speed 4076.54 words/sec, time elapsed 2757.28 sec
# epoch 3, iter 12600, avg. loss 50.12, avg. ppl 5.86 cum. examples 19156, speed 3955.39 words/sec, time elapsed 2779.99 sec
# epoch 3, iter 12700, avg. loss 49.76, avg. ppl 5.94 cum. examples 22354, speed 3994.84 words/sec, time elapsed 2802.35 sec
# epoch 3, iter 12800, avg. loss 49.61, avg. ppl 5.85 cum. examples 25549, speed 3999.29 words/sec, time elapsed 2824.78 sec
# epoch 3, iter 12900, avg. loss 49.95, avg. ppl 6.01 cum. examples 28747, speed 4087.32 words/sec, time elapsed 2846.58 sec
# epoch 3, iter 13000, avg. loss 50.77, avg. ppl 6.12 cum. examples 31941, speed 4092.74 words/sec, time elapsed 2868.44 sec
# epoch 3, iter 13100, avg. loss 50.85, avg. ppl 6.20 cum. examples 35139, speed 4219.38 words/sec, time elapsed 2889.56 sec
# epoch 3, iter 13200, avg. loss 50.28, avg. ppl 6.26 cum. examples 38338, speed 4163.18 words/sec, time elapsed 2910.63 sec
# epoch 3, iter 13300, avg. loss 51.17, avg. ppl 6.19 cum. examples 41536, speed 4021.65 words/sec, time elapsed 2932.95 sec
# epoch 3, iter 13400, avg. loss 51.85, avg. ppl 6.44 cum. examples 44734, speed 4031.35 words/sec, time elapsed 2955.03 sec
# epoch 3, iter 13500, avg. loss 51.09, avg. ppl 6.31 cum. examples 47930, speed 3848.95 words/sec, time elapsed 2978.05 sec
# epoch 3, iter 13600, avg. loss 50.64, avg. ppl 6.24 cum. examples 51129, speed 4182.80 words/sec, time elapsed 2999.20 sec
# epoch 3, iter 13700, avg. loss 51.93, avg. ppl 6.44 cum. examples 54328, speed 4017.37 words/sec, time elapsed 3021.41 sec
# epoch 3, iter 13800, avg. loss 49.63, avg. ppl 6.13 cum. examples 57526, speed 4228.10 words/sec, time elapsed 3042.11 sec
# epoch 3, iter 13900, avg. loss 52.59, avg. ppl 6.43 cum. examples 60725, speed 3788.64 words/sec, time elapsed 3065.96 sec
# epoch 3, iter 14000, avg. loss 50.56, avg. ppl 6.24 cum. examples 63921, speed 4268.33 words/sec, time elapsed 3086.64 sec
# epoch 3, iter 14000, cum. loss 52.33, cum. ppl 6.52 cum. examples 63921
# begin validation ...
# validation: iter 14000, dev. ppl 8.815754
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 3, iter 14100, avg. loss 51.39, avg. ppl 6.33 cum. examples 3196, speed 3377.14 words/sec, time elapsed 3112.99 sec
# epoch 3, iter 14200, avg. loss 50.92, avg. ppl 6.34 cum. examples 6393, speed 4222.02 words/sec, time elapsed 3133.86 sec
# epoch 3, iter 14300, avg. loss 52.43, avg. ppl 6.51 cum. examples 9587, speed 4085.60 words/sec, time elapsed 3155.74 sec
# epoch 3, iter 14400, avg. loss 52.50, avg. ppl 6.56 cum. examples 12783, speed 4222.59 words/sec, time elapsed 3176.87 sec
# epoch 3, iter 14500, avg. loss 51.56, avg. ppl 6.47 cum. examples 15981, speed 4156.88 words/sec, time elapsed 3198.12 sec
# epoch 3, iter 14600, avg. loss 53.74, avg. ppl 6.69 cum. examples 19180, speed 4016.54 words/sec, time elapsed 3220.64 sec
# epoch 3, iter 14700, avg. loss 53.48, avg. ppl 6.76 cum. examples 22378, speed 3746.28 words/sec, time elapsed 3244.53 sec
# epoch 3, iter 14800, avg. loss 52.92, avg. ppl 6.64 cum. examples 25575, speed 4166.96 words/sec, time elapsed 3265.98 sec
# epoch 3, iter 14900, avg. loss 51.97, avg. ppl 6.69 cum. examples 28772, speed 4207.64 words/sec, time elapsed 3286.75 sec
# epoch 3, iter 15000, avg. loss 52.99, avg. ppl 6.67 cum. examples 31970, speed 4280.22 words/sec, time elapsed 3307.62 sec
# epoch 3, iter 15100, avg. loss 53.34, avg. ppl 6.70 cum. examples 35167, speed 4249.90 words/sec, time elapsed 3328.71 sec
# epoch 3, iter 15200, avg. loss 50.95, avg. ppl 6.52 cum. examples 38364, speed 4022.92 words/sec, time elapsed 3350.31 sec
# epoch 3, iter 15300, avg. loss 53.64, avg. ppl 6.80 cum. examples 41558, speed 4172.80 words/sec, time elapsed 3371.73 sec
# epoch 3, iter 15400, avg. loss 53.35, avg. ppl 6.70 cum. examples 44756, speed 3956.00 words/sec, time elapsed 3394.40 sec
# epoch 3, iter 15500, avg. loss 52.51, avg. ppl 6.78 cum. examples 47954, speed 4029.05 words/sec, time elapsed 3416.18 sec
# epoch 3, iter 15600, avg. loss 52.13, avg. ppl 6.63 cum. examples 51153, speed 4172.72 words/sec, time elapsed 3437.30 sec
# epoch 3, iter 15700, avg. loss 53.47, avg. ppl 6.77 cum. examples 54350, speed 4069.00 words/sec, time elapsed 3459.26 sec
# epoch 3, iter 15800, avg. loss 52.75, avg. ppl 6.70 cum. examples 57547, speed 4108.50 words/sec, time elapsed 3480.85 sec
# epoch 3, iter 15900, avg. loss 53.27, avg. ppl 6.82 cum. examples 60744, speed 4008.59 words/sec, time elapsed 3502.97 sec
# epoch 3, iter 16000, avg. loss 52.46, avg. ppl 6.71 cum. examples 63940, speed 4147.05 words/sec, time elapsed 3524.21 sec
# epoch 3, iter 16000, cum. loss 52.59, cum. ppl 6.64 cum. examples 63940
# begin validation ...
# validation: iter 16000, dev. ppl 8.696924
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 3, iter 16100, avg. loss 52.73, avg. ppl 6.68 cum. examples 3198, speed 3295.57 words/sec, time elapsed 3551.15 sec
# epoch 3, iter 16200, avg. loss 55.21, avg. ppl 6.95 cum. examples 6395, speed 3992.19 words/sec, time elapsed 3573.95 sec
# epoch 3, iter 16300, avg. loss 53.67, avg. ppl 6.85 cum. examples 9594, speed 3923.60 words/sec, time elapsed 3596.69 sec
# epoch 3, iter 16400, avg. loss 53.90, avg. ppl 6.96 cum. examples 12791, speed 4195.23 words/sec, time elapsed 3617.87 sec
# epoch 3, iter 16500, avg. loss 52.11, avg. ppl 6.69 cum. examples 15989, speed 3751.78 words/sec, time elapsed 3641.23 sec
# epoch 3, iter 16600, avg. loss 54.18, avg. ppl 6.85 cum. examples 19188, speed 4030.75 words/sec, time elapsed 3663.59 sec
# epoch 4, iter 16700, avg. loss 49.78, avg. ppl 6.22 cum. examples 22358, speed 4084.73 words/sec, time elapsed 3684.73 sec
# epoch 4, iter 16800, avg. loss 46.26, avg. ppl 5.27 cum. examples 25555, speed 4276.40 words/sec, time elapsed 3705.52 sec
# epoch 4, iter 16900, avg. loss 48.25, avg. ppl 5.47 cum. examples 28754, speed 3820.43 words/sec, time elapsed 3729.30 sec
# epoch 4, iter 17000, avg. loss 47.82, avg. ppl 5.42 cum. examples 31954, speed 4070.67 words/sec, time elapsed 3751.55 sec
# epoch 4, iter 17100, avg. loss 47.45, avg. ppl 5.45 cum. examples 35151, speed 4214.52 words/sec, time elapsed 3772.77 sec
# epoch 4, iter 17200, avg. loss 47.12, avg. ppl 5.44 cum. examples 38348, speed 4066.55 words/sec, time elapsed 3794.64 sec
# epoch 4, iter 17300, avg. loss 48.28, avg. ppl 5.61 cum. examples 41545, speed 3959.90 words/sec, time elapsed 3817.24 sec
# epoch 4, iter 17400, avg. loss 47.63, avg. ppl 5.63 cum. examples 44744, speed 4158.29 words/sec, time elapsed 3838.44 sec
# epoch 4, iter 17500, avg. loss 49.44, avg. ppl 5.72 cum. examples 47940, speed 3783.69 words/sec, time elapsed 3862.38 sec
# epoch 4, iter 17600, avg. loss 47.89, avg. ppl 5.65 cum. examples 51136, speed 3819.49 words/sec, time elapsed 3885.51 sec
# epoch 4, iter 17700, avg. loss 49.08, avg. ppl 5.72 cum. examples 54333, speed 4013.47 words/sec, time elapsed 3907.93 sec
# epoch 4, iter 17800, avg. loss 47.05, avg. ppl 5.75 cum. examples 57531, speed 4161.15 words/sec, time elapsed 3928.60 sec
# epoch 4, iter 17900, avg. loss 48.03, avg. ppl 5.79 cum. examples 60730, speed 4081.24 words/sec, time elapsed 3950.03 sec
# epoch 4, iter 18000, avg. loss 50.10, avg. ppl 5.90 cum. examples 63926, speed 3956.58 words/sec, time elapsed 3972.84 sec
# epoch 4, iter 18000, cum. loss 49.80, cum. ppl 5.97 cum. examples 63926
# begin validation ...
# validation: iter 18000, dev. ppl 8.677091
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 4, iter 18100, avg. loss 49.22, avg. ppl 5.89 cum. examples 3194, speed 3342.08 words/sec, time elapsed 3999.35 sec
# epoch 4, iter 18200, avg. loss 50.04, avg. ppl 5.96 cum. examples 6393, speed 3874.33 words/sec, time elapsed 4022.49 sec
# epoch 4, iter 18300, avg. loss 48.74, avg. ppl 5.81 cum. examples 9586, speed 4031.99 words/sec, time elapsed 4044.44 sec
# epoch 4, iter 18400, avg. loss 49.16, avg. ppl 5.88 cum. examples 12784, speed 4107.00 words/sec, time elapsed 4066.04 sec
# epoch 4, iter 18500, avg. loss 50.34, avg. ppl 6.02 cum. examples 15982, speed 4147.68 words/sec, time elapsed 4087.67 sec
# epoch 4, iter 18600, avg. loss 49.07, avg. ppl 5.95 cum. examples 19177, speed 4163.29 words/sec, time elapsed 4108.79 sec
# epoch 4, iter 18700, avg. loss 49.62, avg. ppl 5.97 cum. examples 22367, speed 4016.87 words/sec, time elapsed 4130.85 sec
# epoch 4, iter 18800, avg. loss 50.16, avg. ppl 6.12 cum. examples 25566, speed 3782.20 words/sec, time elapsed 4154.28 sec
# epoch 4, iter 18900, avg. loss 49.85, avg. ppl 5.90 cum. examples 28766, speed 4146.77 words/sec, time elapsed 4175.95 sec
# epoch 4, iter 19000, avg. loss 50.88, avg. ppl 6.25 cum. examples 31965, speed 3913.15 words/sec, time elapsed 4198.65 sec
# epoch 4, iter 19100, avg. loss 50.15, avg. ppl 6.06 cum. examples 35162, speed 3800.13 words/sec, time elapsed 4222.06 sec
# epoch 4, iter 19200, avg. loss 51.25, avg. ppl 6.15 cum. examples 38359, speed 4039.09 words/sec, time elapsed 4244.40 sec
# epoch 4, iter 19300, avg. loss 51.06, avg. ppl 6.18 cum. examples 41559, speed 4014.62 words/sec, time elapsed 4266.75 sec
# epoch 4, iter 19400, avg. loss 51.53, avg. ppl 6.19 cum. examples 44756, speed 3977.68 words/sec, time elapsed 4289.47 sec
# epoch 4, iter 19500, avg. loss 50.62, avg. ppl 6.19 cum. examples 47953, speed 3768.92 words/sec, time elapsed 4313.02 sec
# epoch 4, iter 19600, avg. loss 51.71, avg. ppl 6.21 cum. examples 51150, speed 3927.98 words/sec, time elapsed 4336.06 sec
# epoch 4, iter 19700, avg. loss 50.85, avg. ppl 6.19 cum. examples 54346, speed 4276.24 words/sec, time elapsed 4356.91 sec
# epoch 4, iter 19800, avg. loss 51.00, avg. ppl 6.30 cum. examples 57544, speed 4090.58 words/sec, time elapsed 4378.57 sec
# epoch 4, iter 19900, avg. loss 51.73, avg. ppl 6.31 cum. examples 60742, speed 4008.67 words/sec, time elapsed 4400.98 sec
# epoch 4, iter 20000, avg. loss 51.01, avg. ppl 6.32 cum. examples 63939, speed 4146.33 words/sec, time elapsed 4422.31 sec
# epoch 4, iter 20000, cum. loss 50.40, cum. ppl 6.09 cum. examples 63939
# begin validation ...
# validation: iter 20000, dev. ppl 8.500181
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 4, iter 20100, avg. loss 51.35, avg. ppl 6.34 cum. examples 3198, speed 3414.76 words/sec, time elapsed 4448.36 sec
# epoch 4, iter 20200, avg. loss 51.70, avg. ppl 6.26 cum. examples 6397, speed 4061.81 words/sec, time elapsed 4470.55 sec
# epoch 4, iter 20300, avg. loss 50.50, avg. ppl 6.35 cum. examples 9595, speed 4142.53 words/sec, time elapsed 4491.64 sec
# epoch 4, iter 20400, avg. loss 49.72, avg. ppl 6.27 cum. examples 12793, speed 4360.43 words/sec, time elapsed 4511.51 sec
# epoch 4, iter 20500, avg. loss 52.07, avg. ppl 6.40 cum. examples 15992, speed 4018.90 words/sec, time elapsed 4533.84 sec
# epoch 4, iter 20600, avg. loss 50.45, avg. ppl 6.36 cum. examples 19188, speed 3968.82 words/sec, time elapsed 4555.80 sec
# epoch 4, iter 20700, avg. loss 51.13, avg. ppl 6.40 cum. examples 22385, speed 3891.40 words/sec, time elapsed 4578.42 sec
# epoch 4, iter 20800, avg. loss 52.06, avg. ppl 6.47 cum. examples 25583, speed 4151.62 words/sec, time elapsed 4599.90 sec
# epoch 5, iter 20900, avg. loss 45.85, avg. ppl 5.36 cum. examples 28753, speed 3976.19 words/sec, time elapsed 4621.66 sec
# epoch 5, iter 21000, avg. loss 45.22, avg. ppl 5.11 cum. examples 31947, speed 3953.36 words/sec, time elapsed 4644.06 sec
# epoch 5, iter 21100, avg. loss 45.74, avg. ppl 5.09 cum. examples 35143, speed 4160.27 words/sec, time elapsed 4665.65 sec
# epoch 5, iter 21200, avg. loss 47.97, avg. ppl 5.25 cum. examples 38341, speed 3825.42 words/sec, time elapsed 4689.84 sec
# epoch 5, iter 21300, avg. loss 45.01, avg. ppl 5.16 cum. examples 41536, speed 4121.51 words/sec, time elapsed 4711.10 sec
# epoch 5, iter 21400, avg. loss 45.24, avg. ppl 5.16 cum. examples 44735, speed 4056.40 words/sec, time elapsed 4732.84 sec
# epoch 5, iter 21500, avg. loss 46.34, avg. ppl 5.30 cum. examples 47934, speed 4013.92 words/sec, time elapsed 4754.99 sec
# epoch 5, iter 21600, avg. loss 47.40, avg. ppl 5.29 cum. examples 51131, speed 4046.38 words/sec, time elapsed 4777.48 sec
# epoch 5, iter 21700, avg. loss 46.65, avg. ppl 5.43 cum. examples 54329, speed 3869.62 words/sec, time elapsed 4800.27 sec
# epoch 5, iter 21800, avg. loss 47.71, avg. ppl 5.44 cum. examples 57528, speed 3793.13 words/sec, time elapsed 4824.03 sec
# epoch 5, iter 21900, avg. loss 47.04, avg. ppl 5.48 cum. examples 60725, speed 4073.24 words/sec, time elapsed 4845.73 sec
# epoch 5, iter 22000, avg. loss 46.90, avg. ppl 5.34 cum. examples 63922, speed 3895.26 words/sec, time elapsed 4868.72 sec
# epoch 5, iter 22000, cum. loss 48.30, cum. ppl 5.69 cum. examples 63922
# begin validation ...
# validation: iter 22000, dev. ppl 8.568349
# hit patience 1
# epoch 5, iter 22100, avg. loss 47.14, avg. ppl 5.43 cum. examples 3196, speed 3974.09 words/sec, time elapsed 4891.11 sec
# epoch 5, iter 22200, avg. loss 46.19, avg. ppl 5.41 cum. examples 6393, speed 4192.19 words/sec, time elapsed 4911.99 sec
# epoch 5, iter 22300, avg. loss 47.06, avg. ppl 5.49 cum. examples 9590, speed 4028.40 words/sec, time elapsed 4933.91 sec
# epoch 5, iter 22400, avg. loss 48.29, avg. ppl 5.45 cum. examples 12790, speed 4115.78 words/sec, time elapsed 4956.06 sec
# epoch 5, iter 22500, avg. loss 47.72, avg. ppl 5.62 cum. examples 15990, speed 4028.03 words/sec, time elapsed 4978.01 sec
# epoch 5, iter 22600, avg. loss 48.12, avg. ppl 5.56 cum. examples 19186, speed 3995.99 words/sec, time elapsed 5000.44 sec
# epoch 5, iter 22700, avg. loss 47.02, avg. ppl 5.52 cum. examples 22385, speed 4010.01 words/sec, time elapsed 5022.40 sec
# epoch 5, iter 22800, avg. loss 47.28, avg. ppl 5.58 cum. examples 25583, speed 4026.66 words/sec, time elapsed 5044.24 sec
# epoch 5, iter 22900, avg. loss 49.64, avg. ppl 5.85 cum. examples 28782, speed 3785.91 words/sec, time elapsed 5067.99 sec
# epoch 5, iter 23000, avg. loss 48.72, avg. ppl 5.71 cum. examples 31976, speed 3989.86 words/sec, time elapsed 5090.38 sec
# epoch 5, iter 23100, avg. loss 47.61, avg. ppl 5.61 cum. examples 35172, speed 4101.33 words/sec, time elapsed 5111.89 sec
# epoch 5, iter 23200, avg. loss 48.07, avg. ppl 5.73 cum. examples 38372, speed 4270.54 words/sec, time elapsed 5132.52 sec
# epoch 5, iter 23300, avg. loss 49.01, avg. ppl 5.81 cum. examples 41572, speed 3727.81 words/sec, time elapsed 5156.43 sec
# epoch 5, iter 23400, avg. loss 49.12, avg. ppl 5.89 cum. examples 44770, speed 4143.59 words/sec, time elapsed 5177.81 sec
# epoch 5, iter 23500, avg. loss 50.01, avg. ppl 5.90 cum. examples 47968, speed 4212.01 words/sec, time elapsed 5199.20 sec
# epoch 5, iter 23600, avg. loss 48.57, avg. ppl 5.86 cum. examples 51164, speed 3984.31 words/sec, time elapsed 5221.25 sec
# epoch 5, iter 23700, avg. loss 48.23, avg. ppl 5.79 cum. examples 54363, speed 4061.50 words/sec, time elapsed 5242.87 sec
# epoch 5, iter 23800, avg. loss 49.15, avg. ppl 5.90 cum. examples 57559, speed 4283.20 words/sec, time elapsed 5263.52 sec
# epoch 5, iter 23900, avg. loss 48.85, avg. ppl 5.90 cum. examples 60755, speed 4116.45 words/sec, time elapsed 5284.90 sec
# epoch 5, iter 24000, avg. loss 50.31, avg. ppl 5.92 cum. examples 63949, speed 4234.58 words/sec, time elapsed 5306.23 sec
# epoch 5, iter 24000, cum. loss 48.30, cum. ppl 5.69 cum. examples 63949
# begin validation ...
# validation: iter 24000, dev. ppl 8.700622
# hit patience 2
# epoch 5, iter 24100, avg. loss 49.56, avg. ppl 5.93 cum. examples 3198, speed 3769.23 words/sec, time elapsed 5329.86 sec
# epoch 5, iter 24200, avg. loss 49.59, avg. ppl 5.94 cum. examples 6392, speed 3948.40 words/sec, time elapsed 5352.38 sec
# epoch 5, iter 24300, avg. loss 49.84, avg. ppl 5.92 cum. examples 9587, speed 4013.79 words/sec, time elapsed 5374.68 sec
# epoch 5, iter 24400, avg. loss 49.99, avg. ppl 5.97 cum. examples 12786, speed 3955.02 words/sec, time elapsed 5397.31 sec
# epoch 5, iter 24500, avg. loss 49.40, avg. ppl 5.87 cum. examples 15984, speed 3932.40 words/sec, time elapsed 5420.02 sec
# epoch 5, iter 24600, avg. loss 48.37, avg. ppl 5.91 cum. examples 19183, speed 3916.55 words/sec, time elapsed 5442.26 sec
# epoch 5, iter 24700, avg. loss 48.94, avg. ppl 5.94 cum. examples 22382, speed 4084.40 words/sec, time elapsed 5463.78 sec
# epoch 5, iter 24800, avg. loss 49.76, avg. ppl 6.04 cum. examples 25579, speed 3913.83 words/sec, time elapsed 5486.38 sec
# epoch 5, iter 24900, avg. loss 49.97, avg. ppl 6.01 cum. examples 28778, speed 3997.44 words/sec, time elapsed 5508.67 sec
# epoch 5, iter 25000, avg. loss 49.89, avg. ppl 5.88 cum. examples 31972, speed 4072.78 words/sec, time elapsed 5530.76 sec
# epoch 6, iter 25100, avg. loss 42.52, avg. ppl 4.65 cum. examples 35144, speed 4155.83 words/sec, time elapsed 5551.87 sec
# epoch 6, iter 25200, avg. loss 43.75, avg. ppl 4.74 cum. examples 38340, speed 4024.83 words/sec, time elapsed 5574.20 sec
# epoch 6, iter 25300, avg. loss 43.38, avg. ppl 4.87 cum. examples 41540, speed 3963.21 words/sec, time elapsed 5596.32 sec
# epoch 6, iter 25400, avg. loss 43.92, avg. ppl 4.82 cum. examples 44739, speed 4045.10 words/sec, time elapsed 5618.41 sec
# epoch 6, iter 25500, avg. loss 42.81, avg. ppl 4.91 cum. examples 47935, speed 4208.98 words/sec, time elapsed 5638.84 sec
# epoch 6, iter 25600, avg. loss 44.31, avg. ppl 4.94 cum. examples 51129, speed 3947.22 words/sec, time elapsed 5661.28 sec
# epoch 6, iter 25700, avg. loss 45.86, avg. ppl 5.14 cum. examples 54326, speed 4181.50 words/sec, time elapsed 5682.69 sec
# epoch 6, iter 25800, avg. loss 42.85, avg. ppl 4.90 cum. examples 57525, speed 4195.13 words/sec, time elapsed 5703.24 sec
# epoch 6, iter 25900, avg. loss 45.79, avg. ppl 5.16 cum. examples 60724, speed 4034.49 words/sec, time elapsed 5725.37 sec
# epoch 6, iter 26000, avg. loss 45.82, avg. ppl 5.10 cum. examples 63923, speed 4104.92 words/sec, time elapsed 5747.30 sec
# epoch 6, iter 26000, cum. loss 46.82, cum. ppl 5.41 cum. examples 63923
# begin validation ...
# validation: iter 26000, dev. ppl 8.626187
# hit patience 3
# epoch 6, iter 26100, avg. loss 45.34, avg. ppl 5.22 cum. examples 3196, speed 3771.69 words/sec, time elapsed 5770.55 sec
# epoch 6, iter 26200, avg. loss 45.47, avg. ppl 5.21 cum. examples 6395, speed 4037.98 words/sec, time elapsed 5792.38 sec
# epoch 6, iter 26300, avg. loss 45.73, avg. ppl 5.14 cum. examples 9593, speed 3988.88 words/sec, time elapsed 5814.76 sec
# epoch 6, iter 26400, avg. loss 45.81, avg. ppl 5.26 cum. examples 12792, speed 3877.00 words/sec, time elapsed 5837.54 sec
# epoch 6, iter 26500, avg. loss 46.88, avg. ppl 5.27 cum. examples 15991, speed 4082.55 words/sec, time elapsed 5859.63 sec
# epoch 6, iter 26600, avg. loss 46.43, avg. ppl 5.34 cum. examples 19189, speed 3914.73 words/sec, time elapsed 5882.28 sec
# epoch 6, iter 26700, avg. loss 46.22, avg. ppl 5.28 cum. examples 22386, speed 3971.60 words/sec, time elapsed 5904.63 sec
# epoch 6, iter 26800, avg. loss 47.41, avg. ppl 5.44 cum. examples 25580, speed 3959.80 words/sec, time elapsed 5927.20 sec
# epoch 6, iter 26900, avg. loss 46.59, avg. ppl 5.33 cum. examples 28778, speed 4167.48 words/sec, time elapsed 5948.56 sec
# epoch 6, iter 27000, avg. loss 47.41, avg. ppl 5.35 cum. examples 31973, speed 3849.51 words/sec, time elapsed 5972.02 sec
# epoch 6, iter 27100, avg. loss 47.54, avg. ppl 5.37 cum. examples 35171, speed 4018.64 words/sec, time elapsed 5994.53 sec
# epoch 6, iter 27200, avg. loss 47.34, avg. ppl 5.46 cum. examples 38370, speed 4276.60 words/sec, time elapsed 6015.38 sec
# epoch 6, iter 27300, avg. loss 47.74, avg. ppl 5.44 cum. examples 41567, speed 3788.88 words/sec, time elapsed 6039.18 sec
# epoch 6, iter 27400, avg. loss 46.98, avg. ppl 5.51 cum. examples 44762, speed 4107.68 words/sec, time elapsed 6060.58 sec
# epoch 6, iter 27500, avg. loss 47.62, avg. ppl 5.59 cum. examples 47961, speed 4054.42 words/sec, time elapsed 6082.40 sec
# epoch 6, iter 27600, avg. loss 48.95, avg. ppl 5.71 cum. examples 51158, speed 3923.52 words/sec, time elapsed 6105.29 sec
# epoch 6, iter 27700, avg. loss 49.60, avg. ppl 5.56 cum. examples 54354, speed 3954.35 words/sec, time elapsed 6128.66 sec
# epoch 6, iter 27800, avg. loss 48.97, avg. ppl 5.76 cum. examples 57551, speed 3779.72 words/sec, time elapsed 6152.31 sec
# epoch 6, iter 27900, avg. loss 48.92, avg. ppl 5.61 cum. examples 60748, speed 4168.73 words/sec, time elapsed 6174.07 sec
# epoch 6, iter 28000, avg. loss 47.46, avg. ppl 5.56 cum. examples 63943, speed 4078.04 words/sec, time elapsed 6195.74 sec
# epoch 6, iter 28000, cum. loss 47.22, cum. ppl 5.42 cum. examples 63943
# begin validation ...
# validation: iter 28000, dev. ppl 8.654262
# hit patience 4
# epoch 6, iter 28100, avg. loss 48.74, avg. ppl 5.71 cum. examples 3194, speed 3830.31 words/sec, time elapsed 6219.06 sec
# epoch 6, iter 28200, avg. loss 48.64, avg. ppl 5.77 cum. examples 6393, speed 3966.56 words/sec, time elapsed 6241.44 sec
# epoch 6, iter 28300, avg. loss 48.17, avg. ppl 5.75 cum. examples 9590, speed 3993.75 words/sec, time elapsed 6263.47 sec
# epoch 6, iter 28400, avg. loss 49.48, avg. ppl 5.80 cum. examples 12786, speed 3925.75 words/sec, time elapsed 6286.39 sec
# epoch 6, iter 28500, avg. loss 47.53, avg. ppl 5.63 cum. examples 15984, speed 4277.35 words/sec, time elapsed 6306.94 sec
# epoch 6, iter 28600, avg. loss 49.43, avg. ppl 5.84 cum. examples 19183, speed 3843.49 words/sec, time elapsed 6330.26 sec
# epoch 6, iter 28700, avg. loss 48.08, avg. ppl 5.76 cum. examples 22379, speed 4055.96 words/sec, time elapsed 6351.90 sec
# epoch 6, iter 28800, avg. loss 48.90, avg. ppl 5.74 cum. examples 25573, speed 4037.15 words/sec, time elapsed 6374.04 sec
# epoch 6, iter 28900, avg. loss 48.10, avg. ppl 5.66 cum. examples 28772, speed 4018.81 words/sec, time elapsed 6396.13 sec
# epoch 6, iter 29000, avg. loss 49.06, avg. ppl 5.79 cum. examples 31972, speed 3902.92 words/sec, time elapsed 6419.03 sec
# epoch 6, iter 29100, avg. loss 47.93, avg. ppl 5.75 cum. examples 35168, speed 3999.92 words/sec, time elapsed 6440.93 sec
# epoch 7, iter 29200, avg. loss 46.42, avg. ppl 5.39 cum. examples 38340, speed 4130.24 words/sec, time elapsed 6462.10 sec
# epoch 7, iter 29300, avg. loss 43.22, avg. ppl 4.68 cum. examples 41535, speed 3900.20 words/sec, time elapsed 6485.02 sec
# epoch 7, iter 29400, avg. loss 43.29, avg. ppl 4.70 cum. examples 44731, speed 3839.10 words/sec, time elapsed 6508.31 sec
# epoch 7, iter 29500, avg. loss 43.07, avg. ppl 4.70 cum. examples 47929, speed 3854.04 words/sec, time elapsed 6531.41 sec
# epoch 7, iter 29600, avg. loss 43.01, avg. ppl 4.65 cum. examples 51128, speed 4139.51 words/sec, time elapsed 6553.05 sec
# epoch 7, iter 29700, avg. loss 43.43, avg. ppl 4.77 cum. examples 54324, speed 4309.95 words/sec, time elapsed 6573.66 sec
# epoch 7, iter 29800, avg. loss 42.58, avg. ppl 4.73 cum. examples 57520, speed 4116.12 words/sec, time elapsed 6594.93 sec
# epoch 7, iter 29900, avg. loss 43.41, avg. ppl 4.87 cum. examples 60718, speed 4125.33 words/sec, time elapsed 6616.17 sec
# epoch 7, iter 30000, avg. loss 44.30, avg. ppl 4.93 cum. examples 63916, speed 3940.10 words/sec, time elapsed 6638.71 sec
# epoch 7, iter 30000, cum. loss 46.34, cum. ppl 5.31 cum. examples 63916
# begin validation ...
# validation: iter 30000, dev. ppl 8.875869
# hit patience 5
# hit #1 trial
# load previously best model and decay learning rate to 0.000500
# restore parameters of the optimizers
# epoch 7, iter 30100, avg. loss 44.01, avg. ppl 4.85 cum. examples 3197, speed 3475.95 words/sec, time elapsed 6664.34 sec
# epoch 7, iter 30200, avg. loss 42.17, avg. ppl 4.66 cum. examples 6394, speed 4011.77 words/sec, time elapsed 6686.18 sec
# epoch 7, iter 30300, avg. loss 43.72, avg. ppl 4.77 cum. examples 9591, speed 4080.16 words/sec, time elapsed 6708.11 sec
# epoch 7, iter 30400, avg. loss 42.47, avg. ppl 4.66 cum. examples 12788, speed 4225.12 words/sec, time elapsed 6728.98 sec
# epoch 7, iter 30500, avg. loss 42.15, avg. ppl 4.58 cum. examples 15983, speed 4153.46 words/sec, time elapsed 6750.30 sec
# epoch 7, iter 30600, avg. loss 41.49, avg. ppl 4.60 cum. examples 19178, speed 4166.80 words/sec, time elapsed 6771.16 sec
# epoch 7, iter 30700, avg. loss 43.37, avg. ppl 4.62 cum. examples 22376, speed 3898.28 words/sec, time elapsed 6794.39 sec
# epoch 7, iter 30800, avg. loss 42.43, avg. ppl 4.60 cum. examples 25572, speed 4160.03 words/sec, time elapsed 6815.74 sec
# epoch 7, iter 30900, avg. loss 41.96, avg. ppl 4.61 cum. examples 28770, speed 3787.42 words/sec, time elapsed 6838.94 sec
# epoch 7, iter 31000, avg. loss 41.78, avg. ppl 4.53 cum. examples 31969, speed 4089.32 words/sec, time elapsed 6860.58 sec
# epoch 7, iter 31100, avg. loss 42.35, avg. ppl 4.56 cum. examples 35168, speed 3967.46 words/sec, time elapsed 6883.09 sec
# epoch 7, iter 31200, avg. loss 42.39, avg. ppl 4.61 cum. examples 38367, speed 3821.41 words/sec, time elapsed 6906.32 sec
# epoch 7, iter 31300, avg. loss 43.18, avg. ppl 4.63 cum. examples 41562, speed 3985.73 words/sec, time elapsed 6928.90 sec
# epoch 7, iter 31400, avg. loss 41.53, avg. ppl 4.50 cum. examples 44757, speed 3987.11 words/sec, time elapsed 6951.04 sec
# epoch 7, iter 31500, avg. loss 43.08, avg. ppl 4.61 cum. examples 47952, speed 3821.90 words/sec, time elapsed 6974.60 sec
# epoch 7, iter 31600, avg. loss 41.75, avg. ppl 4.60 cum. examples 51151, speed 3796.02 words/sec, time elapsed 6997.64 sec
# epoch 7, iter 31700, avg. loss 42.72, avg. ppl 4.56 cum. examples 54350, speed 4048.10 words/sec, time elapsed 7019.90 sec
# epoch 7, iter 31800, avg. loss 41.64, avg. ppl 4.53 cum. examples 57548, speed 4232.31 words/sec, time elapsed 7040.72 sec
# epoch 7, iter 31900, avg. loss 42.80, avg. ppl 4.67 cum. examples 60744, speed 4040.19 words/sec, time elapsed 7062.70 sec
# epoch 7, iter 32000, avg. loss 42.48, avg. ppl 4.62 cum. examples 63943, speed 4035.99 words/sec, time elapsed 7084.70 sec
# epoch 7, iter 32000, cum. loss 42.47, cum. ppl 4.62 cum. examples 63943
# begin validation ...
# validation: iter 32000, dev. ppl 7.681446
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 7, iter 32100, avg. loss 41.64, avg. ppl 4.56 cum. examples 3199, speed 3310.71 words/sec, time elapsed 7111.22 sec
# epoch 7, iter 32200, avg. loss 43.14, avg. ppl 4.64 cum. examples 6394, speed 4106.01 words/sec, time elapsed 7133.10 sec
# epoch 7, iter 32300, avg. loss 43.85, avg. ppl 4.59 cum. examples 9593, speed 3863.63 words/sec, time elapsed 7156.94 sec
# epoch 7, iter 32400, avg. loss 42.05, avg. ppl 4.58 cum. examples 12792, speed 3846.55 words/sec, time elapsed 7179.93 sec
# epoch 7, iter 32500, avg. loss 41.51, avg. ppl 4.49 cum. examples 15989, speed 4182.76 words/sec, time elapsed 7201.06 sec
# epoch 7, iter 32600, avg. loss 41.92, avg. ppl 4.54 cum. examples 19187, speed 4203.59 words/sec, time elapsed 7222.13 sec
# epoch 7, iter 32700, avg. loss 42.46, avg. ppl 4.59 cum. examples 22386, speed 4254.18 words/sec, time elapsed 7243.10 sec
# epoch 7, iter 32800, avg. loss 42.84, avg. ppl 4.68 cum. examples 25581, speed 3822.87 words/sec, time elapsed 7266.28 sec
# epoch 7, iter 32900, avg. loss 42.44, avg. ppl 4.59 cum. examples 28779, speed 4149.15 words/sec, time elapsed 7287.76 sec
# epoch 7, iter 33000, avg. loss 42.62, avg. ppl 4.66 cum. examples 31977, speed 4186.30 words/sec, time elapsed 7308.92 sec
# epoch 7, iter 33100, avg. loss 42.83, avg. ppl 4.56 cum. examples 35172, speed 4197.14 words/sec, time elapsed 7330.41 sec
# epoch 7, iter 33200, avg. loss 42.74, avg. ppl 4.64 cum. examples 38372, speed 4066.09 words/sec, time elapsed 7352.33 sec
# epoch 7, iter 33300, avg. loss 43.35, avg. ppl 4.64 cum. examples 41570, speed 3951.45 words/sec, time elapsed 7375.19 sec
# epoch 8, iter 33400, avg. loss 39.89, avg. ppl 4.05 cum. examples 44742, speed 4032.08 words/sec, time elapsed 7397.62 sec
# epoch 8, iter 33500, avg. loss 36.84, avg. ppl 3.80 cum. examples 47940, speed 4034.45 words/sec, time elapsed 7419.49 sec
# epoch 8, iter 33600, avg. loss 37.35, avg. ppl 3.79 cum. examples 51139, speed 4017.00 words/sec, time elapsed 7441.81 sec
# epoch 8, iter 33700, avg. loss 36.37, avg. ppl 3.83 cum. examples 54336, speed 4171.33 words/sec, time elapsed 7462.56 sec
# epoch 8, iter 33800, avg. loss 37.71, avg. ppl 3.88 cum. examples 57533, speed 3926.68 words/sec, time elapsed 7485.22 sec
# epoch 8, iter 33900, avg. loss 37.39, avg. ppl 3.88 cum. examples 60733, speed 4142.35 words/sec, time elapsed 7506.50 sec
# epoch 8, iter 34000, avg. loss 39.11, avg. ppl 3.98 cum. examples 63929, speed 3890.50 words/sec, time elapsed 7529.76 sec
# epoch 8, iter 34000, cum. loss 40.90, cum. ppl 4.33 cum. examples 63929
# begin validation ...
# validation: iter 34000, dev. ppl 7.654695
# save currently the best model to [lstm_model.bin]
# save model parameters to [lstm_model.bin]
# epoch 8, iter 34100, avg. loss 38.03, avg. ppl 3.93 cum. examples 3200, speed 3509.73 words/sec, time elapsed 7555.10 sec
# epoch 8, iter 34200, avg. loss 37.73, avg. ppl 3.90 cum. examples 6395, speed 4064.20 words/sec, time elapsed 7576.91 sec
# epoch 8, iter 34300, avg. loss 37.71, avg. ppl 3.97 cum. examples 9593, speed 4050.46 words/sec, time elapsed 7598.50 sec
# epoch 8, iter 34400, avg. loss 38.86, avg. ppl 4.05 cum. examples 12790, speed 3915.43 words/sec, time elapsed 7621.20 sec
# epoch 8, iter 34500, avg. loss 38.02, avg. ppl 3.95 cum. examples 15989, speed 4030.52 words/sec, time elapsed 7643.18 sec
# epoch 8, iter 34600, avg. loss 38.98, avg. ppl 4.04 cum. examples 19186, speed 4331.36 words/sec, time elapsed 7663.79 sec
# epoch 8, iter 34700, avg. loss 38.31, avg. ppl 3.99 cum. examples 22385, speed 4191.37 words/sec, time elapsed 7684.92 sec
# epoch 8, iter 34800, avg. loss 39.30, avg. ppl 4.06 cum. examples 25584, speed 3886.34 words/sec, time elapsed 7708.00 sec
# epoch 8, iter 34900, avg. loss 40.24, avg. ppl 4.10 cum. examples 28780, speed 3860.89 words/sec, time elapsed 7731.60 sec
# epoch 8, iter 35000, avg. loss 39.37, avg. ppl 4.13 cum. examples 31975, speed 4181.07 words/sec, time elapsed 7752.83 sec
# epoch 8, iter 35100, avg. loss 39.97, avg. ppl 4.13 cum. examples 35173, speed 3925.83 words/sec, time elapsed 7775.81 sec
# epoch 8, iter 35200, avg. loss 38.14, avg. ppl 4.04 cum. examples 38370, speed 3874.48 words/sec, time elapsed 7798.36 sec
# epoch 8, iter 35300, avg. loss 39.25, avg. ppl 4.03 cum. examples 41567, speed 4094.77 words/sec, time elapsed 7820.35 sec
# epoch 8, iter 35400, avg. loss 39.12, avg. ppl 4.04 cum. examples 44762, speed 4017.88 words/sec, time elapsed 7842.61 sec
# epoch 8, iter 35500, avg. loss 38.10, avg. ppl 4.00 cum. examples 47957, speed 4204.33 words/sec, time elapsed 7863.48 sec
# epoch 8, iter 35600, avg. loss 38.62, avg. ppl 4.04 cum. examples 51157, speed 4193.22 words/sec, time elapsed 7884.60 sec
# epoch 8, iter 35700, avg. loss 38.97, avg. ppl 4.09 cum. examples 54354, speed 3965.02 words/sec, time elapsed 7906.92 sec
# ...
# epoch 27, iter 113300, avg. loss 29.33, avg. ppl 2.90 cum. examples 41541, speed 4019.26 words/sec, time elapsed 25002.58 sec
# epoch 27, iter 113400, avg. loss 31.17, avg. ppl 2.93 cum. examples 44736, speed 3876.77 words/sec, time elapsed 25026.47 sec
# epoch 27, iter 113500, avg. loss 30.09, avg. ppl 2.91 cum. examples 47931, speed 3893.70 words/sec, time elapsed 25049.57 sec
# epoch 27, iter 113600, avg. loss 29.08, avg. ppl 2.92 cum. examples 51130, speed 4166.98 words/sec, time elapsed 25070.40 sec
# epoch 27, iter 113700, avg. loss 28.73, avg. ppl 2.84 cum. examples 54328, speed 4100.04 words/sec, time elapsed 25091.90 sec
# epoch 27, iter 113800, avg. loss 29.42, avg. ppl 2.87 cum. examples 57521, speed 4020.00 words/sec, time elapsed 25114.06 sec
# epoch 27, iter 113900, avg. loss 29.25, avg. ppl 2.90 cum. examples 60719, speed 4341.79 words/sec, time elapsed 25134.30 sec
# epoch 27, iter 114000, avg. loss 29.78, avg. ppl 2.92 cum. examples 63915, speed 4052.43 words/sec, time elapsed 25156.25 sec
# epoch 27, iter 114000, cum. loss 29.62, cum. ppl 2.90 cum. examples 63915
# begin validation ...
# validation: iter 114000, dev. ppl 7.428902
# hit patience 1
# epoch 27, iter 114100, avg. loss 29.65, avg. ppl 2.88 cum. examples 3198, speed 3548.20 words/sec, time elapsed 25181.51 sec
# epoch 27, iter 114200, avg. loss 30.13, avg. ppl 2.95 cum. examples 6394, speed 4178.00 words/sec, time elapsed 25202.84 sec
# epoch 27, iter 114300, avg. loss 29.05, avg. ppl 2.88 cum. examples 9590, speed 4120.95 words/sec, time elapsed 25224.11 sec
# epoch 27, iter 114400, avg. loss 28.66, avg. ppl 2.85 cum. examples 12787, speed 4109.45 words/sec, time elapsed 25245.41 sec
# epoch 27, iter 114500, avg. loss 28.81, avg. ppl 2.84 cum. examples 15985, speed 3897.07 words/sec, time elapsed 25268.05 sec
# epoch 27, iter 114600, avg. loss 29.49, avg. ppl 2.88 cum. examples 19177, speed 3941.92 words/sec, time elapsed 25290.64 sec
# epoch 27, iter 114700, avg. loss 29.50, avg. ppl 2.94 cum. examples 22376, speed 4041.95 words/sec, time elapsed 25312.30 sec
# epoch 27, iter 114800, avg. loss 29.38, avg. ppl 2.87 cum. examples 25576, speed 3969.35 words/sec, time elapsed 25334.73 sec
# epoch 27, iter 114900, avg. loss 29.10, avg. ppl 2.89 cum. examples 28772, speed 4172.18 words/sec, time elapsed 25355.72 sec
# epoch 27, iter 115000, avg. loss 30.44, avg. ppl 2.88 cum. examples 31967, speed 3918.97 words/sec, time elapsed 25379.16 sec
# epoch 27, iter 115100, avg. loss 29.81, avg. ppl 2.90 cum. examples 35166, speed 4158.36 words/sec, time elapsed 25400.68 sec
# epoch 27, iter 115200, avg. loss 29.76, avg. ppl 2.90 cum. examples 38362, speed 4124.29 words/sec, time elapsed 25422.33 sec
# epoch 27, iter 115300, avg. loss 29.69, avg. ppl 2.91 cum. examples 41562, speed 4129.50 words/sec, time elapsed 25443.90 sec
# epoch 27, iter 115400, avg. loss 28.90, avg. ppl 2.87 cum. examples 44759, speed 4279.34 words/sec, time elapsed 25464.34 sec
# epoch 27, iter 115500, avg. loss 29.87, avg. ppl 2.93 cum. examples 47956, speed 3994.18 words/sec, time elapsed 25486.58 sec
# epoch 27, iter 115600, avg. loss 29.46, avg. ppl 2.90 cum. examples 51152, speed 4191.46 words/sec, time elapsed 25507.70 sec
# epoch 27, iter 115700, avg. loss 29.38, avg. ppl 2.88 cum. examples 54350, speed 3977.43 words/sec, time elapsed 25530.01 sec
# epoch 27, iter 115800, avg. loss 29.63, avg. ppl 2.87 cum. examples 57549, speed 4178.24 words/sec, time elapsed 25551.53 sec
# epoch 27, iter 115900, avg. loss 30.06, avg. ppl 2.91 cum. examples 60747, speed 3738.52 words/sec, time elapsed 25575.64 sec
# epoch 27, iter 116000, avg. loss 29.71, avg. ppl 2.93 cum. examples 63945, speed 4113.25 words/sec, time elapsed 25597.15 sec
# epoch 27, iter 116000, cum. loss 29.52, cum. ppl 2.89 cum. examples 63945
# begin validation ...
# validation: iter 116000, dev. ppl 7.432089
# hit patience 2
# epoch 27, iter 116100, avg. loss 29.06, avg. ppl 2.85 cum. examples 3200, speed 3585.80 words/sec, time elapsed 25621.91 sec
# epoch 27, iter 116200, avg. loss 29.73, avg. ppl 2.88 cum. examples 6399, speed 4294.07 words/sec, time elapsed 25642.88 sec
# epoch 27, iter 116300, avg. loss 29.47, avg. ppl 2.89 cum. examples 9594, speed 3736.56 words/sec, time elapsed 25666.63 sec
# epoch 27, iter 116400, avg. loss 30.50, avg. ppl 2.94 cum. examples 12792, speed 4032.32 words/sec, time elapsed 25689.07 sec
# epoch 27, iter 116500, avg. loss 29.52, avg. ppl 2.86 cum. examples 15992, speed 4190.89 words/sec, time elapsed 25710.53 sec
# epoch 27, iter 116600, avg. loss 29.77, avg. ppl 2.91 cum. examples 19190, speed 4217.87 words/sec, time elapsed 25731.67 sec
# epoch 28, iter 116700, avg. loss 29.46, avg. ppl 2.90 cum. examples 22360, speed 4042.99 words/sec, time elapsed 25753.35 sec
# epoch 28, iter 116800, avg. loss 30.27, avg. ppl 2.93 cum. examples 25557, speed 4098.78 words/sec, time elapsed 25775.29 sec
# epoch 28, iter 116900, avg. loss 29.87, avg. ppl 2.96 cum. examples 28753, speed 3907.27 words/sec, time elapsed 25797.83 sec
# epoch 28, iter 117000, avg. loss 30.07, avg. ppl 2.90 cum. examples 31949, speed 4094.74 words/sec, time elapsed 25819.89 sec
# epoch 28, iter 117100, avg. loss 29.50, avg. ppl 2.86 cum. examples 35148, speed 4116.12 words/sec, time elapsed 25841.68 sec
# epoch 28, iter 117200, avg. loss 29.73, avg. ppl 2.91 cum. examples 38346, speed 4115.32 words/sec, time elapsed 25863.32 sec
# epoch 28, iter 117300, avg. loss 29.81, avg. ppl 2.88 cum. examples 41544, speed 4095.41 words/sec, time elapsed 25885.32 sec
# epoch 28, iter 117400, avg. loss 28.64, avg. ppl 2.85 cum. examples 44740, speed 4111.40 words/sec, time elapsed 25906.61 sec
# epoch 28, iter 117500, avg. loss 29.55, avg. ppl 2.85 cum. examples 47936, speed 4099.52 words/sec, time elapsed 25928.59 sec
# epoch 28, iter 117600, avg. loss 30.35, avg. ppl 2.94 cum. examples 51132, speed 3908.74 words/sec, time elapsed 25951.61 sec
# epoch 28, iter 117700, avg. loss 29.77, avg. ppl 2.89 cum. examples 54328, speed 3678.69 words/sec, time elapsed 25975.95 sec
# epoch 28, iter 117800, avg. loss 29.57, avg. ppl 2.87 cum. examples 57526, speed 3927.23 words/sec, time elapsed 25998.76 sec
# epoch 28, iter 117900, avg. loss 28.92, avg. ppl 2.86 cum. examples 60723, speed 4110.20 words/sec, time elapsed 26020.17 sec
# epoch 28, iter 118000, avg. loss 30.02, avg. ppl 2.91 cum. examples 63920, speed 4175.25 words/sec, time elapsed 26041.66 sec
# epoch 28, iter 118000, cum. loss 29.68, cum. ppl 2.89 cum. examples 63920
# begin validation ...
# validation: iter 118000, dev. ppl 7.433908
# hit patience 3
# epoch 28, iter 118100, avg. loss 29.56, avg. ppl 2.87 cum. examples 3196, speed 3697.12 words/sec, time elapsed 26065.88 sec
# epoch 28, iter 118200, avg. loss 29.77, avg. ppl 2.90 cum. examples 6395, speed 4113.21 words/sec, time elapsed 26087.64 sec
# epoch 28, iter 118300, avg. loss 28.61, avg. ppl 2.82 cum. examples 9591, speed 4120.49 words/sec, time elapsed 26109.03 sec
# epoch 28, iter 118400, avg. loss 29.26, avg. ppl 2.88 cum. examples 12789, speed 4112.34 words/sec, time elapsed 26130.53 sec
# epoch 28, iter 118500, avg. loss 28.19, avg. ppl 2.84 cum. examples 15987, speed 4224.81 words/sec, time elapsed 26151.00 sec
# epoch 28, iter 118600, avg. loss 29.82, avg. ppl 2.89 cum. examples 19184, speed 4074.29 words/sec, time elapsed 26173.06 sec
# epoch 28, iter 118700, avg. loss 29.59, avg. ppl 2.87 cum. examples 22379, speed 3980.99 words/sec, time elapsed 26195.58 sec
# epoch 28, iter 118800, avg. loss 28.88, avg. ppl 2.83 cum. examples 25577, speed 4106.12 words/sec, time elapsed 26217.18 sec
# epoch 28, iter 118900, avg. loss 28.92, avg. ppl 2.90 cum. examples 28775, speed 3996.73 words/sec, time elapsed 26238.94 sec
# epoch 28, iter 119000, avg. loss 29.64, avg. ppl 2.90 cum. examples 31971, speed 4241.02 words/sec, time elapsed 26259.90 sec
# epoch 28, iter 119100, avg. loss 28.68, avg. ppl 2.82 cum. examples 35171, speed 3999.08 words/sec, time elapsed 26282.06 sec
# epoch 28, iter 119200, avg. loss 29.52, avg. ppl 2.90 cum. examples 38371, speed 3925.37 words/sec, time elapsed 26304.68 sec
# epoch 28, iter 119300, avg. loss 29.22, avg. ppl 2.88 cum. examples 41565, speed 4247.07 words/sec, time elapsed 26325.46 sec
# epoch 28, iter 119400, avg. loss 29.09, avg. ppl 2.88 cum. examples 44762, speed 4093.82 words/sec, time elapsed 26346.93 sec
# epoch 28, iter 119500, avg. loss 29.52, avg. ppl 2.86 cum. examples 47960, speed 4142.00 words/sec, time elapsed 26368.61 sec
# epoch 28, iter 119600, avg. loss 29.69, avg. ppl 2.88 cum. examples 51157, speed 3934.19 words/sec, time elapsed 26391.39 sec
# epoch 28, iter 119700, avg. loss 29.21, avg. ppl 2.88 cum. examples 54355, speed 4156.40 words/sec, time elapsed 26412.65 sec
# epoch 28, iter 119800, avg. loss 29.31, avg. ppl 2.85 cum. examples 57553, speed 4146.92 words/sec, time elapsed 26434.22 sec
# epoch 28, iter 119900, avg. loss 29.79, avg. ppl 2.88 cum. examples 60752, speed 4073.10 words/sec, time elapsed 26456.32 sec
# epoch 28, iter 120000, avg. loss 29.97, avg. ppl 2.89 cum. examples 63951, speed 4082.53 words/sec, time elapsed 26478.47 sec
# epoch 28, iter 120000, cum. loss 29.31, cum. ppl 2.87 cum. examples 63951
# begin validation ...
# validation: iter 120000, dev. ppl 7.434036
# hit patience 4
# epoch 28, iter 120100, avg. loss 28.97, avg. ppl 2.83 cum. examples 3199, speed 3648.63 words/sec, time elapsed 26502.88 sec
# epoch 28, iter 120200, avg. loss 29.11, avg. ppl 2.88 cum. examples 6395, speed 4300.49 words/sec, time elapsed 26523.32 sec
# epoch 28, iter 120300, avg. loss 29.49, avg. ppl 2.89 cum. examples 9593, speed 4188.37 words/sec, time elapsed 26544.57 sec
# epoch 28, iter 120400, avg. loss 28.76, avg. ppl 2.86 cum. examples 12791, speed 4107.38 words/sec, time elapsed 26565.85 sec
# epoch 28, iter 120500, avg. loss 29.01, avg. ppl 2.87 cum. examples 15988, speed 4217.25 words/sec, time elapsed 26586.70 sec
# epoch 28, iter 120600, avg. loss 28.90, avg. ppl 2.81 cum. examples 19185, speed 4016.36 words/sec, time elapsed 26608.94 sec
# epoch 28, iter 120700, avg. loss 29.13, avg. ppl 2.86 cum. examples 22382, speed 3891.69 words/sec, time elapsed 26631.73 sec
# epoch 28, iter 120800, avg. loss 30.37, avg. ppl 2.92 cum. examples 25582, speed 3954.34 words/sec, time elapsed 26654.68 sec
# epoch 29, iter 120900, avg. loss 29.03, avg. ppl 2.84 cum. examples 28750, speed 4001.71 words/sec, time elapsed 26676.70 sec
# epoch 29, iter 121000, avg. loss 29.40, avg. ppl 2.82 cum. examples 31948, speed 4095.53 words/sec, time elapsed 26698.86 sec
# epoch 29, iter 121100, avg. loss 29.46, avg. ppl 2.88 cum. examples 35143, speed 4048.44 words/sec, time elapsed 26720.86 sec
# epoch 29, iter 121200, avg. loss 29.04, avg. ppl 2.87 cum. examples 38341, speed 4223.08 words/sec, time elapsed 26741.71 sec
# epoch 29, iter 121300, avg. loss 30.22, avg. ppl 2.92 cum. examples 41536, speed 3884.59 words/sec, time elapsed 26764.94 sec
# epoch 29, iter 121400, avg. loss 28.69, avg. ppl 2.84 cum. examples 44733, speed 3997.05 words/sec, time elapsed 26786.96 sec
# epoch 29, iter 121500, avg. loss 29.39, avg. ppl 2.87 cum. examples 47931, speed 4045.63 words/sec, time elapsed 26809.02 sec
# epoch 29, iter 121600, avg. loss 29.28, avg. ppl 2.87 cum. examples 51126, speed 4213.08 words/sec, time elapsed 26830.11 sec
# epoch 29, iter 121700, avg. loss 29.23, avg. ppl 2.89 cum. examples 54325, speed 4210.03 words/sec, time elapsed 26851.03 sec
# epoch 29, iter 121800, avg. loss 28.91, avg. ppl 2.83 cum. examples 57522, speed 4215.52 words/sec, time elapsed 26872.12 sec
# epoch 29, iter 121900, avg. loss 28.91, avg. ppl 2.83 cum. examples 60716, speed 3918.99 words/sec, time elapsed 26894.73 sec
# epoch 29, iter 122000, avg. loss 29.11, avg. ppl 2.85 cum. examples 63913, speed 4030.43 words/sec, time elapsed 26916.76 sec
# epoch 29, iter 122000, cum. loss 29.22, cum. ppl 2.86 cum. examples 63913
# begin validation ...
# validation: iter 122000, dev. ppl 7.441389
# hit patience 5
# hit #9 trial
# load previously best model and decay learning rate to 0.000002
# restore parameters of the optimizers
# epoch 29, iter 122100, avg. loss 29.39, avg. ppl 2.86 cum. examples 3198, speed 3741.26 words/sec, time elapsed 26940.64 sec
# epoch 29, iter 122200, avg. loss 29.05, avg. ppl 2.87 cum. examples 6397, speed 4378.38 words/sec, time elapsed 26960.74 sec
# epoch 29, iter 122300, avg. loss 30.25, avg. ppl 2.92 cum. examples 9594, speed 3762.08 words/sec, time elapsed 26984.73 sec
# epoch 29, iter 122400, avg. loss 29.40, avg. ppl 2.92 cum. examples 12793, speed 4055.70 words/sec, time elapsed 27006.41 sec
# epoch 29, iter 122500, avg. loss 29.71, avg. ppl 2.88 cum. examples 15988, speed 4030.57 words/sec, time elapsed 27028.66 sec
# epoch 29, iter 122600, avg. loss 30.15, avg. ppl 2.89 cum. examples 19188, speed 4154.05 words/sec, time elapsed 27050.51 sec
# epoch 29, iter 122700, avg. loss 29.81, avg. ppl 2.91 cum. examples 22386, speed 3938.20 words/sec, time elapsed 27073.16 sec
# epoch 29, iter 122800, avg. loss 29.13, avg. ppl 2.86 cum. examples 25585, speed 4222.18 words/sec, time elapsed 27094.18 sec
# epoch 29, iter 122900, avg. loss 29.30, avg. ppl 2.93 cum. examples 28782, speed 4217.58 words/sec, time elapsed 27114.88 sec
# epoch 29, iter 123000, avg. loss 29.43, avg. ppl 2.88 cum. examples 31978, speed 4013.55 words/sec, time elapsed 27137.02 sec
# epoch 29, iter 123100, avg. loss 29.76, avg. ppl 2.90 cum. examples 35176, speed 4034.01 words/sec, time elapsed 27159.21 sec
# epoch 29, iter 123200, avg. loss 29.80, avg. ppl 2.93 cum. examples 38374, speed 4126.69 words/sec, time elapsed 27180.67 sec
# epoch 29, iter 123300, avg. loss 28.83, avg. ppl 2.85 cum. examples 41573, speed 4067.88 words/sec, time elapsed 27202.32 sec
# epoch 29, iter 123400, avg. loss 29.24, avg. ppl 2.86 cum. examples 44770, speed 4009.41 words/sec, time elapsed 27224.48 sec
# epoch 29, iter 123500, avg. loss 30.49, avg. ppl 2.92 cum. examples 47968, speed 3919.00 words/sec, time elapsed 27247.70 sec
# epoch 29, iter 123600, avg. loss 29.42, avg. ppl 2.92 cum. examples 51163, speed 3934.46 words/sec, time elapsed 27270.03 sec
# epoch 29, iter 123700, avg. loss 28.94, avg. ppl 2.87 cum. examples 54362, speed 3848.18 words/sec, time elapsed 27292.83 sec
# epoch 29, iter 123800, avg. loss 28.87, avg. ppl 2.86 cum. examples 57559, speed 4085.98 words/sec, time elapsed 27314.29 sec
# epoch 29, iter 123900, avg. loss 29.31, avg. ppl 2.88 cum. examples 60756, speed 4169.77 words/sec, time elapsed 27335.55 sec
# epoch 29, iter 124000, avg. loss 30.04, avg. ppl 2.91 cum. examples 63953, speed 4223.48 words/sec, time elapsed 27356.81 sec
# epoch 29, iter 124000, cum. loss 29.52, cum. ppl 2.89 cum. examples 63953
# begin validation ...
# validation: iter 124000, dev. ppl 7.427242
# hit patience 1
# epoch 29, iter 124100, avg. loss 29.97, avg. ppl 2.90 cum. examples 3196, speed 3756.67 words/sec, time elapsed 27380.75 sec
# epoch 29, iter 124200, avg. loss 29.27, avg. ppl 2.91 cum. examples 6395, speed 4183.17 words/sec, time elapsed 27401.72 sec
# epoch 29, iter 124300, avg. loss 30.93, avg. ppl 2.98 cum. examples 9592, speed 4021.51 words/sec, time elapsed 27424.26 sec
# epoch 29, iter 124400, avg. loss 29.30, avg. ppl 2.88 cum. examples 12788, speed 4154.47 words/sec, time elapsed 27445.56 sec
# epoch 29, iter 124500, avg. loss 30.04, avg. ppl 2.91 cum. examples 15986, speed 3916.67 words/sec, time elapsed 27468.53 sec
# epoch 29, iter 124600, avg. loss 28.96, avg. ppl 2.85 cum. examples 19185, speed 4274.40 words/sec, time elapsed 27489.20 sec
# epoch 29, iter 124700, avg. loss 29.64, avg. ppl 2.90 cum. examples 22384, speed 4199.15 words/sec, time elapsed 27510.38 sec
# epoch 29, iter 124800, avg. loss 29.60, avg. ppl 2.91 cum. examples 25578, speed 4262.48 words/sec, time elapsed 27531.16 sec
# epoch 29, iter 124900, avg. loss 29.27, avg. ppl 2.93 cum. examples 28778, speed 4304.24 words/sec, time elapsed 27551.38 sec
# epoch 29, iter 125000, avg. loss 29.72, avg. ppl 2.89 cum. examples 31976, speed 3976.13 words/sec, time elapsed 27573.93 sec

# %% [markdown]
# # The Seq2Seq Model 2: Transformer
# In this part, we will train a sequence-to-sequence Transformer model to translate Portuguese into English. The Transformer was originally proposed in "Attention is all you need" by Vaswani et al. (2017).
#
# <img src="https://www.tensorflow.org/images/tutorials/transformer/apply_the_transformer_to_machine_translation.gif" alt="Applying the Transformer to machine translation">
#
# Figure 2: Applying the Transformer to machine translation. Source: [Google AI Blog](https://ai.googleblog.com/2017/08/transformer-novel-neural-network.html).

# %% [markdown]
# A Transformer is a sequence-to-sequence encoder-decoder model similar to the model in the [NMT with attention tutorial](https://www.tensorflow.org/text/tutorials/nmt_with_attention).
# A single-layer Transformer takes a little more code to write, but is almost identical to that encoder-decoder RNN model. The only difference is that the RNN layers are replaced with self attention layers.
#
# <table>
# <tr>
#   <th>The <a href=https://www.tensorflow.org/text/tutorials/nmt_with_attention>RNN+Attention model</a></th>
#   <th>A 1-layer transformer</th>
# </tr>
# <tr>
#   <td>
#    <img width=411 src="https://www.tensorflow.org/images/tutorials/transformer/RNN+attention-words.png"/>
#   </td>
#   <td>
#    <img width=400 src="https://www.tensorflow.org/images/tutorials/transformer/Transformer-1layer-words.png"/>
#   </td>
# </tr>
# </table>

# %% [markdown]
# ### The embedding and positional encoding layer
#
# The inputs to both the encoder and decoder use the same embedding and positional encoding logic.
#
# <table>
# <tr>
#   <th colspan=1>The embedding and positional encoding layer</th>
# <tr>
# <tr>
#   <td>
#    <img src="https://www.tensorflow.org/images/tutorials/transformer/PositionalEmbedding.png"/>
#   </td>
# </tr>
# </table>

# %% [markdown]
# The formula for calculating the positional encoding (implemented in Python below) is as follows:
#
# $$\Large{PE_{(pos, 2i)} = \sin(pos / 10000^{2i / d_{model}})} $$
# $$\Large{PE_{(pos, 2i+1)} = \cos(pos / 10000^{2i / d_{model}})} $$

# %% [markdown]
# # Transformer Embedding Layer
# Implement embedding layer (consists of lookup embedding & positional encoding) for transformer model.

# %%
class TransformerEmbedding(nn.Module):
    """
    Class that combines token embeddings with positional embeddings.
    """
    def __init__(self, vocab_size, embedding_size, max_len, dropout_rate):
        """
        Init the Transformer Embedding layer.

        @param vocab_size (int): Vocabulary size (number of unique tokens)
        @param embedding_size (int): Embedding size (dimensionality)
        @param max_len (int): Maximum sequence length
        @param dropout_rate (float): Dropout probability
        """
        super().__init__()
        # default values

        ### TODO - Implement the positional embedding and Initialize the following variables :
        ###     self.token_embedding (Embedding Layer)
        ###     self.pos_embedding (Positional Embedding Layer), notes that pos_embedding is not learnable parameters, 
        ###         so we should use the self.register_buffer function to initialize it.
        ###     self.dropout (Dropout Layer)

        # Token Embedding Layer
        self.token_embedding = nn.Embedding(vocab_size, embedding_size)

        # Positional Encoding Layer
        den = torch.exp(- torch.arange(0, embedding_size, 2)* math.log(10000) / embedding_size)
        pos = torch.arange(0, max_len).reshape(max_len, 1)
        pos_embedding = torch.zeros((max_len, embedding_size))
        pos_embedding[:, 0::2] = torch.sin(pos * den)
        pos_embedding[:, 1::2] = torch.cos(pos * den)
        pos_embedding = pos_embedding.unsqueeze(-2)

        self.dropout = nn.Dropout(dropout_rate)
        self.register_buffer('pos_embedding', pos_embedding)

    def forward(self, x):
        """
        Maps input sequences of tokens to their embeddings.

        param x (Tensor): Input tensor of tokens with shape (batch_size, seq_len)

        returns embedded (Tensor): Tensor of token embeddings with shape (batch_size, seq_len, embedding_size)
        """
        # Retrieve token embeddings
        embedded_tokens = self.token_embedding(x.long())
        
        # Retrieve positional embeddings for the appropriate segment of the input sequence
        embedded_positions = self.pos_embedding[:embedded_tokens.size(0), :]

        # Add token and positional embeddings together, apply dropout, and return
        embedded = self.dropout(embedded_tokens + embedded_positions)
        return embedded

# %% [markdown]
# ### The transformer model:
#
# To be convinient, we will use nn.Transformer layer from PyTorch. We will build a 4-layer Transformer model.
#
# <table>
# <tr>
#   <th colspan=1>The original Transformer diagram</th>
#   <th colspan=1>A representation of a 4-layer Transformer</th>
# </tr>
# <tr>
#   <td>
#    <img width=400 src="https://www.tensorflow.org/images/tutorials/transformer/transformer.png"/>
#   </td>
#   <td>
#    <img width=307 src="https://www.tensorflow.org/images/tutorials/transformer/Transformer-4layer-compact.png"/>
#   </td>
# </tr>
# </table>

# %% [markdown]
# # Initialize layers in TransformerNMT model
# Implement the __init__ function  to initialize the
# necessary module for our TransformerNMT model

# %% [markdown]
# # Implement the **forward** function
# Implement the forward function in the TransformerNMT class

# %%
Hypothesis = namedtuple('Hypothesis', ['value', 'score'])

class TransformerNMT(nn.Module):
    """ Neural Machine Translation Model with Transformer:
        - Encoder with stacked self-attention and feedforward layers
        - Decoder with stacked self-attention, encoder-decoder attention, and feedforward layers
    """
    def __init__(self, d_model, n_heads, ff_size, n_layers, max_len, vocab, dropout_rate):
        """ Init TransformerNMT NMT Model.
        @param d_model (int): Hidden Size, the size of hidden states (dimensionality)
        @param n_heads (int): The number of heads in the multiheadattention
        @param n_layers (int): The number of sub-layers in the Encoder and Decoder Transformer
        @param ff_size (int): The dimension of the feedforward network model 
        @param max_len (int) max sequence length
        @param vocab (Vocab): Vocabulary object containing src and tgt languages
                              See vocab.py for documentation.
        @param dropout_rate (float): Dropout probability, for attention
        """
        super(TransformerNMT, self).__init__()
        self.d_model = d_model
        self.n_heads = n_heads
        self.ff_size = ff_size
        self.n_layers = n_layers
        self.max_len = max_len
        self.vocab = vocab
        self.dropout_rate = dropout_rate

        self.src_embedding = None
        self.tgt_embedding = None
        self.transformer = None
        self.target_vocab_projection = None

        ### TODO - Initialize the following variables IN THIS ORDER:
        ###     self.src_embedding: Transformer Embedding Layer used for source language
        ###     self.tgt_embedding: Transformer Embedding Layer used for target language
        ###     self.transformer: Transformer layer
        ###     self.target_vocab_projection (Linear Layer with no bias), mapping hidden representation to the vocab distribution

        self.src_embedding = TransformerEmbedding(vocab_size=len(vocab.src), embedding_size=d_model, max_len=max_len, dropout_rate=dropout_rate)
        self.tgt_embedding = TransformerEmbedding(vocab_size=len(vocab.tgt), embedding_size=d_model, max_len=max_len, dropout_rate=dropout_rate)

        self.transformer = nn.Transformer(d_model=d_model, nhead=n_heads, num_encoder_layers=n_layers, num_decoder_layers=n_layers, dim_feedforward=ff_size, dropout=dropout_rate)
        self.target_vocab_projection = nn.Linear(d_model, len(vocab.tgt))

    def forward(self, source: List[List[str]], target: List[List[str]]) -> torch.Tensor:
        """ Take a mini-batch of source and target sentences, compute the log-likelihood of
        target sentences under the language models learned by the NMT system.

        @param source (List[List[str]]): list of source sentence tokens
        @param target (List[List[str]]): list of target sentence tokens, wrapped by `<s>` and `</s>`

        @returns scores (Tensor): a variable/tensor of shape (b, ) representing the
                                    log-likelihood of generating the gold-standard target sentence for
                                    each example in the input batch. Here b = batch size.
        """
        # Convert list of lists into tensors
        source_padded = self.vocab.src.to_input_tensor(source, device=self.device)   # Tensor: (src_len, b)
        target_padded = self.vocab.tgt.to_input_tensor(target, device=self.device)   # Tensor: (tgt_len, b)

        # Compute masking
        src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = self.generate_sent_masks(source_padded, target_padded)

        # Compute embedding
        embedded_src = self.src_embedding(source_padded) 
        embedded_tgt = self.tgt_embedding(target_padded) 

        # 3. Apply the Transformer to compute decoder output
        decoder_output = self.transformer(embedded_src, embedded_tgt, src_mask, tgt_mask)
        P = F.log_softmax(self.target_vocab_projection(decoder_output), dim=-1)

        # Zero out, probabilities for which we have nothing in the target text
        target_masks = (target_padded != self.vocab.tgt['<pad>']).float()
        
        # Compute log probability of generating true target words
        target_gold_words_log_prob = torch.gather(P, index=target_padded.unsqueeze(-1), dim=-1).squeeze(-1) * target_masks
        scores = target_gold_words_log_prob.sum(dim=0)
        return scores
    
    def encode(self, src, src_mask):
        return self.transformer.encoder(self.src_embedding(src), src_mask)
    
    def decode(self, tgt: torch.Tensor, memory: torch.Tensor, tgt_mask: torch.Tensor):
        return self.transformer.decoder(self.tgt_embedding(tgt), memory, tgt_mask)
    
    def generate_sent_masks(self, src_ids, tgt_ids):
        src_seq_len = src_ids.size(0)
        tgt_seq_len = tgt_ids.size(0)

        tgt_mask = self.generate_square_subsequent_mask(tgt_seq_len)
        src_mask = torch.zeros((src_seq_len, src_seq_len), device=self.device).type(torch.bool)

        src_padding_mask = (src_ids == 0).transpose(0, 1)
        tgt_padding_mask = (tgt_ids == 0).transpose(0, 1)
        
        return src_mask.to(self.device), tgt_mask.to(self.device), src_padding_mask.to(self.device), tgt_padding_mask.to(self.device)
    
    def generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones((sz, sz), device=self.device)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask
  
    @property
    def device(self) -> torch.device:
        """ Determine which device to place the Tensors upon, CPU or GPU.
        """
        return self.src_embedding.token_embedding.weight.device

    @staticmethod
    def load(model_path: str):
        """ Load the model from a file.
        @param model_path (str): path to model
        """
        params = torch.load(model_path, map_location=lambda storage, loc: storage)
        args = params['args']
        model = TransformerNMT(vocab=params['vocab'], **args)
        model.load_state_dict(params['state_dict'])

        return model

    def save(self, path: str):
        """ Save the odel to a file.
        @param path (str): path to the model
        """
        print('save model parameters to [%s]' % path, file=sys.stderr)

        params = {
            'args': dict(d_model=self.d_model, n_heads=self.n_heads, ff_size=self.ff_size, n_layers=self.n_layers, max_len=self.max_len, dropout_rate=self.dropout_rate),
            'vocab': self.vocab,
            'state_dict': self.state_dict()
        }

        torch.save(params, path)

# %% [markdown]
# # Train our full model
# Train our Transformer model using training script above and report the results compared with LSTM-Attention model.

# %%
args.n_heads = 8
args.ff_size = 768
args.n_layers = 4
args.d_model = 768
args.lr = 1e-4
args.dropout = 0.1
args.model_save_path = "transformer_model.bin"

# %%
# Initialize our model and optimizer
model = TransformerNMT(d_model=args.d_model, n_heads=args.n_heads, ff_size=args.ff_size, n_layers=args.n_layers, max_len=args.max_len, vocab=vocab, dropout_rate=float(args.dropout))
model.train()

for p in model.parameters():
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=float(args.lr))

# %%
#@title Training the model
num_trial = 0
train_iter = patience = cum_loss = report_loss = cum_tgt_words = report_tgt_words = 0
cum_examples = report_examples = epoch = valid_num = 0
hist_valid_scores = []
train_time = begin_time = time.time()
print('begin Maximum Likelihood training')

for epoch in range(args.max_epoch):
    for src_sents, tgt_sents in batch_iter(train_data, batch_size=args.batch_size, shuffle=True):
        train_iter += 1

        optimizer.zero_grad()

        batch_size = len(src_sents)

        example_losses = -model(src_sents, tgt_sents) # (batch_size,)
        batch_loss = example_losses.sum()
        loss = batch_loss / batch_size

        loss.backward()

        # clip gradient
        grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), args.clip_grad)

        optimizer.step()

        batch_losses_val = batch_loss.item()
        report_loss += batch_losses_val
        cum_loss += batch_losses_val

        tgt_words_num_to_predict = sum(len(s[1:]) for s in tgt_sents)  # omitting leading `<s>`
        report_tgt_words += tgt_words_num_to_predict
        cum_tgt_words += tgt_words_num_to_predict
        report_examples += batch_size
        cum_examples += batch_size

        if train_iter % (args.log_every*10) == 0:
            print('epoch %d, iter %d, avg. loss %.2f, avg. ppl %.2f ' \
                    'cum. examples %d, speed %.2f words/sec, time elapsed %.2f sec' % (epoch, train_iter,
                                                                                        report_loss / report_examples,
                                                                                        math.exp(report_loss / report_tgt_words),
                                                                                        cum_examples,
                                                                                        report_tgt_words / (time.time() - train_time),
                                                                                        time.time() - begin_time), file=sys.stderr)

            train_time = time.time()
            report_loss = report_tgt_words = report_examples = 0.

        # perform validation
        if train_iter % args.valid_niter == 0:
            print('epoch %d, iter %d, cum. loss %.2f, cum. ppl %.2f cum. examples %d' % (epoch, train_iter,
                                                                                        cum_loss / cum_examples,
                                                                                        np.exp(cum_loss / cum_tgt_words),
                                                                                        cum_examples), file=sys.stderr)

            cum_loss = cum_examples = cum_tgt_words = 0.
            valid_num += 1

            print('begin validation ...', file=sys.stderr)

            # compute dev. ppl and bleu
            dev_ppl = evaluate_ppl(model, dev_data, batch_size=128)   # dev batch size can be a bit larger
            valid_metric = -dev_ppl

            print('validation: iter %d, dev. ppl %f' % (train_iter, dev_ppl), file=sys.stderr)

            is_better = len(hist_valid_scores) == 0 or valid_metric > max(hist_valid_scores)
            hist_valid_scores.append(valid_metric)

            if is_better:
                patience = 0
                print('save currently the best model to [%s]' % args.model_save_path, file=sys.stderr)
                model.save(args.model_save_path)

                # also save the optimizers' state
                torch.save(optimizer.state_dict(), args.model_save_path + '.optim')
            elif patience < int(args.patience):
                patience += 1
                print('hit patience %d' % patience, file=sys.stderr)

                if patience == int(args.patience):
                    num_trial += 1
                    print('hit #%d trial' % num_trial, file=sys.stderr)
                    if num_trial == int(args.max_num_trial):
                        print('early stop!', file=sys.stderr)
                        exit(0)

                    # decay lr, and restore from previously best checkpoint
                    lr = optimizer.param_groups[0]['lr'] * float(args.lr_decay)
                    print('load previously best model and decay learning rate to %f' % lr, file=sys.stderr)

                    # load model
                    params = torch.load(args.model_save_path, map_location=lambda storage, loc: storage)
                    model.load_state_dict(params['state_dict'])
                    model = model.to(device)

                    print('restore parameters of the optimizers', file=sys.stderr)
                    optimizer.load_state_dict(torch.load(args.model_save_path + '.optim'))

                    # set new lr
                    for param_group in optimizer.param_groups:
                        param_group['lr'] = lr

                    # reset patience
                    patience = 0
# Out:
# begin Maximum Likelihood training
# epoch 0, iter 100, avg. loss 193.43, avg. ppl 1071.13 cum. examples 3196, speed 4195.73 words/sec, time elapsed 21.12 sec
# epoch 0, iter 200, avg. loss 164.68, avg. ppl 382.94 cum. examples 6392, speed 4567.86 words/sec, time elapsed 40.49 sec
# epoch 0, iter 300, avg. loss 162.75, avg. ppl 309.34 cum. examples 9589, speed 4765.73 words/sec, time elapsed 59.53 sec
# epoch 0, iter 400, avg. loss 144.10, avg. ppl 165.87 cum. examples 12788, speed 4747.91 words/sec, time elapsed 78.53 sec
# epoch 0, iter 500, avg. loss 129.24, avg. ppl 103.98 cum. examples 15988, speed 4685.28 words/sec, time elapsed 97.53 sec
# epoch 0, iter 600, avg. loss 123.36, avg. ppl 78.92 cum. examples 19185, speed 4622.91 words/sec, time elapsed 117.06 sec
# epoch 0, iter 700, avg. loss 110.81, avg. ppl 54.32 cum. examples 22381, speed 4711.07 words/sec, time elapsed 135.88 sec
# epoch 0, iter 800, avg. loss 102.99, avg. ppl 39.34 cum. examples 25578, speed 4944.84 words/sec, time elapsed 154.01 sec
# epoch 0, iter 900, avg. loss 95.78, avg. ppl 31.72 cum. examples 28774, speed 4752.11 words/sec, time elapsed 172.65 sec
# epoch 0, iter 1000, avg. loss 92.24, avg. ppl 27.72 cum. examples 31973, speed 4523.64 words/sec, time elapsed 192.28 sec
# epoch 0, iter 1100, avg. loss 87.98, avg. ppl 24.45 cum. examples 35171, speed 4488.39 words/sec, time elapsed 211.89 sec
# epoch 0, iter 1200, avg. loss 83.71, avg. ppl 20.28 cum. examples 38366, speed 4762.32 words/sec, time elapsed 230.55 sec
# epoch 0, iter 1300, avg. loss 79.91, avg. ppl 18.35 cum. examples 41564, speed 4688.15 words/sec, time elapsed 249.29 sec
# epoch 0, iter 1400, avg. loss 74.98, avg. ppl 15.95 cum. examples 44761, speed 4802.25 words/sec, time elapsed 267.31 sec
# epoch 0, iter 1500, avg. loss 71.67, avg. ppl 14.11 cum. examples 47960, speed 4880.75 words/sec, time elapsed 285.06 sec
# epoch 0, iter 1600, avg. loss 71.28, avg. ppl 12.96 cum. examples 51157, speed 4735.82 words/sec, time elapsed 303.84 sec
# epoch 0, iter 1700, avg. loss 70.78, avg. ppl 12.32 cum. examples 54356, speed 4640.36 words/sec, time elapsed 323.27 sec
# epoch 0, iter 1800, avg. loss 66.85, avg. ppl 11.12 cum. examples 57551, speed 4843.34 words/sec, time elapsed 341.58 sec
# epoch 0, iter 1900, avg. loss 66.05, avg. ppl 10.40 cum. examples 60750, speed 4539.06 words/sec, time elapsed 361.45 sec
# epoch 0, iter 2000, avg. loss 62.42, avg. ppl 9.83 cum. examples 63949, speed 4706.56 words/sec, time elapsed 380.02 sec
# epoch 0, iter 2000, cum. loss 102.75, cum. ppl 40.41 cum. examples 63949
# begin validation ...
# validation: iter 2000, dev. ppl 7.082200
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 0, iter 2100, avg. loss 63.54, avg. ppl 9.37 cum. examples 3197, speed 3767.76 words/sec, time elapsed 404.11 sec
# epoch 0, iter 2200, avg. loss 60.07, avg. ppl 8.52 cum. examples 6395, speed 4607.72 words/sec, time elapsed 423.57 sec
# epoch 0, iter 2300, avg. loss 59.65, avg. ppl 8.30 cum. examples 9590, speed 4655.68 words/sec, time elapsed 442.92 sec
# epoch 0, iter 2400, avg. loss 58.80, avg. ppl 8.07 cum. examples 12788, speed 4537.21 words/sec, time elapsed 462.76 sec
# epoch 0, iter 2500, avg. loss 56.84, avg. ppl 7.65 cum. examples 15987, speed 4554.18 words/sec, time elapsed 482.39 sec
# epoch 0, iter 2600, avg. loss 54.99, avg. ppl 7.16 cum. examples 19183, speed 4545.75 words/sec, time elapsed 502.03 sec
# epoch 0, iter 2700, avg. loss 53.74, avg. ppl 6.88 cum. examples 22381, speed 4588.34 words/sec, time elapsed 521.45 sec
# epoch 0, iter 2800, avg. loss 51.52, avg. ppl 6.52 cum. examples 25578, speed 4545.41 words/sec, time elapsed 540.78 sec
# epoch 0, iter 2900, avg. loss 50.73, avg. ppl 6.52 cum. examples 28773, speed 4449.54 words/sec, time elapsed 560.21 sec
# epoch 0, iter 3000, avg. loss 51.02, avg. ppl 6.25 cum. examples 31969, speed 4598.60 words/sec, time elapsed 579.55 sec
# epoch 0, iter 3100, avg. loss 50.28, avg. ppl 6.03 cum. examples 35164, speed 4822.90 words/sec, time elapsed 598.09 sec
# epoch 0, iter 3200, avg. loss 48.56, avg. ppl 5.72 cum. examples 38363, speed 4809.20 words/sec, time elapsed 616.61 sec
# epoch 0, iter 3300, avg. loss 46.48, avg. ppl 5.40 cum. examples 41560, speed 4948.33 words/sec, time elapsed 634.41 sec
# epoch 0, iter 3400, avg. loss 46.30, avg. ppl 5.29 cum. examples 44759, speed 4832.25 words/sec, time elapsed 652.81 sec
# epoch 0, iter 3500, avg. loss 46.18, avg. ppl 5.17 cum. examples 47957, speed 4599.38 words/sec, time elapsed 672.35 sec
# epoch 0, iter 3600, avg. loss 43.88, avg. ppl 4.95 cum. examples 51157, speed 4813.04 words/sec, time elapsed 690.58 sec
# epoch 0, iter 3700, avg. loss 43.51, avg. ppl 4.88 cum. examples 54353, speed 4820.72 words/sec, time elapsed 708.79 sec
# epoch 0, iter 3800, avg. loss 43.30, avg. ppl 4.71 cum. examples 57550, speed 4835.92 words/sec, time elapsed 727.27 sec
# epoch 0, iter 3900, avg. loss 42.94, avg. ppl 4.62 cum. examples 60746, speed 4744.36 words/sec, time elapsed 746.17 sec
# epoch 0, iter 4000, avg. loss 43.29, avg. ppl 4.63 cum. examples 63945, speed 4438.72 words/sec, time elapsed 766.52 sec
# epoch 0, iter 4000, cum. loss 50.78, cum. ppl 6.19 cum. examples 63945
# begin validation ...
# validation: iter 4000, dev. ppl 3.305092
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 0, iter 4100, avg. loss 41.32, avg. ppl 4.38 cum. examples 3198, speed 3684.06 words/sec, time elapsed 790.81 sec
# epoch 1, iter 4200, avg. loss 40.54, avg. ppl 4.33 cum. examples 6367, speed 4629.03 words/sec, time elapsed 809.74 sec
# epoch 1, iter 4300, avg. loss 39.27, avg. ppl 4.08 cum. examples 9565, speed 4747.44 words/sec, time elapsed 828.57 sec
# epoch 1, iter 4400, avg. loss 38.27, avg. ppl 3.97 cum. examples 12764, speed 4874.62 words/sec, time elapsed 846.79 sec
# epoch 1, iter 4500, avg. loss 37.80, avg. ppl 3.91 cum. examples 15961, speed 4787.12 words/sec, time elapsed 865.31 sec
# epoch 1, iter 4600, avg. loss 37.16, avg. ppl 3.87 cum. examples 19159, speed 4696.40 words/sec, time elapsed 884.01 sec
# epoch 1, iter 4700, avg. loss 36.23, avg. ppl 3.69 cum. examples 22356, speed 4692.54 words/sec, time elapsed 902.91 sec
# epoch 1, iter 4800, avg. loss 37.59, avg. ppl 3.73 cum. examples 25551, speed 4782.79 words/sec, time elapsed 921.99 sec
# epoch 1, iter 4900, avg. loss 34.98, avg. ppl 3.55 cum. examples 28749, speed 4492.28 words/sec, time elapsed 941.66 sec
# epoch 1, iter 5000, avg. loss 33.68, avg. ppl 3.45 cum. examples 31947, speed 4991.47 words/sec, time elapsed 959.10 sec
# epoch 1, iter 5100, avg. loss 34.88, avg. ppl 3.50 cum. examples 35146, speed 4692.35 words/sec, time elapsed 978.07 sec
# epoch 1, iter 5200, avg. loss 33.54, avg. ppl 3.36 cum. examples 38345, speed 4654.32 words/sec, time elapsed 997.08 sec
# epoch 1, iter 5300, avg. loss 32.78, avg. ppl 3.21 cum. examples 41543, speed 4884.97 words/sec, time elapsed 1015.46 sec
# epoch 1, iter 5400, avg. loss 32.46, avg. ppl 3.20 cum. examples 44742, speed 4689.84 words/sec, time elapsed 1034.52 sec
# epoch 1, iter 5500, avg. loss 32.07, avg. ppl 3.15 cum. examples 47937, speed 4628.35 words/sec, time elapsed 1053.80 sec
# epoch 1, iter 5600, avg. loss 31.94, avg. ppl 3.13 cum. examples 51134, speed 4387.33 words/sec, time elapsed 1074.19 sec
# epoch 1, iter 5700, avg. loss 30.79, avg. ppl 3.02 cum. examples 54330, speed 4658.41 words/sec, time elapsed 1093.32 sec
# epoch 1, iter 5800, avg. loss 30.48, avg. ppl 2.98 cum. examples 57528, speed 4606.52 words/sec, time elapsed 1112.69 sec
# epoch 1, iter 5900, avg. loss 30.35, avg. ppl 2.98 cum. examples 60727, speed 4727.67 words/sec, time elapsed 1131.51 sec
# epoch 1, iter 6000, avg. loss 29.40, avg. ppl 2.85 cum. examples 63924, speed 4723.70 words/sec, time elapsed 1150.50 sec
# epoch 1, iter 6000, cum. loss 34.77, cum. ppl 3.49 cum. examples 63924
# begin validation ...
# validation: iter 6000, dev. ppl 2.208566
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 1, iter 6100, avg. loss 28.23, avg. ppl 2.75 cum. examples 3198, speed 3649.56 words/sec, time elapsed 1174.98 sec
# epoch 1, iter 6200, avg. loss 27.80, avg. ppl 2.72 cum. examples 6395, speed 4731.65 words/sec, time elapsed 1193.77 sec
# epoch 1, iter 6300, avg. loss 29.48, avg. ppl 2.79 cum. examples 9593, speed 4597.64 words/sec, time elapsed 1213.74 sec
# epoch 1, iter 6400, avg. loss 27.30, avg. ppl 2.69 cum. examples 12790, speed 4452.67 words/sec, time elapsed 1233.56 sec
# epoch 1, iter 6500, avg. loss 26.80, avg. ppl 2.65 cum. examples 15987, speed 4653.16 words/sec, time elapsed 1252.46 sec
# epoch 1, iter 6600, avg. loss 26.34, avg. ppl 2.60 cum. examples 19185, speed 4761.70 words/sec, time elapsed 1270.98 sec
# epoch 1, iter 6700, avg. loss 25.52, avg. ppl 2.55 cum. examples 22381, speed 4776.09 words/sec, time elapsed 1289.26 sec
# epoch 1, iter 6800, avg. loss 25.49, avg. ppl 2.50 cum. examples 25580, speed 4672.27 words/sec, time elapsed 1308.27 sec
# epoch 1, iter 6900, avg. loss 24.40, avg. ppl 2.42 cum. examples 28779, speed 4919.08 words/sec, time elapsed 1326.26 sec
# epoch 1, iter 7000, avg. loss 24.59, avg. ppl 2.39 cum. examples 31977, speed 4788.50 words/sec, time elapsed 1345.11 sec
# epoch 1, iter 7100, avg. loss 24.28, avg. ppl 2.40 cum. examples 35173, speed 4763.26 words/sec, time elapsed 1363.71 sec
# epoch 1, iter 7200, avg. loss 23.70, avg. ppl 2.34 cum. examples 38366, speed 4712.12 words/sec, time elapsed 1382.57 sec
# epoch 1, iter 7300, avg. loss 24.12, avg. ppl 2.34 cum. examples 41564, speed 4582.84 words/sec, time elapsed 1402.39 sec
# epoch 1, iter 7400, avg. loss 23.04, avg. ppl 2.29 cum. examples 44759, speed 4601.55 words/sec, time elapsed 1421.69 sec
# epoch 1, iter 7500, avg. loss 23.58, avg. ppl 2.32 cum. examples 47955, speed 4548.63 words/sec, time elapsed 1441.38 sec
# epoch 1, iter 7600, avg. loss 21.65, avg. ppl 2.18 cum. examples 51153, speed 4640.84 words/sec, time elapsed 1460.57 sec
# epoch 1, iter 7700, avg. loss 22.58, avg. ppl 2.25 cum. examples 54349, speed 4477.20 words/sec, time elapsed 1480.50 sec
# epoch 1, iter 7800, avg. loss 21.26, avg. ppl 2.15 cum. examples 57546, speed 4661.29 words/sec, time elapsed 1499.49 sec
# epoch 1, iter 7900, avg. loss 21.64, avg. ppl 2.17 cum. examples 60742, speed 4566.99 words/sec, time elapsed 1519.06 sec
# epoch 1, iter 8000, avg. loss 20.65, avg. ppl 2.10 cum. examples 63940, speed 5047.92 words/sec, time elapsed 1536.71 sec
# epoch 1, iter 8000, cum. loss 24.62, cum. ppl 2.42 cum. examples 63940
# begin validation ...
# validation: iter 8000, dev. ppl 1.703945
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 1, iter 8100, avg. loss 20.04, avg. ppl 2.07 cum. examples 3199, speed 3801.41 words/sec, time elapsed 1559.94 sec
# epoch 1, iter 8200, avg. loss 20.15, avg. ppl 2.07 cum. examples 6396, speed 4533.60 words/sec, time elapsed 1579.53 sec
# epoch 1, iter 8300, avg. loss 19.95, avg. ppl 2.06 cum. examples 9593, speed 4576.95 words/sec, time elapsed 1598.75 sec
# epoch 2, iter 8400, avg. loss 18.61, avg. ppl 1.95 cum. examples 12761, speed 4826.57 words/sec, time elapsed 1616.99 sec
# epoch 2, iter 8500, avg. loss 18.07, avg. ppl 1.92 cum. examples 15956, speed 4899.80 words/sec, time elapsed 1635.03 sec
# epoch 2, iter 8600, avg. loss 17.71, avg. ppl 1.92 cum. examples 19155, speed 4635.31 words/sec, time elapsed 1653.71 sec
# epoch 2, iter 8700, avg. loss 18.03, avg. ppl 1.92 cum. examples 22350, speed 4608.76 words/sec, time elapsed 1672.81 sec
# epoch 2, iter 8800, avg. loss 17.67, avg. ppl 1.91 cum. examples 25545, speed 4771.81 words/sec, time elapsed 1691.16 sec
# epoch 2, iter 8900, avg. loss 18.43, avg. ppl 1.92 cum. examples 28743, speed 4548.02 words/sec, time elapsed 1710.97 sec
# epoch 2, iter 9000, avg. loss 16.89, avg. ppl 1.84 cum. examples 31943, speed 4766.35 words/sec, time elapsed 1729.63 sec
# epoch 2, iter 9100, avg. loss 17.18, avg. ppl 1.86 cum. examples 35143, speed 4861.48 words/sec, time elapsed 1747.88 sec
# epoch 2, iter 9200, avg. loss 16.68, avg. ppl 1.84 cum. examples 38338, speed 4721.20 words/sec, time elapsed 1766.38 sec
# epoch 2, iter 9300, avg. loss 16.03, avg. ppl 1.77 cum. examples 41537, speed 4753.86 words/sec, time elapsed 1785.19 sec
# epoch 2, iter 9400, avg. loss 16.20, avg. ppl 1.81 cum. examples 44735, speed 4854.95 words/sec, time elapsed 1803.23 sec
# epoch 2, iter 9500, avg. loss 15.54, avg. ppl 1.75 cum. examples 47931, speed 4661.83 words/sec, time elapsed 1822.28 sec
# epoch 2, iter 9600, avg. loss 16.07, avg. ppl 1.77 cum. examples 51128, speed 4953.39 words/sec, time elapsed 1840.37 sec
# epoch 2, iter 9700, avg. loss 22.41, avg. ppl 2.23 cum. examples 54324, speed 4598.33 words/sec, time elapsed 1859.85 sec
# epoch 2, iter 9800, avg. loss 16.44, avg. ppl 1.79 cum. examples 57521, speed 4667.38 words/sec, time elapsed 1879.23 sec
# epoch 2, iter 9900, avg. loss 15.32, avg. ppl 1.72 cum. examples 60718, speed 4625.49 words/sec, time elapsed 1898.80 sec
# epoch 2, iter 10000, avg. loss 15.03, avg. ppl 1.72 cum. examples 63915, speed 4659.10 words/sec, time elapsed 1917.89 sec
# epoch 2, iter 10000, cum. loss 17.62, cum. ppl 1.89 cum. examples 63915
# begin validation ...
# validation: iter 10000, dev. ppl 1.484711
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 2, iter 10100, avg. loss 15.74, avg. ppl 1.74 cum. examples 3196, speed 3559.59 words/sec, time elapsed 1943.27 sec
# epoch 2, iter 10200, avg. loss 14.36, avg. ppl 1.68 cum. examples 6394, speed 4724.74 words/sec, time elapsed 1962.00 sec
# epoch 2, iter 10300, avg. loss 14.66, avg. ppl 1.69 cum. examples 9591, speed 4849.16 words/sec, time elapsed 1980.49 sec
# epoch 2, iter 10400, avg. loss 14.31, avg. ppl 1.68 cum. examples 12785, speed 4845.81 words/sec, time elapsed 1998.75 sec
# epoch 2, iter 10500, avg. loss 13.90, avg. ppl 1.66 cum. examples 15982, speed 4700.21 words/sec, time elapsed 2017.42 sec
# epoch 2, iter 10600, avg. loss 14.42, avg. ppl 1.68 cum. examples 19178, speed 4649.27 words/sec, time elapsed 2036.43 sec
# epoch 2, iter 10700, avg. loss 14.58, avg. ppl 1.69 cum. examples 22375, speed 4399.06 words/sec, time elapsed 2056.72 sec
# epoch 2, iter 10800, avg. loss 13.28, avg. ppl 1.63 cum. examples 25572, speed 4646.71 words/sec, time elapsed 2075.50 sec
# epoch 2, iter 10900, avg. loss 14.00, avg. ppl 1.65 cum. examples 28771, speed 4613.36 words/sec, time elapsed 2094.91 sec
# epoch 2, iter 11000, avg. loss 13.16, avg. ppl 1.60 cum. examples 31971, speed 4769.82 words/sec, time elapsed 2113.66 sec
# epoch 2, iter 11100, avg. loss 13.08, avg. ppl 1.59 cum. examples 35170, speed 4758.72 words/sec, time elapsed 2132.68 sec
# epoch 2, iter 11200, avg. loss 13.48, avg. ppl 1.62 cum. examples 38370, speed 4640.88 words/sec, time elapsed 2152.05 sec
# epoch 2, iter 11300, avg. loss 12.78, avg. ppl 1.59 cum. examples 41566, speed 4758.48 words/sec, time elapsed 2170.66 sec
# epoch 2, iter 11400, avg. loss 12.61, avg. ppl 1.57 cum. examples 44763, speed 4621.12 words/sec, time elapsed 2190.02 sec
# epoch 2, iter 11500, avg. loss 12.67, avg. ppl 1.59 cum. examples 47961, speed 4555.26 words/sec, time elapsed 2209.28 sec
# epoch 2, iter 11600, avg. loss 12.29, avg. ppl 1.55 cum. examples 51160, speed 4806.55 words/sec, time elapsed 2227.97 sec
# epoch 2, iter 11700, avg. loss 12.49, avg. ppl 1.58 cum. examples 54355, speed 4630.48 words/sec, time elapsed 2246.89 sec
# epoch 2, iter 11800, avg. loss 11.58, avg. ppl 1.52 cum. examples 57554, speed 4823.96 words/sec, time elapsed 2265.22 sec
# epoch 2, iter 11900, avg. loss 11.82, avg. ppl 1.54 cum. examples 60751, speed 4627.44 words/sec, time elapsed 2284.04 sec
# epoch 2, iter 12000, avg. loss 11.41, avg. ppl 1.51 cum. examples 63951, speed 4777.68 words/sec, time elapsed 2302.60 sec
# epoch 2, iter 12000, cum. loss 13.33, cum. ppl 1.62 cum. examples 63951
# begin validation ...
# validation: iter 12000, dev. ppl 1.354862
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 2, iter 12100, avg. loss 11.48, avg. ppl 1.51 cum. examples 3195, speed 3809.70 words/sec, time elapsed 2326.15 sec
# epoch 2, iter 12200, avg. loss 11.66, avg. ppl 1.51 cum. examples 6393, speed 4865.06 words/sec, time elapsed 2344.63 sec
# epoch 2, iter 12300, avg. loss 11.35, avg. ppl 1.51 cum. examples 9590, speed 4612.07 words/sec, time elapsed 2363.72 sec
# epoch 2, iter 12400, avg. loss 11.40, avg. ppl 1.49 cum. examples 12788, speed 4590.16 words/sec, time elapsed 2383.61 sec
# epoch 2, iter 12500, avg. loss 11.32, avg. ppl 1.49 cum. examples 15986, speed 4709.74 words/sec, time elapsed 2402.80 sec
# epoch 3, iter 12600, avg. loss 10.70, avg. ppl 1.46 cum. examples 19156, speed 4556.27 words/sec, time elapsed 2422.52 sec
# epoch 3, iter 12700, avg. loss 10.85, avg. ppl 1.47 cum. examples 22354, speed 4643.32 words/sec, time elapsed 2441.76 sec
# epoch 3, iter 12800, avg. loss 10.14, avg. ppl 1.43 cum. examples 25549, speed 4572.53 words/sec, time elapsed 2461.38 sec
# epoch 3, iter 12900, avg. loss 10.00, avg. ppl 1.43 cum. examples 28747, speed 4706.05 words/sec, time elapsed 2480.31 sec
# epoch 3, iter 13000, avg. loss 10.17, avg. ppl 1.44 cum. examples 31941, speed 4697.52 words/sec, time elapsed 2499.36 sec
# epoch 3, iter 13100, avg. loss 9.69, avg. ppl 1.42 cum. examples 35139, speed 4807.41 words/sec, time elapsed 2517.89 sec
# epoch 3, iter 13200, avg. loss 9.80, avg. ppl 1.43 cum. examples 38338, speed 4773.84 words/sec, time elapsed 2536.27 sec
# epoch 3, iter 13300, avg. loss 9.91, avg. ppl 1.42 cum. examples 41536, speed 4661.83 words/sec, time elapsed 2555.52 sec
# epoch 3, iter 13400, avg. loss 9.62, avg. ppl 1.41 cum. examples 44734, speed 4666.33 words/sec, time elapsed 2574.60 sec
# epoch 3, iter 13500, avg. loss 9.64, avg. ppl 1.42 cum. examples 47930, speed 4523.37 words/sec, time elapsed 2594.19 sec
# epoch 3, iter 13600, avg. loss 9.34, avg. ppl 1.40 cum. examples 51129, speed 4776.12 words/sec, time elapsed 2612.71 sec
# epoch 3, iter 13700, avg. loss 9.34, avg. ppl 1.40 cum. examples 54328, speed 4623.34 words/sec, time elapsed 2632.01 sec
# epoch 3, iter 13800, avg. loss 8.88, avg. ppl 1.38 cum. examples 57526, speed 4819.01 words/sec, time elapsed 2650.17 sec
# epoch 3, iter 13900, avg. loss 9.71, avg. ppl 1.41 cum. examples 60725, speed 4403.76 words/sec, time elapsed 2670.69 sec
# epoch 3, iter 14000, avg. loss 8.46, avg. ppl 1.36 cum. examples 63921, speed 4903.59 words/sec, time elapsed 2688.69 sec
# epoch 3, iter 14000, cum. loss 10.17, cum. ppl 1.44 cum. examples 63921
# begin validation ...
# validation: iter 14000, dev. ppl 1.270891
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 3, iter 14100, avg. loss 9.05, avg. ppl 1.38 cum. examples 3196, speed 3697.84 words/sec, time elapsed 2712.76 sec
# epoch 3, iter 14200, avg. loss 8.28, avg. ppl 1.35 cum. examples 6393, speed 4840.95 words/sec, time elapsed 2730.96 sec
# epoch 3, iter 14300, avg. loss 8.83, avg. ppl 1.37 cum. examples 9587, speed 4666.59 words/sec, time elapsed 2750.11 sec
# epoch 3, iter 14400, avg. loss 8.72, avg. ppl 1.37 cum. examples 12783, speed 4845.30 words/sec, time elapsed 2768.52 sec
# epoch 3, iter 14500, avg. loss 8.25, avg. ppl 1.35 cum. examples 15981, speed 4762.58 words/sec, time elapsed 2787.07 sec
# epoch 3, iter 14600, avg. loss 9.10, avg. ppl 1.38 cum. examples 19180, speed 4654.37 words/sec, time elapsed 2806.51 sec
# epoch 3, iter 14700, avg. loss 8.96, avg. ppl 1.38 cum. examples 22378, speed 4364.56 words/sec, time elapsed 2827.01 sec
# epoch 3, iter 14800, avg. loss 8.09, avg. ppl 1.34 cum. examples 25575, speed 4761.14 words/sec, time elapsed 2845.79 sec
# epoch 3, iter 14900, avg. loss 7.91, avg. ppl 1.34 cum. examples 28772, speed 4769.21 words/sec, time elapsed 2864.12 sec
# epoch 3, iter 15000, avg. loss 8.15, avg. ppl 1.34 cum. examples 31970, speed 4900.81 words/sec, time elapsed 2882.34 sec
# epoch 3, iter 15100, avg. loss 7.99, avg. ppl 1.33 cum. examples 35167, speed 4874.23 words/sec, time elapsed 2900.73 sec
# epoch 3, iter 15200, avg. loss 7.45, avg. ppl 1.32 cum. examples 38364, speed 4605.80 words/sec, time elapsed 2919.60 sec
# epoch 3, iter 15300, avg. loss 7.94, avg. ppl 1.33 cum. examples 41558, speed 4790.60 words/sec, time elapsed 2938.25 sec
# epoch 3, iter 15400, avg. loss 8.21, avg. ppl 1.34 cum. examples 44756, speed 4613.27 words/sec, time elapsed 2957.69 sec
# epoch 3, iter 15500, avg. loss 7.69, avg. ppl 1.32 cum. examples 47954, speed 4645.22 words/sec, time elapsed 2976.58 sec
# epoch 3, iter 15600, avg. loss 7.12, avg. ppl 1.29 cum. examples 51153, speed 4772.91 words/sec, time elapsed 2995.05 sec
# epoch 3, iter 15700, avg. loss 7.48, avg. ppl 1.31 cum. examples 54350, speed 4726.92 words/sec, time elapsed 3013.95 sec
# epoch 3, iter 15800, avg. loss 7.32, avg. ppl 1.30 cum. examples 57547, speed 4771.75 words/sec, time elapsed 3032.54 sec
# epoch 3, iter 15900, avg. loss 7.43, avg. ppl 1.31 cum. examples 60744, speed 4648.33 words/sec, time elapsed 3051.61 sec
# epoch 3, iter 16000, avg. loss 7.08, avg. ppl 1.29 cum. examples 63940, speed 4785.83 words/sec, time elapsed 3070.02 sec
# epoch 3, iter 16000, cum. loss 8.05, cum. ppl 1.34 cum. examples 63940
# begin validation ...
# validation: iter 16000, dev. ppl 1.211088
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 3, iter 16100, avg. loss 7.39, avg. ppl 1.31 cum. examples 3198, speed 3663.28 words/sec, time elapsed 3094.26 sec
# epoch 3, iter 16200, avg. loss 7.56, avg. ppl 1.30 cum. examples 6395, speed 4628.88 words/sec, time elapsed 3113.92 sec
# epoch 3, iter 16300, avg. loss 7.29, avg. ppl 1.30 cum. examples 9594, speed 4543.58 words/sec, time elapsed 3133.56 sec
# epoch 3, iter 16400, avg. loss 6.79, avg. ppl 1.28 cum. examples 12791, speed 4836.08 words/sec, time elapsed 3151.93 sec
# epoch 3, iter 16500, avg. loss 7.11, avg. ppl 1.30 cum. examples 15989, speed 4423.09 words/sec, time elapsed 3171.75 sec
# epoch 3, iter 16600, avg. loss 7.10, avg. ppl 1.29 cum. examples 19188, speed 4684.12 words/sec, time elapsed 3190.98 sec
# epoch 4, iter 16700, avg. loss 6.74, avg. ppl 1.28 cum. examples 22358, speed 4785.65 words/sec, time elapsed 3209.03 sec
# epoch 4, iter 16800, avg. loss 5.72, avg. ppl 1.23 cum. examples 25555, speed 4912.98 words/sec, time elapsed 3227.13 sec
# epoch 4, iter 16900, avg. loss 6.45, avg. ppl 1.26 cum. examples 28754, speed 4495.31 words/sec, time elapsed 3247.34 sec
# epoch 4, iter 17000, avg. loss 6.17, avg. ppl 1.24 cum. examples 31954, speed 4664.25 words/sec, time elapsed 3266.75 sec
# epoch 4, iter 17100, avg. loss 6.30, avg. ppl 1.25 cum. examples 35151, speed 4890.16 words/sec, time elapsed 3285.04 sec
# epoch 4, iter 17200, avg. loss 5.92, avg. ppl 1.24 cum. examples 38348, speed 4691.92 words/sec, time elapsed 3304.00 sec
# epoch 4, iter 17300, avg. loss 6.20, avg. ppl 1.25 cum. examples 41545, speed 4602.69 words/sec, time elapsed 3323.44 sec
# epoch 4, iter 17400, avg. loss 5.58, avg. ppl 1.22 cum. examples 44744, speed 4830.63 words/sec, time elapsed 3341.69 sec
# epoch 4, iter 17500, avg. loss 6.02, avg. ppl 1.24 cum. examples 47940, speed 4498.68 words/sec, time elapsed 3361.82 sec
# epoch 4, iter 17600, avg. loss 5.85, avg. ppl 1.24 cum. examples 51136, speed 4456.27 words/sec, time elapsed 3381.65 sec
# epoch 4, iter 17700, avg. loss 6.09, avg. ppl 1.24 cum. examples 54333, speed 4632.69 words/sec, time elapsed 3401.07 sec
# epoch 4, iter 17800, avg. loss 5.29, avg. ppl 1.22 cum. examples 57531, speed 4827.35 words/sec, time elapsed 3418.89 sec
# epoch 4, iter 17900, avg. loss 5.50, avg. ppl 1.22 cum. examples 60730, speed 4704.48 words/sec, time elapsed 3437.48 sec
# epoch 4, iter 18000, avg. loss 5.77, avg. ppl 1.23 cum. examples 63926, speed 4612.17 words/sec, time elapsed 3457.05 sec
# epoch 4, iter 18000, cum. loss 6.34, cum. ppl 1.26 cum. examples 63926
# begin validation ...
# validation: iter 18000, dev. ppl 1.176355
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 4, iter 18100, avg. loss 5.84, avg. ppl 1.23 cum. examples 3194, speed 3691.75 words/sec, time elapsed 3481.05 sec
# epoch 4, iter 18200, avg. loss 5.62, avg. ppl 1.22 cum. examples 6393, speed 4550.55 words/sec, time elapsed 3500.75 sec
# epoch 4, iter 18300, avg. loss 5.54, avg. ppl 1.22 cum. examples 9586, speed 4722.60 words/sec, time elapsed 3519.49 sec
# epoch 4, iter 18400, avg. loss 5.51, avg. ppl 1.22 cum. examples 12784, speed 4756.09 words/sec, time elapsed 3538.15 sec
# epoch 4, iter 18500, avg. loss 5.32, avg. ppl 1.21 cum. examples 15982, speed 4768.48 words/sec, time elapsed 3556.96 sec
# epoch 4, iter 18600, avg. loss 5.19, avg. ppl 1.21 cum. examples 19177, speed 4839.95 words/sec, time elapsed 3575.13 sec
# epoch 4, iter 18700, avg. loss 5.43, avg. ppl 1.22 cum. examples 22367, speed 4707.03 words/sec, time elapsed 3593.95 sec
# epoch 4, iter 18800, avg. loss 5.58, avg. ppl 1.22 cum. examples 25566, speed 4441.83 words/sec, time elapsed 3613.90 sec
# epoch 4, iter 18900, avg. loss 5.00, avg. ppl 1.19 cum. examples 28766, speed 4779.46 words/sec, time elapsed 3632.70 sec
# epoch 4, iter 19000, avg. loss 5.28, avg. ppl 1.21 cum. examples 31965, speed 4579.94 words/sec, time elapsed 3652.09 sec
# epoch 4, iter 19100, avg. loss 5.11, avg. ppl 1.20 cum. examples 35162, speed 4430.80 words/sec, time elapsed 3672.18 sec
# epoch 4, iter 19200, avg. loss 5.09, avg. ppl 1.20 cum. examples 38359, speed 4712.75 words/sec, time elapsed 3691.32 sec
# epoch 4, iter 19300, avg. loss 5.10, avg. ppl 1.20 cum. examples 41559, speed 4653.74 words/sec, time elapsed 3710.60 sec
# epoch 4, iter 19400, avg. loss 4.86, avg. ppl 1.19 cum. examples 44756, speed 4617.71 words/sec, time elapsed 3730.17 sec
# epoch 4, iter 19500, avg. loss 4.98, avg. ppl 1.20 cum. examples 47953, speed 4448.80 words/sec, time elapsed 3750.13 sec
# epoch 4, iter 19600, avg. loss 5.09, avg. ppl 1.20 cum. examples 51150, speed 4575.37 words/sec, time elapsed 3769.91 sec
# epoch 4, iter 19700, avg. loss 4.63, avg. ppl 1.18 cum. examples 54346, speed 4920.88 words/sec, time elapsed 3788.03 sec
# epoch 4, iter 19800, avg. loss 5.11, avg. ppl 1.20 cum. examples 57544, speed 4742.31 words/sec, time elapsed 3806.70 sec
# epoch 4, iter 19900, avg. loss 5.00, avg. ppl 1.19 cum. examples 60742, speed 4670.18 words/sec, time elapsed 3825.94 sec
# epoch 4, iter 20000, avg. loss 4.65, avg. ppl 1.18 cum. examples 63939, speed 4785.96 words/sec, time elapsed 3844.42 sec
# epoch 4, iter 20000, cum. loss 5.20, cum. ppl 1.20 cum. examples 63939
# begin validation ...
# validation: iter 20000, dev. ppl 1.142136
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 4, iter 20100, avg. loss 4.69, avg. ppl 1.18 cum. examples 3198, speed 3712.91 words/sec, time elapsed 3868.38 sec
# epoch 4, iter 20200, avg. loss 4.80, avg. ppl 1.19 cum. examples 6397, speed 4692.57 words/sec, time elapsed 3887.59 sec
# epoch 4, iter 20300, avg. loss 4.68, avg. ppl 1.19 cum. examples 9595, speed 4813.45 words/sec, time elapsed 3905.74 sec
# epoch 4, iter 20400, avg. loss 4.25, avg. ppl 1.17 cum. examples 12793, speed 5013.81 words/sec, time elapsed 3923.02 sec
# epoch 4, iter 20500, avg. loss 4.68, avg. ppl 1.18 cum. examples 15992, speed 4649.32 words/sec, time elapsed 3942.31 sec
# epoch 4, iter 20600, avg. loss 4.28, avg. ppl 1.17 cum. examples 19188, speed 4580.27 words/sec, time elapsed 3961.35 sec
# epoch 4, iter 20700, avg. loss 4.68, avg. ppl 1.19 cum. examples 22385, speed 4550.10 words/sec, time elapsed 3980.70 sec
# epoch 4, iter 20800, avg. loss 4.47, avg. ppl 1.17 cum. examples 25583, speed 4757.38 words/sec, time elapsed 3999.44 sec
# epoch 5, iter 20900, avg. loss 3.93, avg. ppl 1.16 cum. examples 28753, speed 4634.78 words/sec, time elapsed 4018.11 sec
# epoch 5, iter 21000, avg. loss 3.80, avg. ppl 1.15 cum. examples 31947, speed 4635.19 words/sec, time elapsed 4037.21 sec
# epoch 5, iter 21100, avg. loss 3.75, avg. ppl 1.14 cum. examples 35143, speed 4800.86 words/sec, time elapsed 4055.92 sec
# epoch 5, iter 21200, avg. loss 4.13, avg. ppl 1.15 cum. examples 38341, speed 4535.12 words/sec, time elapsed 4076.32 sec
# epoch 5, iter 21300, avg. loss 3.84, avg. ppl 1.15 cum. examples 41536, speed 4791.73 words/sec, time elapsed 4094.61 sec
# epoch 5, iter 21400, avg. loss 3.59, avg. ppl 1.14 cum. examples 44735, speed 4768.67 words/sec, time elapsed 4113.10 sec
# epoch 5, iter 21500, avg. loss 3.78, avg. ppl 1.15 cum. examples 47934, speed 4650.26 words/sec, time elapsed 4132.22 sec
# epoch 5, iter 21600, avg. loss 3.76, avg. ppl 1.14 cum. examples 51131, speed 4671.57 words/sec, time elapsed 4151.70 sec
# epoch 5, iter 21700, avg. loss 3.64, avg. ppl 1.14 cum. examples 54329, speed 4511.11 words/sec, time elapsed 4171.25 sec
# epoch 5, iter 21800, avg. loss 3.81, avg. ppl 1.14 cum. examples 57528, speed 4406.94 words/sec, time elapsed 4191.70 sec
# epoch 5, iter 21900, avg. loss 3.60, avg. ppl 1.14 cum. examples 60725, speed 4715.06 words/sec, time elapsed 4210.45 sec
# epoch 5, iter 22000, avg. loss 3.61, avg. ppl 1.14 cum. examples 63922, speed 4526.98 words/sec, time elapsed 4230.23 sec
# epoch 5, iter 22000, cum. loss 4.09, cum. ppl 1.16 cum. examples 63922
# begin validation ...
# validation: iter 22000, dev. ppl 1.114980
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 5, iter 22100, avg. loss 3.48, avg. ppl 1.13 cum. examples 3196, speed 3868.46 words/sec, time elapsed 4253.24 sec
# epoch 5, iter 22200, avg. loss 3.45, avg. ppl 1.13 cum. examples 6393, speed 4766.53 words/sec, time elapsed 4271.59 sec
# epoch 5, iter 22300, avg. loss 3.54, avg. ppl 1.14 cum. examples 9590, speed 4718.03 words/sec, time elapsed 4290.31 sec
# epoch 5, iter 22400, avg. loss 3.61, avg. ppl 1.13 cum. examples 12790, speed 4730.52 words/sec, time elapsed 4309.58 sec
# epoch 5, iter 22500, avg. loss 3.54, avg. ppl 1.14 cum. examples 15990, speed 4627.30 words/sec, time elapsed 4328.69 sec
# epoch 5, iter 22600, avg. loss 3.53, avg. ppl 1.13 cum. examples 19186, speed 4640.56 words/sec, time elapsed 4348.01 sec
# epoch 5, iter 22700, avg. loss 3.34, avg. ppl 1.13 cum. examples 22385, speed 4617.32 words/sec, time elapsed 4367.08 sec
# epoch 5, iter 22800, avg. loss 3.26, avg. ppl 1.13 cum. examples 25583, speed 4639.61 words/sec, time elapsed 4386.03 sec
# epoch 5, iter 22900, avg. loss 3.50, avg. ppl 1.13 cum. examples 28782, speed 4414.18 words/sec, time elapsed 4406.41 sec
# epoch 5, iter 23000, avg. loss 3.52, avg. ppl 1.13 cum. examples 31976, speed 4610.82 words/sec, time elapsed 4425.77 sec
# epoch 5, iter 23100, avg. loss 3.30, avg. ppl 1.13 cum. examples 35172, speed 4743.44 words/sec, time elapsed 4444.38 sec
# epoch 5, iter 23200, avg. loss 3.18, avg. ppl 1.12 cum. examples 38372, speed 4856.55 words/sec, time elapsed 4462.51 sec
# epoch 5, iter 23300, avg. loss 3.63, avg. ppl 1.14 cum. examples 41572, speed 4382.33 words/sec, time elapsed 4482.86 sec
# epoch 5, iter 23400, avg. loss 3.30, avg. ppl 1.13 cum. examples 44770, speed 4783.27 words/sec, time elapsed 4501.38 sec
# epoch 5, iter 23500, avg. loss 3.56, avg. ppl 1.13 cum. examples 47968, speed 4834.63 words/sec, time elapsed 4520.01 sec
# epoch 5, iter 23600, avg. loss 3.12, avg. ppl 1.12 cum. examples 51164, speed 4601.60 words/sec, time elapsed 4539.10 sec
# epoch 5, iter 23700, avg. loss 3.14, avg. ppl 1.12 cum. examples 54363, speed 4687.72 words/sec, time elapsed 4557.84 sec
# epoch 5, iter 23800, avg. loss 3.10, avg. ppl 1.12 cum. examples 57559, speed 4898.38 words/sec, time elapsed 4575.89 sec
# epoch 5, iter 23900, avg. loss 3.14, avg. ppl 1.12 cum. examples 60755, speed 4803.39 words/sec, time elapsed 4594.21 sec
# epoch 5, iter 24000, avg. loss 3.15, avg. ppl 1.12 cum. examples 63949, speed 4841.13 words/sec, time elapsed 4612.87 sec
# epoch 5, iter 24000, cum. loss 3.37, cum. ppl 1.13 cum. examples 63949
# begin validation ...
# validation: iter 24000, dev. ppl 1.101807
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 5, iter 24100, avg. loss 3.10, avg. ppl 1.12 cum. examples 3198, speed 3730.14 words/sec, time elapsed 4636.75 sec
# epoch 5, iter 24200, avg. loss 3.19, avg. ppl 1.12 cum. examples 6392, speed 4555.50 words/sec, time elapsed 4656.26 sec
# epoch 5, iter 24300, avg. loss 3.18, avg. ppl 1.12 cum. examples 9587, speed 4634.87 words/sec, time elapsed 4675.58 sec
# epoch 5, iter 24400, avg. loss 3.06, avg. ppl 1.12 cum. examples 12786, speed 4594.65 words/sec, time elapsed 4695.06 sec
# epoch 5, iter 24500, avg. loss 3.14, avg. ppl 1.12 cum. examples 15984, speed 4537.51 words/sec, time elapsed 4714.74 sec
# epoch 5, iter 24600, avg. loss 3.03, avg. ppl 1.12 cum. examples 19183, speed 4529.00 words/sec, time elapsed 4733.97 sec
# epoch 5, iter 24700, avg. loss 3.02, avg. ppl 1.12 cum. examples 22382, speed 4707.29 words/sec, time elapsed 4752.64 sec
# epoch 5, iter 24800, avg. loss 3.09, avg. ppl 1.12 cum. examples 25579, speed 4542.62 words/sec, time elapsed 4772.11 sec
# epoch 5, iter 24900, avg. loss 3.08, avg. ppl 1.12 cum. examples 28778, speed 4609.41 words/sec, time elapsed 4791.45 sec
# epoch 5, iter 25000, avg. loss 2.82, avg. ppl 1.11 cum. examples 31972, speed 4683.43 words/sec, time elapsed 4810.66 sec
# epoch 6, iter 25100, avg. loss 2.38, avg. ppl 1.09 cum. examples 35144, speed 4827.71 words/sec, time elapsed 4828.83 sec
# epoch 6, iter 25200, avg. loss 2.42, avg. ppl 1.09 cum. examples 38340, speed 4660.99 words/sec, time elapsed 4848.11 sec
# epoch 6, iter 25300, avg. loss 2.44, avg. ppl 1.09 cum. examples 41540, speed 4604.85 words/sec, time elapsed 4867.15 sec
# epoch 6, iter 25400, avg. loss 2.35, avg. ppl 1.09 cum. examples 44739, speed 4747.60 words/sec, time elapsed 4885.97 sec
# epoch 6, iter 25500, avg. loss 2.27, avg. ppl 1.09 cum. examples 47935, speed 4836.73 words/sec, time elapsed 4903.75 sec
# epoch 6, iter 25600, avg. loss 2.22, avg. ppl 1.08 cum. examples 51129, speed 4588.79 words/sec, time elapsed 4923.05 sec
# epoch 6, iter 25700, avg. loss 2.35, avg. ppl 1.09 cum. examples 54326, speed 4804.88 words/sec, time elapsed 4941.69 sec
# epoch 6, iter 25800, avg. loss 2.20, avg. ppl 1.09 cum. examples 57525, speed 4838.54 words/sec, time elapsed 4959.51 sec
# epoch 6, iter 25900, avg. loss 2.33, avg. ppl 1.09 cum. examples 60724, speed 4619.44 words/sec, time elapsed 4978.83 sec
# epoch 6, iter 26000, avg. loss 2.34, avg. ppl 1.09 cum. examples 63923, speed 4742.95 words/sec, time elapsed 4997.81 sec
# epoch 6, iter 26000, cum. loss 2.70, cum. ppl 1.10 cum. examples 63923
# begin validation ...
# validation: iter 26000, dev. ppl 1.089528
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 6, iter 26100, avg. loss 2.27, avg. ppl 1.09 cum. examples 3196, speed 3731.01 words/sec, time elapsed 5021.31 sec
# epoch 6, iter 26200, avg. loss 2.22, avg. ppl 1.08 cum. examples 6395, speed 4669.17 words/sec, time elapsed 5040.19 sec
# epoch 6, iter 26300, avg. loss 2.23, avg. ppl 1.08 cum. examples 9593, speed 4646.15 words/sec, time elapsed 5059.41 sec
# epoch 6, iter 26400, avg. loss 2.30, avg. ppl 1.09 cum. examples 12792, speed 4479.75 words/sec, time elapsed 5079.12 sec
# epoch 6, iter 26500, avg. loss 2.38, avg. ppl 1.09 cum. examples 15991, speed 4704.38 words/sec, time elapsed 5098.29 sec
# epoch 6, iter 26600, avg. loss 2.42, avg. ppl 1.09 cum. examples 19189, speed 4535.07 words/sec, time elapsed 5117.84 sec
# epoch 6, iter 26700, avg. loss 2.26, avg. ppl 1.08 cum. examples 22386, speed 4595.53 words/sec, time elapsed 5137.16 sec
# epoch 6, iter 26800, avg. loss 2.19, avg. ppl 1.08 cum. examples 25580, speed 4580.67 words/sec, time elapsed 5156.67 sec
# epoch 6, iter 26900, avg. loss 2.20, avg. ppl 1.08 cum. examples 28778, speed 4746.45 words/sec, time elapsed 5175.42 sec
# epoch 6, iter 27000, avg. loss 2.17, avg. ppl 1.08 cum. examples 31973, speed 4485.89 words/sec, time elapsed 5195.55 sec
# epoch 6, iter 27100, avg. loss 2.39, avg. ppl 1.09 cum. examples 35171, speed 4684.93 words/sec, time elapsed 5214.87 sec
# epoch 6, iter 27200, avg. loss 2.03, avg. ppl 1.08 cum. examples 38370, speed 4862.44 words/sec, time elapsed 5233.21 sec
# epoch 6, iter 27300, avg. loss 2.24, avg. ppl 1.08 cum. examples 41567, speed 4460.51 words/sec, time elapsed 5253.42 sec
# epoch 6, iter 27400, avg. loss 2.17, avg. ppl 1.08 cum. examples 44762, speed 4752.18 words/sec, time elapsed 5271.92 sec
# epoch 6, iter 27500, avg. loss 2.22, avg. ppl 1.08 cum. examples 47961, speed 4678.56 words/sec, time elapsed 5290.83 sec
# epoch 6, iter 27600, avg. loss 2.48, avg. ppl 1.09 cum. examples 51158, speed 4559.79 words/sec, time elapsed 5310.52 sec
# epoch 6, iter 27700, avg. loss 2.32, avg. ppl 1.08 cum. examples 54354, speed 4540.26 words/sec, time elapsed 5330.88 sec
# epoch 6, iter 27800, avg. loss 2.40, avg. ppl 1.09 cum. examples 57551, speed 4444.12 words/sec, time elapsed 5350.99 sec
# epoch 6, iter 27900, avg. loss 2.16, avg. ppl 1.08 cum. examples 60748, speed 4773.81 words/sec, time elapsed 5369.99 sec
# epoch 6, iter 28000, avg. loss 2.17, avg. ppl 1.08 cum. examples 63943, speed 4740.77 words/sec, time elapsed 5388.63 sec
# epoch 6, iter 28000, cum. loss 2.26, cum. ppl 1.08 cum. examples 63943
# begin validation ...
# validation: iter 28000, dev. ppl 1.074804
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 6, iter 28100, avg. loss 2.05, avg. ppl 1.08 cum. examples 3194, speed 3811.91 words/sec, time elapsed 5412.07 sec
# epoch 6, iter 28200, avg. loss 2.14, avg. ppl 1.08 cum. examples 6393, speed 4588.83 words/sec, time elapsed 5431.41 sec
# epoch 6, iter 28300, avg. loss 2.28, avg. ppl 1.09 cum. examples 9590, speed 4605.21 words/sec, time elapsed 5450.52 sec
# epoch 6, iter 28400, avg. loss 2.24, avg. ppl 1.08 cum. examples 12786, speed 4547.70 words/sec, time elapsed 5470.30 sec
# epoch 6, iter 28500, avg. loss 1.93, avg. ppl 1.07 cum. examples 15984, speed 4893.77 words/sec, time elapsed 5488.27 sec
# epoch 6, iter 28600, avg. loss 2.20, avg. ppl 1.08 cum. examples 19183, speed 4463.66 words/sec, time elapsed 5508.34 sec
# epoch 6, iter 28700, avg. loss 1.98, avg. ppl 1.07 cum. examples 22379, speed 4677.93 words/sec, time elapsed 5527.11 sec
# epoch 6, iter 28800, avg. loss 1.99, avg. ppl 1.07 cum. examples 25573, speed 4666.98 words/sec, time elapsed 5546.25 sec
# epoch 6, iter 28900, avg. loss 2.01, avg. ppl 1.08 cum. examples 28772, speed 4654.77 words/sec, time elapsed 5565.33 sec
# epoch 6, iter 29000, avg. loss 1.99, avg. ppl 1.07 cum. examples 31972, speed 4520.67 words/sec, time elapsed 5585.10 sec
# epoch 6, iter 29100, avg. loss 2.01, avg. ppl 1.08 cum. examples 35168, speed 4615.53 words/sec, time elapsed 5604.08 sec
# epoch 7, iter 29200, avg. loss 1.72, avg. ppl 1.06 cum. examples 38340, speed 4752.15 words/sec, time elapsed 5622.48 sec
# epoch 7, iter 29300, avg. loss 1.54, avg. ppl 1.06 cum. examples 41535, speed 4506.70 words/sec, time elapsed 5642.32 sec
# epoch 7, iter 29400, avg. loss 1.42, avg. ppl 1.05 cum. examples 44731, speed 4504.91 words/sec, time elapsed 5662.16 sec
# epoch 7, iter 29500, avg. loss 1.58, avg. ppl 1.06 cum. examples 47929, speed 4490.12 words/sec, time elapsed 5681.99 sec
# epoch 7, iter 29600, avg. loss 1.45, avg. ppl 1.05 cum. examples 51128, speed 4749.19 words/sec, time elapsed 5700.85 sec
# epoch 7, iter 29700, avg. loss 1.45, avg. ppl 1.05 cum. examples 54324, speed 4955.81 words/sec, time elapsed 5718.78 sec
# epoch 7, iter 29800, avg. loss 1.50, avg. ppl 1.06 cum. examples 57520, speed 4766.76 words/sec, time elapsed 5737.14 sec
# epoch 7, iter 29900, avg. loss 1.38, avg. ppl 1.05 cum. examples 60718, speed 4759.17 words/sec, time elapsed 5755.56 sec
# epoch 7, iter 30000, avg. loss 1.58, avg. ppl 1.06 cum. examples 63916, speed 4552.19 words/sec, time elapsed 5775.06 sec
# epoch 7, iter 30000, cum. loss 1.82, cum. ppl 1.07 cum. examples 63916
# begin validation ...
# validation: iter 30000, dev. ppl 1.068665
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 7, iter 30100, avg. loss 1.47, avg. ppl 1.05 cum. examples 3197, speed 3588.12 words/sec, time elapsed 5799.89 sec
# epoch 7, iter 30200, avg. loss 1.59, avg. ppl 1.06 cum. examples 6394, speed 4657.28 words/sec, time elapsed 5818.70 sec
# epoch 7, iter 30300, avg. loss 1.54, avg. ppl 1.06 cum. examples 9591, speed 4688.08 words/sec, time elapsed 5837.79 sec
# epoch 7, iter 30400, avg. loss 1.44, avg. ppl 1.05 cum. examples 12788, speed 4860.71 words/sec, time elapsed 5855.93 sec
# epoch 7, iter 30500, avg. loss 1.40, avg. ppl 1.05 cum. examples 15983, speed 4789.84 words/sec, time elapsed 5874.42 sec
# epoch 7, iter 30600, avg. loss 1.42, avg. ppl 1.05 cum. examples 19178, speed 4767.24 words/sec, time elapsed 5892.65 sec
# epoch 7, iter 30700, avg. loss 1.49, avg. ppl 1.05 cum. examples 22376, speed 4547.07 words/sec, time elapsed 5912.57 sec
# epoch 7, iter 30800, avg. loss 1.47, avg. ppl 1.05 cum. examples 25572, speed 4786.34 words/sec, time elapsed 5931.13 sec
# epoch 7, iter 30900, avg. loss 1.54, avg. ppl 1.06 cum. examples 28770, speed 4429.82 words/sec, time elapsed 5950.96 sec
# epoch 7, iter 31000, avg. loss 1.44, avg. ppl 1.05 cum. examples 31969, speed 4707.42 words/sec, time elapsed 5969.76 sec
# epoch 7, iter 31100, avg. loss 1.52, avg. ppl 1.06 cum. examples 35168, speed 4585.25 words/sec, time elapsed 5989.23 sec
# epoch 7, iter 31200, avg. loss 1.55, avg. ppl 1.06 cum. examples 38367, speed 4463.81 words/sec, time elapsed 6009.12 sec
# epoch 7, iter 31300, avg. loss 1.49, avg. ppl 1.05 cum. examples 41562, speed 4576.37 words/sec, time elapsed 6028.79 sec
# epoch 7, iter 31400, avg. loss 1.41, avg. ppl 1.05 cum. examples 44757, speed 4572.83 words/sec, time elapsed 6048.09 sec
# epoch 7, iter 31500, avg. loss 1.48, avg. ppl 1.05 cum. examples 47952, speed 4428.95 words/sec, time elapsed 6068.42 sec
# epoch 7, iter 31600, avg. loss 1.51, avg. ppl 1.06 cum. examples 51151, speed 4406.62 words/sec, time elapsed 6088.27 sec
# epoch 7, iter 31700, avg. loss 1.57, avg. ppl 1.06 cum. examples 54350, speed 4704.14 words/sec, time elapsed 6107.43 sec
# epoch 7, iter 31800, avg. loss 1.32, avg. ppl 1.05 cum. examples 57548, speed 4880.89 words/sec, time elapsed 6125.48 sec
# epoch 7, iter 31900, avg. loss 1.47, avg. ppl 1.05 cum. examples 60744, speed 4650.21 words/sec, time elapsed 6144.58 sec
# epoch 7, iter 32000, avg. loss 1.37, avg. ppl 1.05 cum. examples 63943, speed 4600.15 words/sec, time elapsed 6163.88 sec
# epoch 7, iter 32000, cum. loss 1.48, cum. ppl 1.05 cum. examples 63943
# begin validation ...
# validation: iter 32000, dev. ppl 1.056858
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 7, iter 32100, avg. loss 1.42, avg. ppl 1.05 cum. examples 3199, speed 3653.80 words/sec, time elapsed 6187.91 sec
# epoch 7, iter 32200, avg. loss 1.44, avg. ppl 1.05 cum. examples 6394, speed 4727.04 words/sec, time elapsed 6206.92 sec
# epoch 7, iter 32300, avg. loss 1.51, avg. ppl 1.05 cum. examples 9593, speed 4567.45 words/sec, time elapsed 6227.08 sec
# epoch 7, iter 32400, avg. loss 1.46, avg. ppl 1.05 cum. examples 12792, speed 4457.84 words/sec, time elapsed 6246.92 sec
# epoch 7, iter 32500, avg. loss 1.32, avg. ppl 1.05 cum. examples 15989, speed 4868.54 words/sec, time elapsed 6265.07 sec
# epoch 7, iter 32600, avg. loss 1.35, avg. ppl 1.05 cum. examples 19187, speed 4799.01 words/sec, time elapsed 6283.53 sec
# epoch 7, iter 32700, avg. loss 1.40, avg. ppl 1.05 cum. examples 22386, speed 4850.45 words/sec, time elapsed 6301.92 sec
# epoch 7, iter 32800, avg. loss 1.52, avg. ppl 1.06 cum. examples 25581, speed 4539.52 words/sec, time elapsed 6321.44 sec
# epoch 7, iter 32900, avg. loss 1.36, avg. ppl 1.05 cum. examples 28779, speed 4798.55 words/sec, time elapsed 6340.01 sec
# epoch 7, iter 33000, avg. loss 1.31, avg. ppl 1.05 cum. examples 31977, speed 4795.70 words/sec, time elapsed 6358.48 sec
# epoch 7, iter 33100, avg. loss 1.35, avg. ppl 1.05 cum. examples 35172, speed 4822.12 words/sec, time elapsed 6377.19 sec
# epoch 7, iter 33200, avg. loss 1.39, avg. ppl 1.05 cum. examples 38372, speed 4678.73 words/sec, time elapsed 6396.24 sec
# epoch 7, iter 33300, avg. loss 1.36, avg. ppl 1.05 cum. examples 41570, speed 4593.35 words/sec, time elapsed 6415.91 sec
# epoch 8, iter 33400, avg. loss 1.11, avg. ppl 1.04 cum. examples 44742, speed 4629.88 words/sec, time elapsed 6435.44 sec
# epoch 8, iter 33500, avg. loss 0.87, avg. ppl 1.03 cum. examples 47940, speed 4752.36 words/sec, time elapsed 6454.01 sec
# epoch 8, iter 33600, avg. loss 0.95, avg. ppl 1.03 cum. examples 51139, speed 4634.51 words/sec, time elapsed 6473.35 sec
# epoch 8, iter 33700, avg. loss 0.89, avg. ppl 1.03 cum. examples 54336, speed 4755.61 words/sec, time elapsed 6491.55 sec
# epoch 8, iter 33800, avg. loss 0.99, avg. ppl 1.04 cum. examples 57533, speed 4572.97 words/sec, time elapsed 6511.00 sec
# epoch 8, iter 33900, avg. loss 0.88, avg. ppl 1.03 cum. examples 60733, speed 4720.57 words/sec, time elapsed 6529.68 sec
# epoch 8, iter 34000, avg. loss 0.93, avg. ppl 1.03 cum. examples 63929, speed 4524.04 words/sec, time elapsed 6549.69 sec
# epoch 8, iter 34000, cum. loss 1.24, cum. ppl 1.05 cum. examples 63929
# begin validation ...
# validation: iter 34000, dev. ppl 1.056932
# hit patience 1
# epoch 8, iter 34100, avg. loss 0.89, avg. ppl 1.03 cum. examples 3200, speed 4218.93 words/sec, time elapsed 6570.77 sec
# epoch 8, iter 34200, avg. loss 0.89, avg. ppl 1.03 cum. examples 6395, speed 4702.27 words/sec, time elapsed 6589.61 sec
# epoch 8, iter 34300, avg. loss 0.92, avg. ppl 1.03 cum. examples 9593, speed 4637.94 words/sec, time elapsed 6608.47 sec
# epoch 8, iter 34400, avg. loss 1.01, avg. ppl 1.04 cum. examples 12790, speed 4548.12 words/sec, time elapsed 6628.01 sec
# epoch 8, iter 34500, avg. loss 0.89, avg. ppl 1.03 cum. examples 15989, speed 4613.55 words/sec, time elapsed 6647.22 sec
# epoch 8, iter 34600, avg. loss 0.92, avg. ppl 1.03 cum. examples 19186, speed 4886.28 words/sec, time elapsed 6665.48 sec
# epoch 8, iter 34700, avg. loss 1.00, avg. ppl 1.04 cum. examples 22385, speed 4792.11 words/sec, time elapsed 6683.96 sec
# epoch 8, iter 34800, avg. loss 0.95, avg. ppl 1.03 cum. examples 25584, speed 4468.04 words/sec, time elapsed 6704.04 sec
# epoch 8, iter 34900, avg. loss 1.06, avg. ppl 1.04 cum. examples 28780, speed 4427.21 words/sec, time elapsed 6724.63 sec
# epoch 8, iter 35000, avg. loss 0.98, avg. ppl 1.04 cum. examples 31975, speed 4786.82 words/sec, time elapsed 6743.17 sec
# epoch 8, iter 35100, avg. loss 0.99, avg. ppl 1.04 cum. examples 35173, speed 4495.73 words/sec, time elapsed 6763.23 sec
# epoch 8, iter 35200, avg. loss 1.04, avg. ppl 1.04 cum. examples 38370, speed 4511.15 words/sec, time elapsed 6782.60 sec
# epoch 8, iter 35300, avg. loss 0.97, avg. ppl 1.04 cum. examples 41567, speed 4718.66 words/sec, time elapsed 6801.68 sec
# epoch 8, iter 35400, avg. loss 0.92, avg. ppl 1.03 cum. examples 44762, speed 4599.17 words/sec, time elapsed 6821.13 sec
# epoch 8, iter 35500, avg. loss 0.93, avg. ppl 1.03 cum. examples 47957, speed 4783.61 words/sec, time elapsed 6839.47 sec
# epoch 8, iter 35600, avg. loss 0.92, avg. ppl 1.03 cum. examples 51157, speed 4799.38 words/sec, time elapsed 6857.92 sec
# epoch 8, iter 35700, avg. loss 1.00, avg. ppl 1.04 cum. examples 54354, speed 4569.34 words/sec, time elapsed 6877.29 sec
# epoch 8, iter 35800, avg. loss 0.93, avg. ppl 1.03 cum. examples 57550, speed 4689.15 words/sec, time elapsed 6896.31 sec
# epoch 8, iter 35900, avg. loss 1.02, avg. ppl 1.04 cum. examples 60750, speed 4720.74 words/sec, time elapsed 6915.42 sec
# epoch 8, iter 36000, avg. loss 1.02, avg. ppl 1.04 cum. examples 63947, speed 4690.60 words/sec, time elapsed 6934.77 sec
# epoch 8, iter 36000, cum. loss 0.96, cum. ppl 1.04 cum. examples 63947
# begin validation ...
# ...
# epoch 27, iter 113200, avg. loss 0.01, avg. ppl 1.00 cum. examples 38343, speed 4605.58 words/sec, time elapsed 21802.91 sec
# epoch 27, iter 113300, avg. loss 0.02, avg. ppl 1.00 cum. examples 41541, speed 4692.29 words/sec, time elapsed 21821.68 sec
# epoch 27, iter 113400, avg. loss 0.01, avg. ppl 1.00 cum. examples 44736, speed 4556.78 words/sec, time elapsed 21842.00 sec
# epoch 27, iter 113500, avg. loss 0.01, avg. ppl 1.00 cum. examples 47931, speed 4511.91 words/sec, time elapsed 21861.94 sec
# epoch 27, iter 113600, avg. loss 0.01, avg. ppl 1.00 cum. examples 51130, speed 4767.94 words/sec, time elapsed 21880.15 sec
# epoch 27, iter 113700, avg. loss 0.01, avg. ppl 1.00 cum. examples 54328, speed 4713.16 words/sec, time elapsed 21898.85 sec
# epoch 27, iter 113800, avg. loss 0.01, avg. ppl 1.00 cum. examples 57521, speed 4615.47 words/sec, time elapsed 21918.15 sec
# epoch 27, iter 113900, avg. loss 0.01, avg. ppl 1.00 cum. examples 60719, speed 4945.46 words/sec, time elapsed 21935.92 sec
# epoch 27, iter 114000, avg. loss 0.01, avg. ppl 1.00 cum. examples 63915, speed 4765.74 words/sec, time elapsed 21954.59 sec
# epoch 27, iter 114000, cum. loss 0.01, cum. ppl 1.00 cum. examples 63915
# begin validation ...
# validation: iter 114000, dev. ppl 1.013774
# hit patience 1
# epoch 27, iter 114100, avg. loss 0.02, avg. ppl 1.00 cum. examples 3198, speed 3971.42 words/sec, time elapsed 21977.15 sec
# epoch 27, iter 114200, avg. loss 0.01, avg. ppl 1.00 cum. examples 6394, speed 4819.10 words/sec, time elapsed 21995.64 sec
# epoch 27, iter 114300, avg. loss 0.01, avg. ppl 1.00 cum. examples 9590, speed 4738.39 words/sec, time elapsed 22014.14 sec
# epoch 27, iter 114400, avg. loss 0.01, avg. ppl 1.00 cum. examples 12787, speed 4727.18 words/sec, time elapsed 22032.66 sec
# epoch 27, iter 114500, avg. loss 0.01, avg. ppl 1.00 cum. examples 15985, speed 4501.78 words/sec, time elapsed 22052.26 sec
# epoch 27, iter 114600, avg. loss 0.01, avg. ppl 1.00 cum. examples 19177, speed 4560.99 words/sec, time elapsed 22071.78 sec
# epoch 27, iter 114700, avg. loss 0.01, avg. ppl 1.00 cum. examples 22376, speed 4670.29 words/sec, time elapsed 22090.53 sec
# epoch 27, iter 114800, avg. loss 0.02, avg. ppl 1.00 cum. examples 25576, speed 4537.47 words/sec, time elapsed 22110.15 sec
# epoch 27, iter 114900, avg. loss 0.01, avg. ppl 1.00 cum. examples 28772, speed 4760.43 words/sec, time elapsed 22128.54 sec
# epoch 27, iter 115000, avg. loss 0.01, avg. ppl 1.00 cum. examples 31967, speed 4565.33 words/sec, time elapsed 22148.66 sec
# epoch 27, iter 115100, avg. loss 0.01, avg. ppl 1.00 cum. examples 35166, speed 4801.76 words/sec, time elapsed 22167.30 sec
# epoch 27, iter 115200, avg. loss 0.01, avg. ppl 1.00 cum. examples 38362, speed 4702.53 words/sec, time elapsed 22186.29 sec
# epoch 27, iter 115300, avg. loss 0.01, avg. ppl 1.00 cum. examples 41562, speed 4770.81 words/sec, time elapsed 22204.96 sec
# epoch 27, iter 115400, avg. loss 0.01, avg. ppl 1.00 cum. examples 44759, speed 4911.17 words/sec, time elapsed 22222.77 sec
# epoch 27, iter 115500, avg. loss 0.01, avg. ppl 1.00 cum. examples 47956, speed 4604.93 words/sec, time elapsed 22242.06 sec
# epoch 27, iter 115600, avg. loss 0.01, avg. ppl 1.00 cum. examples 51152, speed 4811.42 words/sec, time elapsed 22260.46 sec
# epoch 27, iter 115700, avg. loss 0.01, avg. ppl 1.00 cum. examples 54350, speed 4576.25 words/sec, time elapsed 22279.85 sec
# epoch 27, iter 115800, avg. loss 0.01, avg. ppl 1.00 cum. examples 57549, speed 4809.92 words/sec, time elapsed 22298.55 sec
# epoch 27, iter 115900, avg. loss 0.01, avg. ppl 1.00 cum. examples 60747, speed 4428.33 words/sec, time elapsed 22318.90 sec
# epoch 27, iter 116000, avg. loss 0.01, avg. ppl 1.00 cum. examples 63945, speed 4713.09 words/sec, time elapsed 22337.67 sec
# epoch 27, iter 116000, cum. loss 0.01, cum. ppl 1.00 cum. examples 63945
# begin validation ...
# validation: iter 116000, dev. ppl 1.013121
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 27, iter 116100, avg. loss 0.02, avg. ppl 1.00 cum. examples 3200, speed 3556.03 words/sec, time elapsed 22362.64 sec
# epoch 27, iter 116200, avg. loss 0.01, avg. ppl 1.00 cum. examples 6399, speed 4907.93 words/sec, time elapsed 22380.98 sec
# epoch 27, iter 116300, avg. loss 0.02, avg. ppl 1.00 cum. examples 9594, speed 4366.45 words/sec, time elapsed 22401.31 sec
# epoch 27, iter 116400, avg. loss 0.02, avg. ppl 1.00 cum. examples 12792, speed 4662.12 words/sec, time elapsed 22420.72 sec
# epoch 27, iter 116500, avg. loss 0.01, avg. ppl 1.00 cum. examples 15992, speed 4820.72 words/sec, time elapsed 22439.38 sec
# epoch 27, iter 116600, avg. loss 0.01, avg. ppl 1.00 cum. examples 19190, speed 4805.31 words/sec, time elapsed 22457.93 sec
# epoch 28, iter 116700, avg. loss 0.01, avg. ppl 1.00 cum. examples 22360, speed 4655.82 words/sec, time elapsed 22476.76 sec
# epoch 28, iter 116800, avg. loss 0.01, avg. ppl 1.00 cum. examples 25557, speed 4734.23 words/sec, time elapsed 22495.75 sec
# epoch 28, iter 116900, avg. loss 0.01, avg. ppl 1.00 cum. examples 28753, speed 4545.74 words/sec, time elapsed 22515.13 sec
# epoch 28, iter 117000, avg. loss 0.01, avg. ppl 1.00 cum. examples 31949, speed 4716.55 words/sec, time elapsed 22534.28 sec
# epoch 28, iter 117100, avg. loss 0.01, avg. ppl 1.00 cum. examples 35148, speed 4742.43 words/sec, time elapsed 22553.19 sec
# epoch 28, iter 117200, avg. loss 0.01, avg. ppl 1.00 cum. examples 38346, speed 4742.26 words/sec, time elapsed 22571.97 sec
# epoch 28, iter 117300, avg. loss 0.01, avg. ppl 1.00 cum. examples 41544, speed 4694.33 words/sec, time elapsed 22591.16 sec
# epoch 28, iter 117400, avg. loss 0.01, avg. ppl 1.00 cum. examples 44740, speed 4716.97 words/sec, time elapsed 22609.72 sec
# epoch 28, iter 117500, avg. loss 0.01, avg. ppl 1.00 cum. examples 47936, speed 4751.61 words/sec, time elapsed 22628.69 sec
# epoch 28, iter 117600, avg. loss 0.01, avg. ppl 1.00 cum. examples 51132, speed 4550.50 words/sec, time elapsed 22648.45 sec
# epoch 28, iter 117700, avg. loss 0.03, avg. ppl 1.00 cum. examples 54328, speed 4318.25 words/sec, time elapsed 22669.19 sec
# epoch 28, iter 117800, avg. loss 0.02, avg. ppl 1.00 cum. examples 57526, speed 4571.61 words/sec, time elapsed 22688.79 sec
# epoch 28, iter 117900, avg. loss 0.01, avg. ppl 1.00 cum. examples 60723, speed 4793.03 words/sec, time elapsed 22707.14 sec
# epoch 28, iter 118000, avg. loss 0.01, avg. ppl 1.00 cum. examples 63920, speed 4803.05 words/sec, time elapsed 22725.83 sec
# epoch 28, iter 118000, cum. loss 0.01, cum. ppl 1.00 cum. examples 63920
# begin validation ...
# validation: iter 118000, dev. ppl 1.012639
# save currently the best model to [transformer_model.bin]
# save model parameters to [transformer_model.bin]
# epoch 28, iter 118100, avg. loss 0.01, avg. ppl 1.00 cum. examples 3196, speed 3653.65 words/sec, time elapsed 22750.33 sec
# epoch 28, iter 118200, avg. loss 0.01, avg. ppl 1.00 cum. examples 6395, speed 4729.33 words/sec, time elapsed 22769.26 sec
# epoch 28, iter 118300, avg. loss 0.00, avg. ppl 1.00 cum. examples 9591, speed 4742.70 words/sec, time elapsed 22787.85 sec
# epoch 28, iter 118400, avg. loss 0.01, avg. ppl 1.00 cum. examples 12789, speed 4757.12 words/sec, time elapsed 22806.43 sec
# epoch 28, iter 118500, avg. loss 0.01, avg. ppl 1.00 cum. examples 15987, speed 4815.85 words/sec, time elapsed 22824.39 sec
# epoch 28, iter 118600, avg. loss 0.01, avg. ppl 1.00 cum. examples 19184, speed 4695.14 words/sec, time elapsed 22843.53 sec
# epoch 28, iter 118700, avg. loss 0.00, avg. ppl 1.00 cum. examples 22379, speed 4629.36 words/sec, time elapsed 22862.89 sec
# epoch 28, iter 118800, avg. loss 0.00, avg. ppl 1.00 cum. examples 25577, speed 4694.65 words/sec, time elapsed 22881.79 sec
# epoch 28, iter 118900, avg. loss 0.01, avg. ppl 1.00 cum. examples 28775, speed 4577.37 words/sec, time elapsed 22900.79 sec
# epoch 28, iter 119000, avg. loss 0.01, avg. ppl 1.00 cum. examples 31971, speed 4882.25 words/sec, time elapsed 22918.99 sec
# epoch 28, iter 119100, avg. loss 0.01, avg. ppl 1.00 cum. examples 35171, speed 4604.15 words/sec, time elapsed 22938.25 sec
# epoch 28, iter 119200, avg. loss 0.01, avg. ppl 1.00 cum. examples 38371, speed 4563.51 words/sec, time elapsed 22957.70 sec
# epoch 28, iter 119300, avg. loss 0.00, avg. ppl 1.00 cum. examples 41565, speed 4901.69 words/sec, time elapsed 22975.71 sec
# epoch 28, iter 119400, avg. loss 0.01, avg. ppl 1.00 cum. examples 44762, speed 4748.70 words/sec, time elapsed 22994.22 sec
# epoch 28, iter 119500, avg. loss 0.01, avg. ppl 1.00 cum. examples 47960, speed 4746.51 words/sec, time elapsed 23013.13 sec
# epoch 28, iter 119600, avg. loss 0.01, avg. ppl 1.00 cum. examples 51157, speed 4591.72 words/sec, time elapsed 23032.65 sec
# epoch 28, iter 119700, avg. loss 0.01, avg. ppl 1.00 cum. examples 54355, speed 4763.22 words/sec, time elapsed 23051.20 sec
# epoch 28, iter 119800, avg. loss 0.01, avg. ppl 1.00 cum. examples 57553, speed 4780.09 words/sec, time elapsed 23069.92 sec
# epoch 28, iter 119900, avg. loss 0.02, avg. ppl 1.00 cum. examples 60752, speed 4683.11 words/sec, time elapsed 23089.13 sec
# epoch 28, iter 120000, avg. loss 0.01, avg. ppl 1.00 cum. examples 63951, speed 4732.66 words/sec, time elapsed 23108.25 sec
# epoch 28, iter 120000, cum. loss 0.01, cum. ppl 1.00 cum. examples 63951
# begin validation ...
# validation: iter 120000, dev. ppl 1.013010
# hit patience 1
# epoch 28, iter 120100, avg. loss 0.02, avg. ppl 1.00 cum. examples 3199, speed 4047.27 words/sec, time elapsed 23130.25 sec
# epoch 28, iter 120200, avg. loss 0.01, avg. ppl 1.00 cum. examples 6395, speed 4910.11 words/sec, time elapsed 23148.15 sec
# epoch 28, iter 120300, avg. loss 0.01, avg. ppl 1.00 cum. examples 9593, speed 4766.36 words/sec, time elapsed 23166.82 sec
# epoch 28, iter 120400, avg. loss 0.01, avg. ppl 1.00 cum. examples 12791, speed 4665.00 words/sec, time elapsed 23185.56 sec
# epoch 28, iter 120500, avg. loss 0.01, avg. ppl 1.00 cum. examples 15988, speed 4775.37 words/sec, time elapsed 23203.98 sec
# epoch 28, iter 120600, avg. loss 0.01, avg. ppl 1.00 cum. examples 19185, speed 4621.49 words/sec, time elapsed 23223.30 sec
# epoch 28, iter 120700, avg. loss 0.01, avg. ppl 1.00 cum. examples 22382, speed 4482.43 words/sec, time elapsed 23243.09 sec
# epoch 28, iter 120800, avg. loss 0.01, avg. ppl 1.00 cum. examples 25582, speed 4543.27 words/sec, time elapsed 23263.06 sec
# epoch 29, iter 120900, avg. loss 0.01, avg. ppl 1.00 cum. examples 28750, speed 4605.29 words/sec, time elapsed 23282.20 sec
# epoch 29, iter 121000, avg. loss 0.01, avg. ppl 1.00 cum. examples 31948, speed 4670.52 words/sec, time elapsed 23301.63 sec
# epoch 29, iter 121100, avg. loss 0.02, avg. ppl 1.00 cum. examples 35143, speed 4672.89 words/sec, time elapsed 23320.69 sec
# epoch 29, iter 121200, avg. loss 0.01, avg. ppl 1.00 cum. examples 38341, speed 4819.59 words/sec, time elapsed 23338.96 sec
# epoch 29, iter 121300, avg. loss 0.02, avg. ppl 1.00 cum. examples 41536, speed 4514.53 words/sec, time elapsed 23358.95 sec
# epoch 29, iter 121400, avg. loss 0.01, avg. ppl 1.00 cum. examples 44733, speed 4583.97 words/sec, time elapsed 23378.15 sec
# epoch 29, iter 121500, avg. loss 0.01, avg. ppl 1.00 cum. examples 47931, speed 4590.46 words/sec, time elapsed 23397.59 sec
# epoch 29, iter 121600, avg. loss 0.01, avg. ppl 1.00 cum. examples 51126, speed 4800.27 words/sec, time elapsed 23416.10 sec
# epoch 29, iter 121700, avg. loss 0.01, avg. ppl 1.00 cum. examples 54325, speed 4796.39 words/sec, time elapsed 23434.47 sec
# epoch 29, iter 121800, avg. loss 0.01, avg. ppl 1.00 cum. examples 57522, speed 4747.65 words/sec, time elapsed 23453.19 sec
# epoch 29, iter 121900, avg. loss 0.03, avg. ppl 1.00 cum. examples 60716, speed 4559.09 words/sec, time elapsed 23472.62 sec
# epoch 29, iter 122000, avg. loss 0.01, avg. ppl 1.00 cum. examples 63913, speed 4627.63 words/sec, time elapsed 23491.81 sec
# epoch 29, iter 122000, cum. loss 0.01, cum. ppl 1.00 cum. examples 63913
# begin validation ...
# validation: iter 122000, dev. ppl 1.014027
# hit patience 2
# epoch 29, iter 122100, avg. loss 0.01, avg. ppl 1.00 cum. examples 3198, speed 4186.17 words/sec, time elapsed 23513.15 sec
# epoch 29, iter 122200, avg. loss 0.01, avg. ppl 1.00 cum. examples 6397, speed 4973.64 words/sec, time elapsed 23530.85 sec
# epoch 29, iter 122300, avg. loss 0.02, avg. ppl 1.00 cum. examples 9594, speed 4382.13 words/sec, time elapsed 23551.45 sec
# epoch 29, iter 122400, avg. loss 0.01, avg. ppl 1.00 cum. examples 12793, speed 4615.65 words/sec, time elapsed 23570.49 sec
# epoch 29, iter 122500, avg. loss 0.01, avg. ppl 1.00 cum. examples 15988, speed 4631.28 words/sec, time elapsed 23589.85 sec
# epoch 29, iter 122600, avg. loss 0.00, avg. ppl 1.00 cum. examples 19188, speed 4761.76 words/sec, time elapsed 23608.91 sec
# epoch 29, iter 122700, avg. loss 0.01, avg. ppl 1.00 cum. examples 22386, speed 4544.29 words/sec, time elapsed 23628.55 sec
# epoch 29, iter 122800, avg. loss 0.01, avg. ppl 1.00 cum. examples 25585, speed 4774.32 words/sec, time elapsed 23647.14 sec
# epoch 29, iter 122900, avg. loss 0.01, avg. ppl 1.00 cum. examples 28782, speed 4801.80 words/sec, time elapsed 23665.32 sec
# epoch 29, iter 123000, avg. loss 0.01, avg. ppl 1.00 cum. examples 31978, speed 4668.12 words/sec, time elapsed 23684.35 sec
# epoch 29, iter 123100, avg. loss 0.01, avg. ppl 1.00 cum. examples 35176, speed 4657.13 words/sec, time elapsed 23703.57 sec
# epoch 29, iter 123200, avg. loss 0.01, avg. ppl 1.00 cum. examples 38374, speed 4697.07 words/sec, time elapsed 23722.42 sec
# epoch 29, iter 123300, avg. loss 0.01, avg. ppl 1.00 cum. examples 41573, speed 4694.22 words/sec, time elapsed 23741.19 sec
# epoch 29, iter 123400, avg. loss 0.01, avg. ppl 1.00 cum. examples 44770, speed 4610.80 words/sec, time elapsed 23760.46 sec
# epoch 29, iter 123500, avg. loss 0.01, avg. ppl 1.00 cum. examples 47968, speed 4573.69 words/sec, time elapsed 23780.36 sec
# epoch 29, iter 123600, avg. loss 0.01, avg. ppl 1.00 cum. examples 51163, speed 4553.67 words/sec, time elapsed 23799.65 sec
# epoch 29, iter 123700, avg. loss 0.01, avg. ppl 1.00 cum. examples 54362, speed 4445.61 words/sec, time elapsed 23819.38 sec
# epoch 29, iter 123800, avg. loss 0.01, avg. ppl 1.00 cum. examples 57559, speed 4699.84 words/sec, time elapsed 23838.05 sec
# epoch 29, iter 123900, avg. loss 0.01, avg. ppl 1.00 cum. examples 60756, speed 4735.43 words/sec, time elapsed 23856.76 sec
# epoch 29, iter 124000, avg. loss 0.01, avg. ppl 1.00 cum. examples 63953, speed 4810.57 words/sec, time elapsed 23875.43 sec
# epoch 29, iter 124000, cum. loss 0.01, cum. ppl 1.00 cum. examples 63953
# begin validation ...
# validation: iter 124000, dev. ppl 1.013113
# hit patience 3
# epoch 29, iter 124100, avg. loss 0.01, avg. ppl 1.00 cum. examples 3196, speed 4106.10 words/sec, time elapsed 23897.33 sec
# epoch 29, iter 124200, avg. loss 0.01, avg. ppl 1.00 cum. examples 6395, speed 4768.48 words/sec, time elapsed 23915.73 sec
# epoch 29, iter 124300, avg. loss 0.01, avg. ppl 1.00 cum. examples 9592, speed 4635.07 words/sec, time elapsed 23935.29 sec
# epoch 29, iter 124400, avg. loss 0.01, avg. ppl 1.00 cum. examples 12788, speed 4782.35 words/sec, time elapsed 23953.78 sec
# epoch 29, iter 124500, avg. loss 0.01, avg. ppl 1.00 cum. examples 15986, speed 4486.38 words/sec, time elapsed 23973.84 sec
# epoch 29, iter 124600, avg. loss 0.01, avg. ppl 1.00 cum. examples 19185, speed 4901.71 words/sec, time elapsed 23991.87 sec
# epoch 29, iter 124700, avg. loss 0.01, avg. ppl 1.00 cum. examples 22384, speed 4805.96 words/sec, time elapsed 24010.37 sec
# epoch 29, iter 124800, avg. loss 0.01, avg. ppl 1.00 cum. examples 25578, speed 4836.40 words/sec, time elapsed 24028.69 sec
# epoch 29, iter 124900, avg. loss 0.01, avg. ppl 1.00 cum. examples 28778, speed 4921.88 words/sec, time elapsed 24046.37 sec
# epoch 29, iter 125000, avg. loss 0.01, avg. ppl 1.00 cum. examples 31976, speed 4620.04 words/sec, time elapsed 24065.77 sec

# %% [markdown]
# dựa trên các tiêu chí avg. loss, avg. ppl, time elapsed thì có thể thấy mô hình Transformer có kết quả tốt hơn so với mô hình LSTM-Attention về cả độ chính xác và tốc độ huấn luyện

# %%
# Load the pre-trained model weights
model_path = "/content/drive/MyDrive/Colab Notebooks/VietAI/ASM/transformer_model.bin"
model_state_dict = torch.load(model_path)

# Create an instance of the TransformerNMT model with the same configuration used during training
model = TransformerNMT(d_model=768, n_heads=8, ff_size=768, n_layers=4, max_len=320, vocab=vocab, dropout_rate=0.1)

# Load the model weights
model.load_state_dict(model_state_dict)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-ec97a9261fdd> in <cell line: 9>()
#       7
#       8 # Load the model weights
# ----> 9 model.load_state_dict(model_state_dict)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    2039
#    2040         if len(error_msgs) > 0:
# -> 2041             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2042                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    2043         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for TransformerNMT:
# 	Missing key(s) in state_dict: "src_embedding.pos_embedding", "src_embedding.token_embedding.weight", "tgt_embedding.pos_embedding", "tgt_embedding.token_embedding.weight", "transformer.encoder.layers.0.self_attn.in_proj_weight", "transformer.encoder.layers.0.self_attn.in_proj_bias", "transformer.encoder.layers.0.self_attn.out_proj.weight", "transformer.encoder.layers.0.self_attn.out_proj.bias", "transformer.encoder.layers.0.linear1.weight", "transformer.encoder.layers.0.linear1.bias", "transformer.encoder.layers.0.linear2.weight", "transformer.encoder.layers.0.linear2.bias", "transformer.encoder.layers.0.norm1.weight", "transformer.encoder.layers.0.norm1.bias", "transformer.encoder.layers.0.norm2.weight", "transformer.encoder.layers.0.norm2.bias", "transformer.encoder.layers.1.self_attn.in_proj_weight", "transformer.encoder.layers.1.self_attn.in_proj_bias", "transformer.encoder.layers.1.self_attn.out_proj.weight", "transformer.encoder.layers.1.self_attn.out_proj.bias", "transformer.encoder.layers.1.linear1.weight", "transformer.encoder.layers.1.linear1.bias", "transformer.encoder.layers.1.linear2.weight", "transformer.encoder.layers.1.linear2.bias", "transformer.encoder.layers.1.norm1.weight", "transformer.encoder.layers.1.norm1.bias", "transformer.encoder.layers.1.norm2.weight", "transformer.encoder.layers.1.norm2.bias", "transformer.encoder.layers.2.self_attn.in_proj_weight", "transformer.encoder.layers.2.self_attn.in_proj_bias", "transformer.encoder.layers.2.self_attn....
# 	Unexpected key(s) in state_dict: "args", "vocab", "state_dict".

# %%
import nltk

def tokenize(sentence):
    # Download the necessary resources for tokenization (only required once)
    nltk.download('punkt')
    
    # Tokenize the sentence into individual tokens
    tokens = nltk.word_tokenize(sentence)
    
    return tokens

# %%
# Tokenize the source sentence
source_sentence = "xin chào, bạn khỏe không?"
source_tokens = tokenize(source_sentence)  # Implement a tokenization function that splits the sentence into tokens
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
source_tokens
# Out:
# ['xin', 'chào', ',', 'bạn', 'khỏe', 'không', '?']

# %%
# Translate the source sentence
translated_tokens = model.translate(source_tokens)

# Join the translated tokens into a readable translation
translation = " ".join(translated_tokens)

# Print the translation
print(translation)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-523a93fa651c> in <cell line: 2>()
#       1 # Translate the source sentence
# ----> 2 translated_tokens = model.translate(source_tokens)
#       3
#       4 # Join the translated tokens into a readable translation
#       5 translation = " ".join(translated_tokens)
#
# AttributeError: 'dict' object has no attribute 'translate'

# %%
# function to generate output sequence using greedy algorithm
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    src = src.to(device)
    src_mask = src_mask.to(device)

    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type(torch.long).to(device)
    for i in range(max_len-1):
        memory = memory.to(device)
        tgt_mask = TransformerNMT.generate_square_subsequent_mask(ys.size(0)).type(torch.bool).to(device)
        out = model.decode(ys, memory, tgt_mask)
        out = out.transpose(0, 1)
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim=1)
        next_word = next_word.item()

        ys = torch.cat([ys,
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=0)
        if next_word == 2:
            break
    return ys


# actual function to translate input sentence into target language
def translate(model: torch.nn.Module, src_sentence: str):
    model.eval()
    src = text_transform[SRC_LANGUAGE](src_sentence).view(-1, 1)
    num_tokens = src.shape[0]
    src_mask = (torch.zeros(num_tokens, num_tokens)).type(torch.bool)
    tgt_tokens = greedy_decode(
        model,  src, src_mask, max_len=num_tokens + 5, start_symbol=1).flatten()
    return " ".join(vocab_transform[TGT_LANGUAGE].lookup_tokens(list(tgt_tokens.cpu().numpy()))).replace("<s>", "").replace("</s>", "")
